# %%
#Importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ##Data Loading

# %%
#Loading data
path = '/content/4A_cleaned_7.xlsx'
data =pd.read_excel(path)
data.head(2)
# Out:
#   IP NUMBER UNIT SEX  AGE MARITAL STATUS RELIGION DISTRICT OF RESIDENCE  \
# 0   1861416   GI   M   30              2      COU           Nakasongola
# 1   1868011   GI   F   46              2      COU               Kampala
#
#     REGION                 WORKING DIAGNOSIS ADDITIONAL WORKING DIAGNOSIS  \
# 0  CENTRAL                ISS,Abdominal TB,,                        ISS,,
# 1  CENTRAL  ISS Stage I&II,Disseminated TB,,             ISS Stage I&II,,
#
#    NUMBER OF ADDITIONAL WORKING DIAGNOSIS          TB_type  \
# 0                                       1     Abdominal_TB
# 1                                       1  Disseminated TB
#
#    NUMBER OF PREVIOUS ADMISSIONS DAY OF ADMISSION MONTH OF ADMISSION  \
# 0                              5          Tuesday           November
# 1                              3           Monday           December
#
#    YEAR OF ADMISSION  DURATION  OUT COME
# 0               2010         5  IMPROVED
# 1               2010         3  IMPROVED

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4034 entries, 0 to 4033
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   IP NUMBER                               4034 non-null   object
#  1   UNIT                                    4034 non-null   object
#  2   SEX                                     4034 non-null   object
#  3   AGE                                     4034 non-null   int64
#  4   MARITAL STATUS                          4031 non-null   object
#  5   RELIGION                                4034 non-null   object
#  6   DISTRICT OF RESIDENCE                   4034 non-null   object
#  7   REGION                                  4034 non-null   object
#  8   WORKING DIAGNOSIS                       4034 non-null   object
#  9   ADDITIONAL WORKING DIAGNOSIS            3854 non-null   object
#  10  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  4034 non-null   int64
#  11  TB_type                                 4034 non-null   object
#  12  NUMBER OF PREVIOUS ADMISSIONS           4034 non-null   int64
#  13  DAY OF ADMISSION                        4034 non-null   object
#  14  MONTH OF ADMISSION                      4034 non-null   object
#  15  YEAR OF ADMISSION                       4034 non-null   int64
#  16  DURATION                                4034 non-null   int64
#  17  OUT COME                                4034 non-null   object
# dtypes: int64(5), object(13)
# memory usage: 567.4+ KB

# %% [markdown]
# ##**Data Preprocessing**

# %%
#Deleting features which are not going to be used
features_to_remove = ['IP NUMBER', 'UNIT', 'DISTRICT OF RESIDENCE','WORKING DIAGNOSIS' ,'ADDITIONAL WORKING DIAGNOSIS',
                'MARITAL STATUS']
data = data.drop(columns = features_to_remove)

# %%
#filtering out only patients with "DIED" outcome
data = data[data['OUT COME'] == 'DIED']

# %%
#Encoding categorical features
non_features = ['YEAR OF ADMISSION', 'DURATION', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS','AGE','NUMBER OF PREVIOUS ADMISSIONS']
data1 = data.drop(columns=non_features)

text_columns = data1.select_dtypes(include=['object']).columns

data2 = pd.get_dummies(data, columns=text_columns)

# %%
data2['NUMBER OF PREVIOUS ADMISSIONS'].unique()
# Out:
# array([ 2,  4,  5,  1,  7,  6,  9, 20, 11, 13,  3,  8, 15, 14, 10, 18, 16,
#        22, 21, 25, 12, 26, 23, 92,  0])

# %%
data2['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'] = data2['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'].astype(float)
data2['AGE'] = data2['AGE'].astype(float)

# %%
data2.sample(4)
# Out:
#        AGE  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  \
# 2864  23.0                                     1.0
# 1993  30.0                                     1.0
# 257   25.0                                     1.0
# 3850  33.0                                     1.0
#
#       NUMBER OF PREVIOUS ADMISSIONS  YEAR OF ADMISSION  DURATION  SEX_F  \
# 2864                              0               2017        16      1
# 1993                              0               2015        12      0
# 257                               2               2011         2      1
# 3850                              0               2019         3      1
#
#       SEX_M  RELIGION_CATHOLIC  RELIGION_COU  RELIGION_ISLAM  ...  \
# 2864      0                  0             0               1  ...
# 1993      1                  0             0               1  ...
# 257       0                  1             0               0  ...
# 3850      0                  0             1               0  ...
#
#       MONTH OF ADMISSION_February  MONTH OF ADMISSION_January  \
# 2864                            0                           0
# 1993                            0                           1
# 257                             0                           0
# 3850                            0                           0
#
#       MONTH OF ADMISSION_July  MONTH OF ADMISSION_June  \
# 2864                        0                        0
# 1993                        0                        0
# 257                         0                        0
# 3850                        0                        0
#
#       MONTH OF ADMISSION_March  MONTH OF ADMISSION_May  \
# 2864                         1                       0
# 1993                         0                       0
# 257                          0                       0
# 3850                         0                       0
#
#       MONTH OF ADMISSION_November  MONTH OF ADMISSION_October  \
# 2864                            0                           0
# 1993                            0                           0
# 257                             1                           0
# 3850                            0                           0
#
#       MONTH OF ADMISSION_September  OUT COME_DIED
# 2864                             0              1
# 1993                             0              1
# 257                              0              1
# 3850                             0              1
#
# [4 rows x 43 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 5 to 4030
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   AGE                                     1291 non-null   float64
#  1   NUMBER OF ADDITIONAL WORKING DIAGNOSIS  1291 non-null   float64
#  2   NUMBER OF PREVIOUS ADMISSIONS           1291 non-null   int64
#  3   YEAR OF ADMISSION                       1291 non-null   int64
#  4   DURATION                                1291 non-null   int64
#  5   SEX_F                                   1291 non-null   uint8
#  6   SEX_M                                   1291 non-null   uint8
#  7   RELIGION_CATHOLIC                       1291 non-null   uint8
#  8   RELIGION_COU                            1291 non-null   uint8
#  9   RELIGION_ISLAM                          1291 non-null   uint8
#  10  RELIGION_OTHERS                         1291 non-null   uint8
#  11  RELIGION_PENTECOSTAL                    1291 non-null   uint8
#  12  REGION_CENTRAL                          1291 non-null   uint8
#  13  REGION_EASTERN                          1291 non-null   uint8
#  14  REGION_NORTHERN                         1291 non-null   uint8
#  15  REGION_UNKNOWN                          1291 non-null   uint8
#  16  REGION_WESTERN                          1291 non-null   uint8
#  17  TB_type_Abdominal_TB                    1291 non-null   uint8
#  18  TB_type_CNS_TB                          1291 non-null   uint8
#  19  TB_type_Disseminated TB                 1291 non-null   uint8
#  20  TB_type_Other TBs                       1291 non-null   uint8
#  21  TB_type_PTB                             1291 non-null   uint8
#  22  TB_type_TB iris                         1291 non-null   uint8
#  23  DAY OF ADMISSION_Friday                 1291 non-null   uint8
#  24  DAY OF ADMISSION_Monday                 1291 non-null   uint8
#  25  DAY OF ADMISSION_Saturday               1291 non-null   uint8
#  26  DAY OF ADMISSION_Sunday                 1291 non-null   uint8
#  27  DAY OF ADMISSION_Thursday               1291 non-null   uint8
#  28  DAY OF ADMISSION_Tuesday                1291 non-null   uint8
#  29  DAY OF ADMISSION_Wednesday              1291 non-null   uint8
#  30  MONTH OF ADMISSION_April                1291 non-null   uint8
#  31  MONTH OF ADMISSION_August               1291 non-null   uint8
#  32  MONTH OF ADMISSION_December             1291 non-null   uint8
#  33  MONTH OF ADMISSION_February             1291 non-null   uint8
#  34  MONTH OF ADMISSION_January              1291 non-null   uint8
#  35  MONTH OF ADMISSION_July                 1291 non-null   uint8
#  36  MONTH OF ADMISSION_June                 1291 non-null   uint8
#  37  MONTH OF ADMISSION_March                1291 non-null   uint8
#  38  MONTH OF ADMISSION_May                  1291 non-null   uint8
#  39  MONTH OF ADMISSION_November             1291 non-null   uint8
#  40  MONTH OF ADMISSION_October              1291 non-null   uint8
#  41  MONTH OF ADMISSION_September            1291 non-null   uint8
#  42  OUT COME_DIED                           1291 non-null   uint8
# dtypes: float64(2), int64(3), uint8(38)
# memory usage: 108.4 KB

# %%
from scipy.stats import skew
import seaborn as sns

#Visualizing skeness of the continuous features
continuous_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS','DURATION']
for col in continuous_features:
  print(col)
  print(skew(data2[col]))

  plt.figure()
  sns.distplot(data2[col])
  plt.show()
# Out:
# AGE
# 0.9509241869210756
# <ipython-input-11-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])
# NUMBER OF PREVIOUS ADMISSIONS
# 9.760011787542462
# <ipython-input-11-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])
# NUMBER OF ADDITIONAL WORKING DIAGNOSIS
# 0.47741907750448015
# <ipython-input-11-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])
# DURATION
# 1.4581473673442764
# <ipython-input-11-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])

# %%
#Visualizing Correlation among the continuous features nluding the target
continuous_features_target = ['AGE','NUMBER OF PREVIOUS ADMISSIONS', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS', 'DURATION']
plt.figure(figsize=(12,4))
sns.heatmap(data2[continuous_features_target].corr(), annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Heatmap of continuous Features Correlation')
plt.show()

# %%
#Transforming the continuous features
transform_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS','DURATION']
for col in transform_features:
  data2[col] = np.log1p(data2[col])

#Second transformation
data2['NUMBER OF PREVIOUS ADMISSIONS'] = np.log1p(data2['NUMBER OF PREVIOUS ADMISSIONS'])

# %%
#Normalizing and Standardizing continuous features
normalise_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS','NUMBER OF ADDITIONAL WORKING DIAGNOSIS']
scaler = MinMaxScaler()
data2[normalise_features] = scaler.fit_transform(data2[normalise_features])

# %%
#Plotting Density plot
import seaborn as sns

continuous_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS','NUMBER OF ADDITIONAL WORKING DIAGNOSIS','DURATION']

fig, axes = plt.subplots(1, len(continuous_features), figsize=(15, 5))

for i, col in enumerate(continuous_features):
  sns.kdeplot(data[col], fill=True,ax=axes[i])
  axes[i].set_title(f'Density Plot for {col}')
  axes[i].set_xlabel('Values')
  axes[i].set_ylabel('Density')
# plt.figure(figsize=(8,9))
# plt.bar(data['AGE'])
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data2.sample(2)
# Out:
#            AGE  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  \
# 151   0.382431                                0.898244
# 1071  0.450285                                0.386853
#
#       NUMBER OF PREVIOUS ADMISSIONS  YEAR OF ADMISSION  DURATION  SEX_F  \
# 151                        0.600162               2011  1.791759      0
# 1071                       0.000000               2013  1.945910      0
#
#       SEX_M  RELIGION_CATHOLIC  RELIGION_COU  RELIGION_ISLAM  ...  \
# 151       1                  0             1               0  ...
# 1071      1                  0             1               0  ...
#
#       MONTH OF ADMISSION_February  MONTH OF ADMISSION_January  \
# 151                             0                           0
# 1071                            0                           0
#
#       MONTH OF ADMISSION_July  MONTH OF ADMISSION_June  \
# 151                         0                        1
# 1071                        0                        0
#
#       MONTH OF ADMISSION_March  MONTH OF ADMISSION_May  \
# 151                          0                       0
# 1071                         0                       0
#
#       MONTH OF ADMISSION_November  MONTH OF ADMISSION_October  \
# 151                             0                           0
# 1071                            0                           0
#
#       MONTH OF ADMISSION_September  OUT COME_DIED
# 151                              0              1
# 1071                             0              1
#
# [2 rows x 43 columns]

# %%
data2['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'].unique()
# Out:
# array([0.38685281, 0.61314719, 0.77370561, 1.        , 0.8982444 ,
#        0.        ])

# %%
data2.shape
# Out:
# (1291, 43)

# %%
#Saving Preprocced data
#data.to_excel('preprocessed1_TB-4a.xlsx', index=False)

# %% [markdown]
# ##Data Splitting

# %%
data2['YEAR OF ADMISSION'].unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
#counting occurence of each year
year_count = data2['YEAR OF ADMISSION'].value_counts().sort_index()

#Plotting the Chart
plt.bar(year_count.index, year_count.values)

#Labelling
plt.xlabel('Year of admission')
plt.ylabel('Count')
plt.title('Year of admission Distribution')

#Labelling the bins
for year, count in zip(year_count.index, year_count.values):
  plt.text(year, count, str(year), ha='center', va='bottom')

#Show the Plot
plt.show()

# %%
#Splitting dataset into training and testing set
train_df = data2[data['YEAR OF ADMISSION'] <= 2016]

test_df = data2[data['YEAR OF ADMISSION'] > 2016]
#extracting features and targets

non_train_feature = ['YEAR OF ADMISSION',	'DURATION']

X_train = train_df.drop(columns=non_train_feature)
y_train = train_df['DURATION']

X_test = test_df.drop(columns=non_train_feature)
y_test = test_df['DURATION']

#Splitting data into training and testing sets
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %% [markdown]
# #**MODEL TRAINING**

# %%
import tensorflow as tf
from tensorflow import keras

tf.random.set_seed(42)

# %% [markdown]
# ##**Model1**

# %%
#neural network Architecture(ANN)
model1 = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(500, activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(5, activation='relu'),
    keras.layers.Dense(1, activation='linear')
])

model1.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse','mae'])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 500)               21000
#
#  dense_1 (Dense)             (None, 15)                7515
#
#  dense_2 (Dense)             (None, 10)                160
#
#  dense_3 (Dense)             (None, 5)                 55
#
#  dense_4 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 28736 (112.25 KB)
# Trainable params: 28736 (112.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#model1 training and validation
history1 = model1.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 2s 15ms/step - loss: 2.4045 - mse: 2.4045 - mae: 1.3639 - val_loss: 0.8486 - val_mse: 0.8486 - val_mae: 0.7547
# Epoch 2/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5925 - mse: 0.5925 - mae: 0.6187 - val_loss: 0.5017 - val_mse: 0.5017 - val_mae: 0.5796
# Epoch 3/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5041 - mse: 0.5041 - mae: 0.5827 - val_loss: 0.4592 - val_mse: 0.4592 - val_mae: 0.5637
# Epoch 4/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4830 - mse: 0.4830 - mae: 0.5680 - val_loss: 0.5020 - val_mse: 0.5020 - val_mae: 0.5817
# Epoch 5/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4762 - mse: 0.4762 - mae: 0.5630 - val_loss: 0.4900 - val_mse: 0.4900 - val_mae: 0.5787
# Epoch 6/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4696 - mse: 0.4696 - mae: 0.5599 - val_loss: 0.5172 - val_mse: 0.5172 - val_mae: 0.5926
# Epoch 7/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4601 - mse: 0.4601 - mae: 0.5531 - val_loss: 0.4868 - val_mse: 0.4868 - val_mae: 0.5799
# Epoch 8/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4644 - mse: 0.4644 - mae: 0.5544 - val_loss: 0.4940 - val_mse: 0.4940 - val_mae: 0.5850
# Epoch 9/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4451 - mse: 0.4451 - mae: 0.5455 - val_loss: 0.4964 - val_mse: 0.4964 - val_mae: 0.5863
# Epoch 10/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4407 - mse: 0.4407 - mae: 0.5403 - val_loss: 0.5526 - val_mse: 0.5526 - val_mae: 0.6107
# Epoch 11/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4254 - mse: 0.4254 - mae: 0.5306 - val_loss: 0.5263 - val_mse: 0.5263 - val_mae: 0.6002
# Epoch 12/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4149 - mse: 0.4149 - mae: 0.5242 - val_loss: 0.5185 - val_mse: 0.5185 - val_mae: 0.5956
# Epoch 13/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4026 - mse: 0.4026 - mae: 0.5156 - val_loss: 0.5629 - val_mse: 0.5629 - val_mae: 0.6207
# Epoch 14/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3884 - mse: 0.3884 - mae: 0.5065 - val_loss: 0.5407 - val_mse: 0.5407 - val_mae: 0.6062
# Epoch 15/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3794 - mse: 0.3794 - mae: 0.4991 - val_loss: 0.5388 - val_mse: 0.5388 - val_mae: 0.6042
# Epoch 16/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3654 - mse: 0.3654 - mae: 0.4889 - val_loss: 0.5475 - val_mse: 0.5475 - val_mae: 0.6072
# Epoch 17/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3430 - mse: 0.3430 - mae: 0.4749 - val_loss: 0.6076 - val_mse: 0.6076 - val_mae: 0.6402
# Epoch 18/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3368 - mse: 0.3368 - mae: 0.4670 - val_loss: 0.6003 - val_mse: 0.6003 - val_mae: 0.6358
# Epoch 19/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3139 - mse: 0.3139 - mae: 0.4489 - val_loss: 0.6343 - val_mse: 0.6343 - val_mae: 0.6535
# Epoch 20/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2980 - mse: 0.2980 - mae: 0.4395 - val_loss: 0.6004 - val_mse: 0.6004 - val_mae: 0.6309
# Epoch 21/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2947 - mse: 0.2947 - mae: 0.4323 - val_loss: 0.5922 - val_mse: 0.5922 - val_mae: 0.6272
# Epoch 22/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2648 - mse: 0.2648 - mae: 0.4117 - val_loss: 0.6302 - val_mse: 0.6302 - val_mae: 0.6460
# Epoch 23/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2492 - mse: 0.2492 - mae: 0.3978 - val_loss: 0.6833 - val_mse: 0.6833 - val_mae: 0.6717
# Epoch 24/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2356 - mse: 0.2356 - mae: 0.3864 - val_loss: 0.6426 - val_mse: 0.6426 - val_mae: 0.6471
# Epoch 25/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2184 - mse: 0.2184 - mae: 0.3690 - val_loss: 0.6620 - val_mse: 0.6620 - val_mae: 0.6600
# Epoch 26/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2071 - mse: 0.2071 - mae: 0.3568 - val_loss: 0.6849 - val_mse: 0.6849 - val_mae: 0.6698
# Epoch 27/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1948 - mse: 0.1948 - mae: 0.3445 - val_loss: 0.6773 - val_mse: 0.6773 - val_mae: 0.6611
# Epoch 28/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1801 - mse: 0.1801 - mae: 0.3320 - val_loss: 0.7067 - val_mse: 0.7067 - val_mae: 0.6734
# Epoch 29/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1707 - mse: 0.1707 - mae: 0.3202 - val_loss: 0.7965 - val_mse: 0.7965 - val_mae: 0.7249
# Epoch 30/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1589 - mse: 0.1589 - mae: 0.3099 - val_loss: 0.7364 - val_mse: 0.7364 - val_mae: 0.6892
# Epoch 31/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1464 - mse: 0.1464 - mae: 0.2936 - val_loss: 0.7249 - val_mse: 0.7249 - val_mae: 0.6796
# Epoch 32/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1367 - mse: 0.1367 - mae: 0.2838 - val_loss: 0.7537 - val_mse: 0.7537 - val_mae: 0.6939
# Epoch 33/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1302 - mse: 0.1302 - mae: 0.2758 - val_loss: 0.7631 - val_mse: 0.7631 - val_mae: 0.6980
# Epoch 34/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1205 - mse: 0.1205 - mae: 0.2619 - val_loss: 0.7353 - val_mse: 0.7353 - val_mae: 0.6862
# Epoch 35/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1109 - mse: 0.1109 - mae: 0.2500 - val_loss: 0.7751 - val_mse: 0.7751 - val_mae: 0.7062
# Epoch 36/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1074 - mse: 0.1074 - mae: 0.2424 - val_loss: 0.7787 - val_mse: 0.7787 - val_mae: 0.7029
# Epoch 37/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0973 - mse: 0.0973 - mae: 0.2351 - val_loss: 0.7491 - val_mse: 0.7491 - val_mae: 0.6872
# Epoch 38/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0924 - mse: 0.0924 - mae: 0.2264 - val_loss: 0.7825 - val_mse: 0.7825 - val_mae: 0.7103
# Epoch 39/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0824 - mse: 0.0824 - mae: 0.2127 - val_loss: 0.8395 - val_mse: 0.8395 - val_mae: 0.7388
# Epoch 40/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0815 - mse: 0.0815 - mae: 0.2076 - val_loss: 0.7869 - val_mse: 0.7869 - val_mae: 0.7126
# Epoch 41/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0689 - mse: 0.0689 - mae: 0.1881 - val_loss: 0.8193 - val_mse: 0.8193 - val_mae: 0.7230
# Epoch 42/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0636 - mse: 0.0636 - mae: 0.1786 - val_loss: 0.7579 - val_mse: 0.7579 - val_mae: 0.6947
# Epoch 43/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0629 - mse: 0.0629 - mae: 0.1776 - val_loss: 0.8071 - val_mse: 0.8071 - val_mae: 0.7209
# Epoch 44/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0589 - mse: 0.0589 - mae: 0.1682 - val_loss: 0.8106 - val_mse: 0.8106 - val_mae: 0.7193
# Epoch 45/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0530 - mse: 0.0530 - mae: 0.1586 - val_loss: 0.8403 - val_mse: 0.8403 - val_mae: 0.7358
# Epoch 46/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0514 - mse: 0.0514 - mae: 0.1547 - val_loss: 0.8077 - val_mse: 0.8077 - val_mae: 0.7217
# Epoch 47/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0497 - mse: 0.0497 - mae: 0.1504 - val_loss: 0.8152 - val_mse: 0.8152 - val_mae: 0.7240
# Epoch 48/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0436 - mse: 0.0436 - mae: 0.1376 - val_loss: 0.8522 - val_mse: 0.8522 - val_mae: 0.7436
# Epoch 49/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0427 - mse: 0.0427 - mae: 0.1347 - val_loss: 0.8443 - val_mse: 0.8443 - val_mae: 0.7401
# Epoch 50/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0439 - mse: 0.0439 - mae: 0.1388 - val_loss: 0.8195 - val_mse: 0.8195 - val_mae: 0.7239
# Epoch 51/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0401 - mse: 0.0401 - mae: 0.1323 - val_loss: 0.8744 - val_mse: 0.8744 - val_mae: 0.7552
# Epoch 52/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1363 - val_loss: 0.8501 - val_mse: 0.8501 - val_mae: 0.7399
# Epoch 53/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1276 - val_loss: 0.8595 - val_mse: 0.8595 - val_mae: 0.7450
# Epoch 54/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0385 - mse: 0.0385 - mae: 0.1243 - val_loss: 0.8419 - val_mse: 0.8419 - val_mae: 0.7384
# Epoch 55/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0354 - mse: 0.0354 - mae: 0.1207 - val_loss: 0.8718 - val_mse: 0.8718 - val_mae: 0.7557
# Epoch 56/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0353 - mse: 0.0353 - mae: 0.1194 - val_loss: 0.8471 - val_mse: 0.8471 - val_mae: 0.7347
# Epoch 57/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0328 - mse: 0.0328 - mae: 0.1134 - val_loss: 0.8393 - val_mse: 0.8393 - val_mae: 0.7361
# Epoch 58/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0327 - mse: 0.0327 - mae: 0.1108 - val_loss: 0.8489 - val_mse: 0.8489 - val_mae: 0.7403
# Epoch 59/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0326 - mse: 0.0326 - mae: 0.1082 - val_loss: 0.8528 - val_mse: 0.8528 - val_mae: 0.7444
# Epoch 60/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0326 - mse: 0.0326 - mae: 0.1106 - val_loss: 0.8446 - val_mse: 0.8446 - val_mae: 0.7385
# Epoch 61/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1028 - val_loss: 0.8623 - val_mse: 0.8623 - val_mae: 0.7492
# Epoch 62/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0297 - mse: 0.0297 - mae: 0.1058 - val_loss: 0.8599 - val_mse: 0.8599 - val_mae: 0.7472
# Epoch 63/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0282 - mse: 0.0282 - mae: 0.0982 - val_loss: 0.8440 - val_mse: 0.8440 - val_mae: 0.7358
# Epoch 64/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0271 - mse: 0.0271 - mae: 0.0948 - val_loss: 0.8645 - val_mse: 0.8645 - val_mae: 0.7455
# Epoch 65/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0287 - mse: 0.0287 - mae: 0.0971 - val_loss: 0.8377 - val_mse: 0.8377 - val_mae: 0.7368
# Epoch 66/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0282 - mse: 0.0282 - mae: 0.0977 - val_loss: 0.8774 - val_mse: 0.8774 - val_mae: 0.7569
# Epoch 67/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0288 - mse: 0.0288 - mae: 0.1008 - val_loss: 0.8483 - val_mse: 0.8483 - val_mae: 0.7392
# Epoch 68/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0261 - mse: 0.0261 - mae: 0.0912 - val_loss: 0.8627 - val_mse: 0.8627 - val_mae: 0.7469
# Epoch 69/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0283 - mse: 0.0283 - mae: 0.1005 - val_loss: 0.8664 - val_mse: 0.8664 - val_mae: 0.7477
# Epoch 70/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0284 - mse: 0.0284 - mae: 0.1043 - val_loss: 0.8671 - val_mse: 0.8671 - val_mae: 0.7463
# Epoch 71/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0261 - mse: 0.0261 - mae: 0.0942 - val_loss: 0.8893 - val_mse: 0.8893 - val_mae: 0.7605
# Epoch 72/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0273 - mse: 0.0273 - mae: 0.1015 - val_loss: 0.8292 - val_mse: 0.8292 - val_mae: 0.7271
# Epoch 73/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0287 - mse: 0.0287 - mae: 0.1032 - val_loss: 0.8634 - val_mse: 0.8634 - val_mae: 0.7489
# Epoch 74/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0274 - mse: 0.0274 - mae: 0.0986 - val_loss: 0.8646 - val_mse: 0.8646 - val_mae: 0.7482
# Epoch 75/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0270 - mse: 0.0270 - mae: 0.1006 - val_loss: 0.8879 - val_mse: 0.8879 - val_mae: 0.7588
# Epoch 76/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0255 - mse: 0.0255 - mae: 0.0959 - val_loss: 0.8631 - val_mse: 0.8631 - val_mae: 0.7447
# Epoch 77/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0249 - mse: 0.0249 - mae: 0.0890 - val_loss: 0.8640 - val_mse: 0.8640 - val_mae: 0.7447
# Epoch 78/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0231 - mse: 0.0231 - mae: 0.0862 - val_loss: 0.8678 - val_mse: 0.8678 - val_mae: 0.7489
# Epoch 79/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0227 - mse: 0.0227 - mae: 0.0845 - val_loss: 0.8698 - val_mse: 0.8698 - val_mae: 0.7516
# Epoch 80/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0280 - mse: 0.0280 - mae: 0.0998 - val_loss: 0.8666 - val_mse: 0.8666 - val_mae: 0.7531
# Epoch 81/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0254 - mse: 0.0254 - mae: 0.0976 - val_loss: 0.8701 - val_mse: 0.8701 - val_mae: 0.7469
# Epoch 82/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0263 - mse: 0.0263 - mae: 0.1022 - val_loss: 0.8524 - val_mse: 0.8524 - val_mae: 0.7374
# Epoch 83/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0266 - mse: 0.0266 - mae: 0.1016 - val_loss: 0.8765 - val_mse: 0.8765 - val_mae: 0.7546
# Epoch 84/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0238 - mse: 0.0238 - mae: 0.0843 - val_loss: 0.9021 - val_mse: 0.9021 - val_mae: 0.7669
# Epoch 85/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0267 - mse: 0.0267 - mae: 0.1051 - val_loss: 0.8659 - val_mse: 0.8659 - val_mae: 0.7499
# Epoch 86/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0297 - mse: 0.0297 - mae: 0.1095 - val_loss: 0.8422 - val_mse: 0.8422 - val_mae: 0.7338
# Epoch 87/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0277 - mse: 0.0277 - mae: 0.1015 - val_loss: 0.8369 - val_mse: 0.8369 - val_mae: 0.7329
# Epoch 88/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0266 - mse: 0.0266 - mae: 0.1039 - val_loss: 0.8606 - val_mse: 0.8606 - val_mae: 0.7486
# Epoch 89/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0232 - mse: 0.0232 - mae: 0.0894 - val_loss: 0.8699 - val_mse: 0.8699 - val_mae: 0.7518
# Epoch 90/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0222 - mse: 0.0222 - mae: 0.0819 - val_loss: 0.8396 - val_mse: 0.8396 - val_mae: 0.7338
# Epoch 91/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0224 - mse: 0.0224 - mae: 0.0844 - val_loss: 0.8432 - val_mse: 0.8432 - val_mae: 0.7329
# Epoch 92/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0230 - mse: 0.0230 - mae: 0.0917 - val_loss: 0.8643 - val_mse: 0.8643 - val_mae: 0.7508
# Epoch 93/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0217 - mse: 0.0217 - mae: 0.0867 - val_loss: 0.8387 - val_mse: 0.8387 - val_mae: 0.7396
# Epoch 94/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0209 - mse: 0.0209 - mae: 0.0832 - val_loss: 0.8697 - val_mse: 0.8697 - val_mae: 0.7525
# Epoch 95/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0207 - mse: 0.0207 - mae: 0.0806 - val_loss: 0.8989 - val_mse: 0.8989 - val_mae: 0.7629
# Epoch 96/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0214 - mse: 0.0214 - mae: 0.0808 - val_loss: 0.8792 - val_mse: 0.8792 - val_mae: 0.7540
# Epoch 97/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0235 - mse: 0.0235 - mae: 0.0925 - val_loss: 0.8560 - val_mse: 0.8560 - val_mae: 0.7455
# Epoch 98/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0258 - mse: 0.0258 - mae: 0.1034 - val_loss: 0.8481 - val_mse: 0.8481 - val_mae: 0.7345
# Epoch 99/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0229 - mse: 0.0229 - mae: 0.0890 - val_loss: 0.8531 - val_mse: 0.8531 - val_mae: 0.7416
# Epoch 100/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0204 - mse: 0.0204 - mae: 0.0803 - val_loss: 0.8615 - val_mse: 0.8615 - val_mae: 0.7440

# %%
#Evaluating the model's performance
test_loss, test_mse, test_mae = model1.evaluate(X_test, y_test)

print(f'Test Loss: {test_loss}')
print(f'Test MSE: {test_mse}')
print(f'Test MAE: {test_mae}')
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8884 - mse: 0.8884 - mae: 0.7607
# Test Loss: 0.8883614540100098
# Test MSE: 0.8883614540100098
# Test MAE: 0.7606740593910217

# %%
#extracting relevant informationfrom the training history
train_loss =history1.history['loss']
val_loss = history1.history['val_loss']

#Plotting Traing and validation cures
plt.figure(figsize=(10,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and validation curves')
plt.show()

# %%
#making predictions
y_pred1 = model1.predict(X_test)

#Changing the shape of the results and getting the loss
y_pred1_= y_pred1.flatten()
residual1 = y_test - y_pred1_
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
#Plotting the Residual Plot
plt.figure(figsize=(8,6))
plt.scatter(y_pred1_, residual1,alpha=0.5)
plt.title('Residual Plot 1')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.grid(True)
plt.show()

# %%
#plotting a learning curve
hist_dict = history1.history
loss_values = hist_dict['loss']
val_loss_values = hist_dict["val_loss"]

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs,loss_values,'ro-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##**Model2**

# %%
#A more complex model architecture (ANN)
model2 = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],), kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(128, activation='relu', kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu', kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu', kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(8, activation='relu', kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='linear')
])

model2.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])
model2.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_34 (Dense)            (None, 256)               10752
#
#  batch_normalization_18 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_35 (Dense)            (None, 128)               32896
#
#  batch_normalization_19 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_36 (Dense)            (None, 64)                8256
#
#  batch_normalization_20 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_37 (Dense)            (None, 32)                2080
#
#  batch_normalization_21 (Ba  (None, 32)                128
#  tchNormalization)
#
#  dropout_21 (Dropout)        (None, 32)                0
#
#  dense_38 (Dense)            (None, 16)                528
#
#  batch_normalization_22 (Ba  (None, 16)                64
#  tchNormalization)
#
#  dropout_22 (Dropout)        (None, 16)                0
#
#  dense_39 (Dense)            (None, 8)                 136
#
#  batch_normalization_23 (Ba  (None, 8)                 32
#  tchNormalization)
#
#  dropout_23 (Dropout)        (None, 8)                 0
#
#  dense_40 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 56673 (221.38 KB)
# Trainable params: 55665 (217.44 KB)
# Non-trainable params: 1008 (3.94 KB)
# _________________________________________________________________

# %%
history2=model2.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/200
# 23/23 [==============================] - 5s 21ms/step - loss: 6.7566 - mae: 1.8751 - mse: 6.7566 - val_loss: 2.6627 - val_mae: 1.4910 - val_mse: 2.6627
# Epoch 2/200
# 23/23 [==============================] - 0s 8ms/step - loss: 5.5835 - mae: 1.7821 - mse: 5.5835 - val_loss: 1.7561 - val_mae: 1.1561 - val_mse: 1.7561
# Epoch 3/200
# 23/23 [==============================] - 0s 7ms/step - loss: 4.6849 - mae: 1.6512 - mse: 4.6849 - val_loss: 1.4299 - val_mae: 1.0229 - val_mse: 1.4299
# Epoch 4/200
# 23/23 [==============================] - 0s 7ms/step - loss: 4.5570 - mae: 1.5884 - mse: 4.5570 - val_loss: 1.2637 - val_mae: 0.9434 - val_mse: 1.2637
# Epoch 5/200
# 23/23 [==============================] - 0s 7ms/step - loss: 3.7558 - mae: 1.4922 - mse: 3.7558 - val_loss: 1.1622 - val_mae: 0.8927 - val_mse: 1.1622
# Epoch 6/200
# 23/23 [==============================] - 0s 8ms/step - loss: 3.6685 - mae: 1.4573 - mse: 3.6685 - val_loss: 1.0617 - val_mae: 0.8482 - val_mse: 1.0617
# Epoch 7/200
# 23/23 [==============================] - 0s 8ms/step - loss: 3.2176 - mae: 1.3877 - mse: 3.2176 - val_loss: 1.0025 - val_mae: 0.8210 - val_mse: 1.0025
# Epoch 8/200
# 23/23 [==============================] - 0s 8ms/step - loss: 2.8320 - mae: 1.3138 - mse: 2.8320 - val_loss: 0.9277 - val_mae: 0.7881 - val_mse: 0.9277
# Epoch 9/200
# 23/23 [==============================] - 0s 8ms/step - loss: 2.6478 - mae: 1.2641 - mse: 2.6478 - val_loss: 0.8735 - val_mae: 0.7621 - val_mse: 0.8735
# Epoch 10/200
# 23/23 [==============================] - 0s 8ms/step - loss: 2.2404 - mae: 1.1867 - mse: 2.2404 - val_loss: 0.7935 - val_mae: 0.7234 - val_mse: 0.7935
# Epoch 11/200
# 23/23 [==============================] - 0s 8ms/step - loss: 2.2337 - mae: 1.1763 - mse: 2.2337 - val_loss: 0.7502 - val_mae: 0.7012 - val_mse: 0.7502
# Epoch 12/200
# 23/23 [==============================] - 0s 9ms/step - loss: 2.0586 - mae: 1.1304 - mse: 2.0586 - val_loss: 0.7219 - val_mae: 0.6859 - val_mse: 0.7219
# Epoch 13/200
# 23/23 [==============================] - 0s 8ms/step - loss: 1.7663 - mae: 1.0452 - mse: 1.7663 - val_loss: 0.6973 - val_mae: 0.6737 - val_mse: 0.6973
# Epoch 14/200
# 23/23 [==============================] - 0s 7ms/step - loss: 1.6597 - mae: 1.0142 - mse: 1.6597 - val_loss: 0.6570 - val_mae: 0.6534 - val_mse: 0.6570
# Epoch 15/200
# 23/23 [==============================] - 0s 7ms/step - loss: 1.6471 - mae: 1.0316 - mse: 1.6471 - val_loss: 0.6304 - val_mae: 0.6402 - val_mse: 0.6304
# Epoch 16/200
# 23/23 [==============================] - 0s 8ms/step - loss: 1.4866 - mae: 0.9821 - mse: 1.4866 - val_loss: 0.5983 - val_mae: 0.6239 - val_mse: 0.5983
# Epoch 17/200
# 23/23 [==============================] - 0s 8ms/step - loss: 1.3572 - mae: 0.9326 - mse: 1.3572 - val_loss: 0.5692 - val_mae: 0.6103 - val_mse: 0.5692
# Epoch 18/200
# 23/23 [==============================] - 0s 8ms/step - loss: 1.2608 - mae: 0.8938 - mse: 1.2608 - val_loss: 0.5446 - val_mae: 0.5978 - val_mse: 0.5446
# Epoch 19/200
# 23/23 [==============================] - 0s 7ms/step - loss: 1.2860 - mae: 0.8989 - mse: 1.2860 - val_loss: 0.5272 - val_mae: 0.5904 - val_mse: 0.5272
# Epoch 20/200
# 23/23 [==============================] - 0s 8ms/step - loss: 1.1226 - mae: 0.8361 - mse: 1.1226 - val_loss: 0.5083 - val_mae: 0.5816 - val_mse: 0.5083
# Epoch 21/200
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0504 - mae: 0.8107 - mse: 1.0504 - val_loss: 0.4886 - val_mae: 0.5721 - val_mse: 0.4886
# Epoch 22/200
# 23/23 [==============================] - 0s 8ms/step - loss: 1.1420 - mae: 0.8526 - mse: 1.1420 - val_loss: 0.4833 - val_mae: 0.5695 - val_mse: 0.4833
# Epoch 23/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.9782 - mae: 0.7996 - mse: 0.9782 - val_loss: 0.4741 - val_mae: 0.5667 - val_mse: 0.4741
# Epoch 24/200
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0935 - mae: 0.8219 - mse: 1.0935 - val_loss: 0.4708 - val_mae: 0.5666 - val_mse: 0.4708
# Epoch 25/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8860 - mae: 0.7439 - mse: 0.8860 - val_loss: 0.4671 - val_mae: 0.5644 - val_mse: 0.4671
# Epoch 26/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9991 - mae: 0.7948 - mse: 0.9991 - val_loss: 0.4627 - val_mae: 0.5624 - val_mse: 0.4627
# Epoch 27/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.9898 - mae: 0.7944 - mse: 0.9898 - val_loss: 0.4611 - val_mae: 0.5631 - val_mse: 0.4611
# Epoch 28/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.8647 - mae: 0.7325 - mse: 0.8647 - val_loss: 0.4589 - val_mae: 0.5612 - val_mse: 0.4589
# Epoch 29/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9244 - mae: 0.7576 - mse: 0.9244 - val_loss: 0.4580 - val_mae: 0.5617 - val_mse: 0.4580
# Epoch 30/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9183 - mae: 0.7487 - mse: 0.9183 - val_loss: 0.4573 - val_mae: 0.5621 - val_mse: 0.4573
# Epoch 31/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.8652 - mae: 0.7469 - mse: 0.8652 - val_loss: 0.4569 - val_mae: 0.5611 - val_mse: 0.4569
# Epoch 32/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.8394 - mae: 0.7220 - mse: 0.8394 - val_loss: 0.4578 - val_mae: 0.5613 - val_mse: 0.4578
# Epoch 33/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8842 - mae: 0.7561 - mse: 0.8842 - val_loss: 0.4583 - val_mae: 0.5615 - val_mse: 0.4583
# Epoch 34/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.8156 - mae: 0.7111 - mse: 0.8156 - val_loss: 0.4574 - val_mae: 0.5628 - val_mse: 0.4574
# Epoch 35/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.7852 - mae: 0.7156 - mse: 0.7852 - val_loss: 0.4586 - val_mae: 0.5636 - val_mse: 0.4586
# Epoch 36/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8232 - mae: 0.7341 - mse: 0.8232 - val_loss: 0.4585 - val_mae: 0.5622 - val_mse: 0.4585
# Epoch 37/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.8092 - mae: 0.7154 - mse: 0.8092 - val_loss: 0.4602 - val_mae: 0.5633 - val_mse: 0.4602
# Epoch 38/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7707 - mae: 0.6992 - mse: 0.7707 - val_loss: 0.4619 - val_mae: 0.5636 - val_mse: 0.4619
# Epoch 39/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8061 - mae: 0.7069 - mse: 0.8061 - val_loss: 0.4646 - val_mae: 0.5645 - val_mse: 0.4646
# Epoch 40/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7748 - mae: 0.7067 - mse: 0.7748 - val_loss: 0.4690 - val_mae: 0.5671 - val_mse: 0.4690
# Epoch 41/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7721 - mae: 0.6954 - mse: 0.7721 - val_loss: 0.4667 - val_mae: 0.5660 - val_mse: 0.4667
# Epoch 42/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7555 - mae: 0.6790 - mse: 0.7555 - val_loss: 0.4689 - val_mae: 0.5675 - val_mse: 0.4689
# Epoch 43/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6927 - mae: 0.6699 - mse: 0.6927 - val_loss: 0.4682 - val_mae: 0.5675 - val_mse: 0.4682
# Epoch 44/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.7733 - mae: 0.7118 - mse: 0.7733 - val_loss: 0.4615 - val_mae: 0.5642 - val_mse: 0.4615
# Epoch 45/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.7460 - mae: 0.6986 - mse: 0.7460 - val_loss: 0.4559 - val_mae: 0.5614 - val_mse: 0.4559
# Epoch 46/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.7243 - mae: 0.6804 - mse: 0.7243 - val_loss: 0.4529 - val_mae: 0.5601 - val_mse: 0.4529
# Epoch 47/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7065 - mae: 0.6839 - mse: 0.7065 - val_loss: 0.4527 - val_mae: 0.5588 - val_mse: 0.4527
# Epoch 48/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7313 - mae: 0.6903 - mse: 0.7313 - val_loss: 0.4496 - val_mae: 0.5570 - val_mse: 0.4496
# Epoch 49/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6923 - mae: 0.6696 - mse: 0.6923 - val_loss: 0.4483 - val_mae: 0.5566 - val_mse: 0.4483
# Epoch 50/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7164 - mae: 0.6837 - mse: 0.7164 - val_loss: 0.4502 - val_mae: 0.5575 - val_mse: 0.4502
# Epoch 51/200
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6975 - mae: 0.6679 - mse: 0.6975 - val_loss: 0.4506 - val_mae: 0.5573 - val_mse: 0.4506
# Epoch 52/200
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6930 - mae: 0.6746 - mse: 0.6930 - val_loss: 0.4507 - val_mae: 0.5572 - val_mse: 0.4507
# Epoch 53/200
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7165 - mae: 0.6853 - mse: 0.7165 - val_loss: 0.4505 - val_mae: 0.5570 - val_mse: 0.4505
# Epoch 54/200
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6963 - mae: 0.6662 - mse: 0.6963 - val_loss: 0.4531 - val_mae: 0.5590 - val_mse: 0.4531
# Epoch 55/200
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6873 - mae: 0.6622 - mse: 0.6873 - val_loss: 0.4572 - val_mae: 0.5606 - val_mse: 0.4572
# Epoch 56/200
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6693 - mae: 0.6643 - mse: 0.6693 - val_loss: 0.4570 - val_mae: 0.5604 - val_mse: 0.4570
# Epoch 57/200
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6392 - mae: 0.6505 - mse: 0.6392 - val_loss: 0.4568 - val_mae: 0.5603 - val_mse: 0.4568
# Epoch 58/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7259 - mae: 0.6845 - mse: 0.7259 - val_loss: 0.4559 - val_mae: 0.5599 - val_mse: 0.4559
# Epoch 59/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6794 - mae: 0.6633 - mse: 0.6794 - val_loss: 0.4531 - val_mae: 0.5585 - val_mse: 0.4531
# Epoch 60/200
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7088 - mae: 0.6817 - mse: 0.7088 - val_loss: 0.4539 - val_mae: 0.5583 - val_mse: 0.4539
# Epoch 61/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6441 - mae: 0.6459 - mse: 0.6441 - val_loss: 0.4525 - val_mae: 0.5574 - val_mse: 0.4525
# Epoch 62/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6647 - mae: 0.6599 - mse: 0.6647 - val_loss: 0.4521 - val_mae: 0.5571 - val_mse: 0.4521
# Epoch 63/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6352 - mae: 0.6400 - mse: 0.6352 - val_loss: 0.4548 - val_mae: 0.5586 - val_mse: 0.4548
# Epoch 64/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6719 - mae: 0.6495 - mse: 0.6719 - val_loss: 0.4572 - val_mae: 0.5600 - val_mse: 0.4572
# Epoch 65/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6614 - mae: 0.6566 - mse: 0.6614 - val_loss: 0.4563 - val_mae: 0.5602 - val_mse: 0.4563
# Epoch 66/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6452 - mae: 0.6538 - mse: 0.6452 - val_loss: 0.4550 - val_mae: 0.5588 - val_mse: 0.4550
# Epoch 67/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6418 - mae: 0.6471 - mse: 0.6418 - val_loss: 0.4536 - val_mae: 0.5575 - val_mse: 0.4536
# Epoch 68/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6528 - mae: 0.6580 - mse: 0.6528 - val_loss: 0.4540 - val_mae: 0.5577 - val_mse: 0.4540
# Epoch 69/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6286 - mae: 0.6482 - mse: 0.6286 - val_loss: 0.4517 - val_mae: 0.5564 - val_mse: 0.4517
# Epoch 70/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6582 - mae: 0.6493 - mse: 0.6582 - val_loss: 0.4495 - val_mae: 0.5553 - val_mse: 0.4495
# Epoch 71/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6464 - mae: 0.6463 - mse: 0.6464 - val_loss: 0.4480 - val_mae: 0.5543 - val_mse: 0.4480
# Epoch 72/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6130 - mae: 0.6360 - mse: 0.6130 - val_loss: 0.4477 - val_mae: 0.5540 - val_mse: 0.4477
# Epoch 73/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6209 - mae: 0.6420 - mse: 0.6209 - val_loss: 0.4462 - val_mae: 0.5535 - val_mse: 0.4462
# Epoch 74/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6521 - mae: 0.6490 - mse: 0.6521 - val_loss: 0.4467 - val_mae: 0.5540 - val_mse: 0.4467
# Epoch 75/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6511 - mae: 0.6496 - mse: 0.6511 - val_loss: 0.4468 - val_mae: 0.5534 - val_mse: 0.4468
# Epoch 76/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6392 - mae: 0.6470 - mse: 0.6392 - val_loss: 0.4486 - val_mae: 0.5541 - val_mse: 0.4486
# Epoch 77/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6022 - mae: 0.6235 - mse: 0.6022 - val_loss: 0.4511 - val_mae: 0.5554 - val_mse: 0.4511
# Epoch 78/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6077 - mae: 0.6351 - mse: 0.6077 - val_loss: 0.4513 - val_mae: 0.5557 - val_mse: 0.4513
# Epoch 79/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6278 - mae: 0.6416 - mse: 0.6278 - val_loss: 0.4494 - val_mae: 0.5548 - val_mse: 0.4494
# Epoch 80/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6216 - mae: 0.6396 - mse: 0.6216 - val_loss: 0.4505 - val_mae: 0.5553 - val_mse: 0.4505
# Epoch 81/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6327 - mae: 0.6496 - mse: 0.6327 - val_loss: 0.4494 - val_mae: 0.5553 - val_mse: 0.4494
# Epoch 82/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6076 - mae: 0.6312 - mse: 0.6076 - val_loss: 0.4513 - val_mae: 0.5564 - val_mse: 0.4513
# Epoch 83/200
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5837 - mae: 0.6243 - mse: 0.5837 - val_loss: 0.4509 - val_mae: 0.5561 - val_mse: 0.4509
# Epoch 84/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6431 - mae: 0.6534 - mse: 0.6431 - val_loss: 0.4532 - val_mae: 0.5576 - val_mse: 0.4532
# Epoch 85/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6017 - mae: 0.6262 - mse: 0.6017 - val_loss: 0.4520 - val_mae: 0.5573 - val_mse: 0.4520
# Epoch 86/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5798 - mae: 0.6177 - mse: 0.5798 - val_loss: 0.4514 - val_mae: 0.5575 - val_mse: 0.4514
# Epoch 87/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5972 - mae: 0.6215 - mse: 0.5972 - val_loss: 0.4515 - val_mae: 0.5580 - val_mse: 0.4515
# Epoch 88/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6119 - mae: 0.6356 - mse: 0.6119 - val_loss: 0.4530 - val_mae: 0.5590 - val_mse: 0.4530
# Epoch 89/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5873 - mae: 0.6224 - mse: 0.5873 - val_loss: 0.4506 - val_mae: 0.5578 - val_mse: 0.4506
# Epoch 90/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6055 - mae: 0.6263 - mse: 0.6055 - val_loss: 0.4552 - val_mae: 0.5605 - val_mse: 0.4552
# Epoch 91/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5774 - mae: 0.6199 - mse: 0.5774 - val_loss: 0.4555 - val_mae: 0.5605 - val_mse: 0.4555
# Epoch 92/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6301 - mae: 0.6400 - mse: 0.6301 - val_loss: 0.4533 - val_mae: 0.5595 - val_mse: 0.4533
# Epoch 93/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5907 - mae: 0.6241 - mse: 0.5907 - val_loss: 0.4513 - val_mae: 0.5582 - val_mse: 0.4513
# Epoch 94/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5742 - mae: 0.6090 - mse: 0.5742 - val_loss: 0.4515 - val_mae: 0.5583 - val_mse: 0.4515
# Epoch 95/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5597 - mae: 0.6083 - mse: 0.5597 - val_loss: 0.4489 - val_mae: 0.5566 - val_mse: 0.4489
# Epoch 96/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5710 - mae: 0.6112 - mse: 0.5710 - val_loss: 0.4486 - val_mae: 0.5567 - val_mse: 0.4486
# Epoch 97/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6065 - mae: 0.6379 - mse: 0.6065 - val_loss: 0.4513 - val_mae: 0.5583 - val_mse: 0.4513
# Epoch 98/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5644 - mae: 0.6164 - mse: 0.5644 - val_loss: 0.4500 - val_mae: 0.5578 - val_mse: 0.4500
# Epoch 99/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5817 - mae: 0.6058 - mse: 0.5817 - val_loss: 0.4498 - val_mae: 0.5575 - val_mse: 0.4498
# Epoch 100/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6065 - mae: 0.6315 - mse: 0.6065 - val_loss: 0.4488 - val_mae: 0.5568 - val_mse: 0.4488
# Epoch 101/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5587 - mae: 0.6007 - mse: 0.5587 - val_loss: 0.4474 - val_mae: 0.5557 - val_mse: 0.4474
# Epoch 102/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6029 - mae: 0.6265 - mse: 0.6029 - val_loss: 0.4488 - val_mae: 0.5564 - val_mse: 0.4488
# Epoch 103/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5652 - mae: 0.6130 - mse: 0.5652 - val_loss: 0.4496 - val_mae: 0.5570 - val_mse: 0.4496
# Epoch 104/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5698 - mae: 0.6155 - mse: 0.5698 - val_loss: 0.4498 - val_mae: 0.5570 - val_mse: 0.4498
# Epoch 105/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5785 - mae: 0.6211 - mse: 0.5785 - val_loss: 0.4511 - val_mae: 0.5578 - val_mse: 0.4511
# Epoch 106/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5856 - mae: 0.6177 - mse: 0.5856 - val_loss: 0.4519 - val_mae: 0.5586 - val_mse: 0.4519
# Epoch 107/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5794 - mae: 0.6200 - mse: 0.5794 - val_loss: 0.4533 - val_mae: 0.5593 - val_mse: 0.4533
# Epoch 108/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5992 - mae: 0.6298 - mse: 0.5992 - val_loss: 0.4519 - val_mae: 0.5586 - val_mse: 0.4519
# Epoch 109/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5863 - mae: 0.6208 - mse: 0.5863 - val_loss: 0.4550 - val_mae: 0.5601 - val_mse: 0.4550
# Epoch 110/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5886 - mae: 0.6230 - mse: 0.5886 - val_loss: 0.4533 - val_mae: 0.5595 - val_mse: 0.4533
# Epoch 111/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5687 - mae: 0.6095 - mse: 0.5687 - val_loss: 0.4505 - val_mae: 0.5578 - val_mse: 0.4505
# Epoch 112/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5981 - mae: 0.6286 - mse: 0.5981 - val_loss: 0.4527 - val_mae: 0.5587 - val_mse: 0.4527
# Epoch 113/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5731 - mae: 0.6110 - mse: 0.5731 - val_loss: 0.4527 - val_mae: 0.5586 - val_mse: 0.4527
# Epoch 114/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5808 - mae: 0.6255 - mse: 0.5808 - val_loss: 0.4527 - val_mae: 0.5587 - val_mse: 0.4527
# Epoch 115/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5587 - mae: 0.6102 - mse: 0.5587 - val_loss: 0.4539 - val_mae: 0.5594 - val_mse: 0.4539
# Epoch 116/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5676 - mae: 0.6076 - mse: 0.5676 - val_loss: 0.4532 - val_mae: 0.5589 - val_mse: 0.4532
# Epoch 117/200
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5568 - mae: 0.6030 - mse: 0.5568 - val_loss: 0.4513 - val_mae: 0.5578 - val_mse: 0.4513
# Epoch 118/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5554 - mae: 0.6032 - mse: 0.5554 - val_loss: 0.4531 - val_mae: 0.5586 - val_mse: 0.4531
# Epoch 119/200
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5650 - mae: 0.6159 - mse: 0.5650 - val_loss: 0.4541 - val_mae: 0.5592 - val_mse: 0.4541
# Epoch 120/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5806 - mae: 0.6220 - mse: 0.5806 - val_loss: 0.4523 - val_mae: 0.5586 - val_mse: 0.4523
# Epoch 121/200
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5677 - mae: 0.6080 - mse: 0.5677 - val_loss: 0.4517 - val_mae: 0.5585 - val_mse: 0.4517
# Epoch 122/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5724 - mae: 0.6145 - mse: 0.5724 - val_loss: 0.4516 - val_mae: 0.5584 - val_mse: 0.4516
# Epoch 123/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5679 - mae: 0.6136 - mse: 0.5679 - val_loss: 0.4508 - val_mae: 0.5580 - val_mse: 0.4508
# Epoch 124/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5746 - mae: 0.6182 - mse: 0.5746 - val_loss: 0.4483 - val_mae: 0.5567 - val_mse: 0.4483
# Epoch 125/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5524 - mae: 0.6030 - mse: 0.5524 - val_loss: 0.4503 - val_mae: 0.5580 - val_mse: 0.4503
# Epoch 126/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5563 - mae: 0.6055 - mse: 0.5563 - val_loss: 0.4478 - val_mae: 0.5565 - val_mse: 0.4478
# Epoch 127/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5645 - mae: 0.6132 - mse: 0.5645 - val_loss: 0.4475 - val_mae: 0.5563 - val_mse: 0.4475
# Epoch 128/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5557 - mae: 0.6056 - mse: 0.5557 - val_loss: 0.4457 - val_mae: 0.5552 - val_mse: 0.4457
# Epoch 129/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5785 - mae: 0.6067 - mse: 0.5785 - val_loss: 0.4487 - val_mae: 0.5571 - val_mse: 0.4487
# Epoch 130/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5864 - mae: 0.6245 - mse: 0.5864 - val_loss: 0.4496 - val_mae: 0.5577 - val_mse: 0.4496
# Epoch 131/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5466 - mae: 0.6002 - mse: 0.5466 - val_loss: 0.4491 - val_mae: 0.5574 - val_mse: 0.4491
# Epoch 132/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5517 - mae: 0.6038 - mse: 0.5517 - val_loss: 0.4472 - val_mae: 0.5563 - val_mse: 0.4472
# Epoch 133/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5540 - mae: 0.6071 - mse: 0.5540 - val_loss: 0.4505 - val_mae: 0.5581 - val_mse: 0.4505
# Epoch 134/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5412 - mae: 0.5946 - mse: 0.5412 - val_loss: 0.4506 - val_mae: 0.5582 - val_mse: 0.4506
# Epoch 135/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5385 - mae: 0.5985 - mse: 0.5385 - val_loss: 0.4502 - val_mae: 0.5579 - val_mse: 0.4502
# Epoch 136/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5463 - mae: 0.5992 - mse: 0.5463 - val_loss: 0.4498 - val_mae: 0.5576 - val_mse: 0.4498
# Epoch 137/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5498 - mae: 0.6028 - mse: 0.5498 - val_loss: 0.4480 - val_mae: 0.5567 - val_mse: 0.4480
# Epoch 138/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5540 - mae: 0.6085 - mse: 0.5540 - val_loss: 0.4502 - val_mae: 0.5580 - val_mse: 0.4502
# Epoch 139/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5686 - mae: 0.6096 - mse: 0.5686 - val_loss: 0.4517 - val_mae: 0.5589 - val_mse: 0.4517
# Epoch 140/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5432 - mae: 0.5944 - mse: 0.5432 - val_loss: 0.4514 - val_mae: 0.5588 - val_mse: 0.4514
# Epoch 141/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5386 - mae: 0.5985 - mse: 0.5386 - val_loss: 0.4488 - val_mae: 0.5574 - val_mse: 0.4488
# Epoch 142/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5453 - mae: 0.6024 - mse: 0.5453 - val_loss: 0.4512 - val_mae: 0.5585 - val_mse: 0.4512
# Epoch 143/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5385 - mae: 0.5970 - mse: 0.5385 - val_loss: 0.4489 - val_mae: 0.5572 - val_mse: 0.4489
# Epoch 144/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5450 - mae: 0.6023 - mse: 0.5450 - val_loss: 0.4480 - val_mae: 0.5568 - val_mse: 0.4480
# Epoch 145/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5408 - mae: 0.5997 - mse: 0.5408 - val_loss: 0.4481 - val_mae: 0.5568 - val_mse: 0.4481
# Epoch 146/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5433 - mae: 0.6017 - mse: 0.5433 - val_loss: 0.4481 - val_mae: 0.5567 - val_mse: 0.4481
# Epoch 147/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5577 - mae: 0.6103 - mse: 0.5577 - val_loss: 0.4486 - val_mae: 0.5570 - val_mse: 0.4486
# Epoch 148/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5585 - mae: 0.6046 - mse: 0.5585 - val_loss: 0.4509 - val_mae: 0.5584 - val_mse: 0.4509
# Epoch 149/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5397 - mae: 0.5997 - mse: 0.5397 - val_loss: 0.4470 - val_mae: 0.5561 - val_mse: 0.4470
# Epoch 150/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5434 - mae: 0.5983 - mse: 0.5434 - val_loss: 0.4478 - val_mae: 0.5565 - val_mse: 0.4478
# Epoch 151/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5473 - mae: 0.6067 - mse: 0.5473 - val_loss: 0.4484 - val_mae: 0.5570 - val_mse: 0.4484
# Epoch 152/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5509 - mae: 0.6027 - mse: 0.5509 - val_loss: 0.4504 - val_mae: 0.5579 - val_mse: 0.4504
# Epoch 153/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5460 - mae: 0.5976 - mse: 0.5460 - val_loss: 0.4520 - val_mae: 0.5587 - val_mse: 0.4520
# Epoch 154/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5370 - mae: 0.6044 - mse: 0.5370 - val_loss: 0.4513 - val_mae: 0.5582 - val_mse: 0.4513
# Epoch 155/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5474 - mae: 0.6077 - mse: 0.5474 - val_loss: 0.4497 - val_mae: 0.5574 - val_mse: 0.4497
# Epoch 156/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5537 - mae: 0.6037 - mse: 0.5537 - val_loss: 0.4520 - val_mae: 0.5586 - val_mse: 0.4520
# Epoch 157/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5559 - mae: 0.6110 - mse: 0.5559 - val_loss: 0.4503 - val_mae: 0.5579 - val_mse: 0.4503
# Epoch 158/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5494 - mae: 0.6016 - mse: 0.5494 - val_loss: 0.4522 - val_mae: 0.5591 - val_mse: 0.4522
# Epoch 159/200
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5544 - mae: 0.6053 - mse: 0.5544 - val_loss: 0.4556 - val_mae: 0.5607 - val_mse: 0.4556
# Epoch 160/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5439 - mae: 0.6004 - mse: 0.5439 - val_loss: 0.4527 - val_mae: 0.5595 - val_mse: 0.4527
# Epoch 161/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5320 - mae: 0.5956 - mse: 0.5320 - val_loss: 0.4507 - val_mae: 0.5587 - val_mse: 0.4507
# Epoch 162/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5549 - mae: 0.6065 - mse: 0.5549 - val_loss: 0.4481 - val_mae: 0.5572 - val_mse: 0.4481
# Epoch 163/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5422 - mae: 0.5990 - mse: 0.5422 - val_loss: 0.4492 - val_mae: 0.5579 - val_mse: 0.4492
# Epoch 164/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5374 - mae: 0.5994 - mse: 0.5374 - val_loss: 0.4506 - val_mae: 0.5587 - val_mse: 0.4506
# Epoch 165/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5439 - mae: 0.6006 - mse: 0.5439 - val_loss: 0.4516 - val_mae: 0.5592 - val_mse: 0.4516
# Epoch 166/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5367 - mae: 0.5958 - mse: 0.5367 - val_loss: 0.4522 - val_mae: 0.5595 - val_mse: 0.4522
# Epoch 167/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5421 - mae: 0.5955 - mse: 0.5421 - val_loss: 0.4526 - val_mae: 0.5597 - val_mse: 0.4526
# Epoch 168/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5455 - mae: 0.6023 - mse: 0.5455 - val_loss: 0.4505 - val_mae: 0.5587 - val_mse: 0.4505
# Epoch 169/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5274 - mae: 0.5918 - mse: 0.5274 - val_loss: 0.4518 - val_mae: 0.5594 - val_mse: 0.4518
# Epoch 170/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5400 - mae: 0.5986 - mse: 0.5400 - val_loss: 0.4518 - val_mae: 0.5594 - val_mse: 0.4518
# Epoch 171/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5377 - mae: 0.5948 - mse: 0.5377 - val_loss: 0.4524 - val_mae: 0.5596 - val_mse: 0.4524
# Epoch 172/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5353 - mae: 0.5906 - mse: 0.5353 - val_loss: 0.4531 - val_mae: 0.5599 - val_mse: 0.4531
# Epoch 173/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5450 - mae: 0.5989 - mse: 0.5450 - val_loss: 0.4553 - val_mae: 0.5610 - val_mse: 0.4553
# Epoch 174/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5449 - mae: 0.6004 - mse: 0.5449 - val_loss: 0.4520 - val_mae: 0.5593 - val_mse: 0.4520
# Epoch 175/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5482 - mae: 0.6006 - mse: 0.5482 - val_loss: 0.4565 - val_mae: 0.5613 - val_mse: 0.4565
# Epoch 176/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5418 - mae: 0.5952 - mse: 0.5418 - val_loss: 0.4567 - val_mae: 0.5614 - val_mse: 0.4567
# Epoch 177/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5469 - mae: 0.6011 - mse: 0.5469 - val_loss: 0.4510 - val_mae: 0.5589 - val_mse: 0.4510
# Epoch 178/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5399 - mae: 0.6000 - mse: 0.5399 - val_loss: 0.4524 - val_mae: 0.5595 - val_mse: 0.4524
# Epoch 179/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5221 - mae: 0.5898 - mse: 0.5221 - val_loss: 0.4510 - val_mae: 0.5588 - val_mse: 0.4510
# Epoch 180/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5307 - mae: 0.5929 - mse: 0.5307 - val_loss: 0.4504 - val_mae: 0.5585 - val_mse: 0.4504
# Epoch 181/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5489 - mae: 0.5998 - mse: 0.5489 - val_loss: 0.4493 - val_mae: 0.5580 - val_mse: 0.4493
# Epoch 182/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5354 - mae: 0.5970 - mse: 0.5354 - val_loss: 0.4495 - val_mae: 0.5581 - val_mse: 0.4495
# Epoch 183/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5265 - mae: 0.5864 - mse: 0.5265 - val_loss: 0.4518 - val_mae: 0.5593 - val_mse: 0.4518
# Epoch 184/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5320 - mae: 0.5950 - mse: 0.5320 - val_loss: 0.4505 - val_mae: 0.5586 - val_mse: 0.4505
# Epoch 185/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5344 - mae: 0.5991 - mse: 0.5344 - val_loss: 0.4515 - val_mae: 0.5592 - val_mse: 0.4515
# Epoch 186/200
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5382 - mae: 0.5941 - mse: 0.5382 - val_loss: 0.4498 - val_mae: 0.5583 - val_mse: 0.4498
# Epoch 187/200
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5257 - mae: 0.5924 - mse: 0.5257 - val_loss: 0.4522 - val_mae: 0.5596 - val_mse: 0.4522
# Epoch 188/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5378 - mae: 0.5936 - mse: 0.5378 - val_loss: 0.4491 - val_mae: 0.5581 - val_mse: 0.4491
# Epoch 189/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5273 - mae: 0.5935 - mse: 0.5273 - val_loss: 0.4510 - val_mae: 0.5591 - val_mse: 0.4510
# Epoch 190/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5264 - mae: 0.5845 - mse: 0.5264 - val_loss: 0.4485 - val_mae: 0.5577 - val_mse: 0.4485
# Epoch 191/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5372 - mae: 0.5958 - mse: 0.5372 - val_loss: 0.4497 - val_mae: 0.5584 - val_mse: 0.4497
# Epoch 192/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5283 - mae: 0.5891 - mse: 0.5283 - val_loss: 0.4501 - val_mae: 0.5586 - val_mse: 0.4501
# Epoch 193/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5369 - mae: 0.5973 - mse: 0.5369 - val_loss: 0.4513 - val_mae: 0.5593 - val_mse: 0.4513
# Epoch 194/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5379 - mae: 0.5976 - mse: 0.5379 - val_loss: 0.4509 - val_mae: 0.5590 - val_mse: 0.4509
# Epoch 195/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5214 - mae: 0.5861 - mse: 0.5214 - val_loss: 0.4490 - val_mae: 0.5581 - val_mse: 0.4490
# Epoch 196/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5377 - mae: 0.5917 - mse: 0.5377 - val_loss: 0.4498 - val_mae: 0.5586 - val_mse: 0.4498
# Epoch 197/200
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5209 - mae: 0.5872 - mse: 0.5209 - val_loss: 0.4528 - val_mae: 0.5603 - val_mse: 0.4528
# Epoch 198/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5304 - mae: 0.5924 - mse: 0.5304 - val_loss: 0.4517 - val_mae: 0.5597 - val_mse: 0.4517
# Epoch 199/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5386 - mae: 0.6000 - mse: 0.5386 - val_loss: 0.4507 - val_mae: 0.5593 - val_mse: 0.4507
# Epoch 200/200
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5223 - mae: 0.5895 - mse: 0.5223 - val_loss: 0.4500 - val_mae: 0.5588 - val_mse: 0.4500

# %%
#Evaluating
test_loss, test_mae, test_mse = model2.evaluate(X_test, y_test)

print(f'Test Loss: {test_loss}')
print(f'Test MAE: {test_mae}')
print(f'Test MSE: {test_mse}')
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4893 - mae: 0.5651 - mse: 0.4893
# Test Loss: 0.4893479347229004
# Test MAE: 0.5650946497917175
# Test MSE: 0.4893479347229004

# %%
#extracting relevant informationfrom the training history
train_loss =history2.history['loss']
val_loss = history2.history['val_loss']

#Plotting Traing and validation cures
plt.figure(figsize=(10,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and validation curves')
plt.show()

# %%
#making predictions
y_pred2 = model2.predict(X_test)
y_pred2_= y_pred2.flatten()
residual2 = y_test - y_pred2_
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
#Plotting the Residual Plot
plt.figure(figsize=(8,6))
plt.scatter(y_pred2_, residual2,alpha=0.5)
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.grid(True)
plt.show()

# %%
#plotting a learning curve
hist_dict = history2.history
loss_values = hist_dict['loss']
val_loss_values = hist_dict["val_loss"]

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs,loss_values,'ro-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##**Model3**

# %%
#creating a neural network model for model3
input_layer = tf.keras.layers.Input(shape=(X_train.shape[1],))
hidden_layer1 = tf.keras.layers.Dense(64, activation='relu')(input_layer)
hidden_layer2 = tf.keras.layers.Dense(20, activation='relu')(hidden_layer1)
output_layer = tf.keras.layers.Dense(1, activation='linear',)(hidden_layer2)

model3 = tf.keras.Model(inputs=input_layer, outputs=output_layer)

# %%
#implementing Cross-validation
from sklearn.model_selection import KFold
from tensorflow.keras.optimizers import Adam

folds = 2
cross_val = KFold(n_splits=folds, shuffle=True, random_state=5)

i = 0

for train_index, test_index in cross_val.split(X_train, y_train):
  X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
  y_train_fold, y_test_fold = y_train.iloc[train_index],y_train.iloc[test_index]

 # optim = Adam(learning_rate=0.01)
  model2.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse','mae'])
  #Training with early stopping
  early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=80, restore_best_weights=True)

  history3 = model2.fit(X_train_fold, y_train_fold, epochs=100, batch_size=150, validation_data=(X_test_fold, y_test_fold), callbacks=[early_stopping])

  score = model2.evaluate(X_test, y_test)
  i+=1
  print("Validation Scorefor fold {}: {}".format(i, score))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s 122ms/step - loss: 0.4136 - mse: 0.4136 - mae: 0.5100 - val_loss: 0.2167 - val_mse: 0.2167 - val_mae: 0.3648
# Epoch 2/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.4405 - mse: 0.4405 - mae: 0.5398 - val_loss: 0.2200 - val_mse: 0.2200 - val_mae: 0.3689
# Epoch 3/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.4269 - mse: 0.4269 - mae: 0.5316 - val_loss: 0.2227 - val_mse: 0.2227 - val_mae: 0.3719
# Epoch 4/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4086 - mse: 0.4086 - mae: 0.5193 - val_loss: 0.2271 - val_mse: 0.2271 - val_mae: 0.3766
# Epoch 5/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.4083 - mse: 0.4083 - mae: 0.5140 - val_loss: 0.2311 - val_mse: 0.2311 - val_mae: 0.3805
# Epoch 6/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3965 - mse: 0.3965 - mae: 0.5040 - val_loss: 0.2358 - val_mse: 0.2358 - val_mae: 0.3848
# Epoch 7/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3951 - mse: 0.3951 - mae: 0.5091 - val_loss: 0.2393 - val_mse: 0.2393 - val_mae: 0.3880
# Epoch 8/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3945 - mse: 0.3945 - mae: 0.5095 - val_loss: 0.2433 - val_mse: 0.2433 - val_mae: 0.3917
# Epoch 9/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3804 - mse: 0.3804 - mae: 0.4964 - val_loss: 0.2468 - val_mse: 0.2468 - val_mae: 0.3947
# Epoch 10/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.4182 - mse: 0.4182 - mae: 0.5178 - val_loss: 0.2488 - val_mse: 0.2488 - val_mae: 0.3964
# Epoch 11/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3905 - mse: 0.3905 - mae: 0.5108 - val_loss: 0.2496 - val_mse: 0.2496 - val_mae: 0.3970
# Epoch 12/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3912 - mse: 0.3912 - mae: 0.4948 - val_loss: 0.2527 - val_mse: 0.2527 - val_mae: 0.3997
# Epoch 13/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.4106 - mse: 0.4106 - mae: 0.5097 - val_loss: 0.2566 - val_mse: 0.2566 - val_mae: 0.4033
# Epoch 14/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3734 - mse: 0.3734 - mae: 0.4885 - val_loss: 0.2600 - val_mse: 0.2600 - val_mae: 0.4063
# Epoch 15/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3866 - mse: 0.3866 - mae: 0.5077 - val_loss: 0.2644 - val_mse: 0.2644 - val_mae: 0.4101
# Epoch 16/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3825 - mse: 0.3825 - mae: 0.4964 - val_loss: 0.2673 - val_mse: 0.2673 - val_mae: 0.4126
# Epoch 17/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3802 - mse: 0.3802 - mae: 0.4979 - val_loss: 0.2694 - val_mse: 0.2694 - val_mae: 0.4143
# Epoch 18/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3843 - mse: 0.3843 - mae: 0.4970 - val_loss: 0.2704 - val_mse: 0.2704 - val_mae: 0.4154
# Epoch 19/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3744 - mse: 0.3744 - mae: 0.4992 - val_loss: 0.2704 - val_mse: 0.2704 - val_mae: 0.4156
# Epoch 20/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3836 - mse: 0.3836 - mae: 0.5015 - val_loss: 0.2713 - val_mse: 0.2713 - val_mae: 0.4165
# Epoch 21/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3726 - mse: 0.3726 - mae: 0.4823 - val_loss: 0.2718 - val_mse: 0.2718 - val_mae: 0.4169
# Epoch 22/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3606 - mse: 0.3606 - mae: 0.4851 - val_loss: 0.2725 - val_mse: 0.2725 - val_mae: 0.4175
# Epoch 23/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3709 - mse: 0.3709 - mae: 0.4878 - val_loss: 0.2736 - val_mse: 0.2736 - val_mae: 0.4185
# Epoch 24/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3865 - mse: 0.3865 - mae: 0.5012 - val_loss: 0.2748 - val_mse: 0.2748 - val_mae: 0.4195
# Epoch 25/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3575 - mse: 0.3575 - mae: 0.4855 - val_loss: 0.2740 - val_mse: 0.2740 - val_mae: 0.4187
# Epoch 26/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3608 - mse: 0.3608 - mae: 0.4856 - val_loss: 0.2740 - val_mse: 0.2740 - val_mae: 0.4187
# Epoch 27/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3727 - mse: 0.3727 - mae: 0.4900 - val_loss: 0.2728 - val_mse: 0.2728 - val_mae: 0.4175
# Epoch 28/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3532 - mse: 0.3532 - mae: 0.4788 - val_loss: 0.2727 - val_mse: 0.2727 - val_mae: 0.4173
# Epoch 29/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3557 - mse: 0.3557 - mae: 0.4763 - val_loss: 0.2731 - val_mse: 0.2731 - val_mae: 0.4177
# Epoch 30/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3616 - mse: 0.3616 - mae: 0.4778 - val_loss: 0.2735 - val_mse: 0.2735 - val_mae: 0.4180
# Epoch 31/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3526 - mse: 0.3526 - mae: 0.4782 - val_loss: 0.2739 - val_mse: 0.2739 - val_mae: 0.4182
# Epoch 32/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.3383 - mse: 0.3383 - mae: 0.4663 - val_loss: 0.2744 - val_mse: 0.2744 - val_mae: 0.4183
# Epoch 33/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3593 - mse: 0.3593 - mae: 0.4808 - val_loss: 0.2747 - val_mse: 0.2747 - val_mae: 0.4185
# Epoch 34/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3648 - mse: 0.3648 - mae: 0.4911 - val_loss: 0.2739 - val_mse: 0.2739 - val_mae: 0.4177
# Epoch 35/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3512 - mse: 0.3512 - mae: 0.4754 - val_loss: 0.2736 - val_mse: 0.2736 - val_mae: 0.4172
# Epoch 36/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3613 - mse: 0.3613 - mae: 0.4842 - val_loss: 0.2745 - val_mse: 0.2745 - val_mae: 0.4176
# Epoch 37/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3501 - mse: 0.3501 - mae: 0.4805 - val_loss: 0.2774 - val_mse: 0.2774 - val_mae: 0.4201
# Epoch 38/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3522 - mse: 0.3522 - mae: 0.4692 - val_loss: 0.2793 - val_mse: 0.2793 - val_mae: 0.4218
# Epoch 39/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3508 - mse: 0.3508 - mae: 0.4730 - val_loss: 0.2818 - val_mse: 0.2818 - val_mae: 0.4239
# Epoch 40/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3603 - mse: 0.3603 - mae: 0.4806 - val_loss: 0.2815 - val_mse: 0.2815 - val_mae: 0.4234
# Epoch 41/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3561 - mse: 0.3561 - mae: 0.4743 - val_loss: 0.2822 - val_mse: 0.2822 - val_mae: 0.4240
# Epoch 42/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3419 - mse: 0.3419 - mae: 0.4687 - val_loss: 0.2830 - val_mse: 0.2830 - val_mae: 0.4246
# Epoch 43/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3613 - mse: 0.3613 - mae: 0.4800 - val_loss: 0.2848 - val_mse: 0.2848 - val_mae: 0.4262
# Epoch 44/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3627 - mse: 0.3627 - mae: 0.4798 - val_loss: 0.2855 - val_mse: 0.2855 - val_mae: 0.4269
# Epoch 45/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3648 - mse: 0.3648 - mae: 0.4882 - val_loss: 0.2873 - val_mse: 0.2873 - val_mae: 0.4285
# Epoch 46/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3395 - mse: 0.3395 - mae: 0.4717 - val_loss: 0.2885 - val_mse: 0.2885 - val_mae: 0.4295
# Epoch 47/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3319 - mse: 0.3319 - mae: 0.4521 - val_loss: 0.2888 - val_mse: 0.2888 - val_mae: 0.4298
# Epoch 48/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3277 - mse: 0.3277 - mae: 0.4530 - val_loss: 0.2885 - val_mse: 0.2885 - val_mae: 0.4293
# Epoch 49/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3312 - mse: 0.3312 - mae: 0.4624 - val_loss: 0.2877 - val_mse: 0.2877 - val_mae: 0.4282
# Epoch 50/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3465 - mse: 0.3465 - mae: 0.4810 - val_loss: 0.2880 - val_mse: 0.2880 - val_mae: 0.4283
# Epoch 51/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3365 - mse: 0.3365 - mae: 0.4716 - val_loss: 0.2868 - val_mse: 0.2868 - val_mae: 0.4271
# Epoch 52/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3532 - mse: 0.3532 - mae: 0.4741 - val_loss: 0.2854 - val_mse: 0.2854 - val_mae: 0.4256
# Epoch 53/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3382 - mse: 0.3382 - mae: 0.4700 - val_loss: 0.2860 - val_mse: 0.2860 - val_mae: 0.4259
# Epoch 54/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3423 - mse: 0.3423 - mae: 0.4713 - val_loss: 0.2859 - val_mse: 0.2859 - val_mae: 0.4257
# Epoch 55/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3629 - mse: 0.3629 - mae: 0.4843 - val_loss: 0.2855 - val_mse: 0.2855 - val_mae: 0.4250
# Epoch 56/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3378 - mse: 0.3378 - mae: 0.4661 - val_loss: 0.2850 - val_mse: 0.2850 - val_mae: 0.4244
# Epoch 57/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3364 - mse: 0.3364 - mae: 0.4716 - val_loss: 0.2851 - val_mse: 0.2851 - val_mae: 0.4243
# Epoch 58/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3267 - mse: 0.3267 - mae: 0.4563 - val_loss: 0.2843 - val_mse: 0.2843 - val_mae: 0.4232
# Epoch 59/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3216 - mse: 0.3216 - mae: 0.4553 - val_loss: 0.2850 - val_mse: 0.2850 - val_mae: 0.4236
# Epoch 60/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3361 - mse: 0.3361 - mae: 0.4690 - val_loss: 0.2850 - val_mse: 0.2850 - val_mae: 0.4233
# Epoch 61/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3378 - mse: 0.3378 - mae: 0.4613 - val_loss: 0.2848 - val_mse: 0.2848 - val_mae: 0.4230
# Epoch 62/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3370 - mse: 0.3370 - mae: 0.4735 - val_loss: 0.2837 - val_mse: 0.2837 - val_mae: 0.4220
# Epoch 63/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3592 - mse: 0.3592 - mae: 0.4747 - val_loss: 0.2834 - val_mse: 0.2834 - val_mae: 0.4214
# Epoch 64/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3367 - mse: 0.3367 - mae: 0.4656 - val_loss: 0.2830 - val_mse: 0.2830 - val_mae: 0.4208
# Epoch 65/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3249 - mse: 0.3249 - mae: 0.4609 - val_loss: 0.2824 - val_mse: 0.2824 - val_mae: 0.4202
# Epoch 66/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3759 - mse: 0.3759 - mae: 0.4898 - val_loss: 0.2819 - val_mse: 0.2819 - val_mae: 0.4197
# Epoch 67/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3310 - mse: 0.3310 - mae: 0.4660 - val_loss: 0.2830 - val_mse: 0.2830 - val_mae: 0.4208
# Epoch 68/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3555 - mse: 0.3555 - mae: 0.4791 - val_loss: 0.2847 - val_mse: 0.2847 - val_mae: 0.4228
# Epoch 69/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3513 - mse: 0.3513 - mae: 0.4734 - val_loss: 0.2872 - val_mse: 0.2872 - val_mae: 0.4253
# Epoch 70/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3492 - mse: 0.3492 - mae: 0.4829 - val_loss: 0.2893 - val_mse: 0.2893 - val_mae: 0.4273
# Epoch 71/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3396 - mse: 0.3396 - mae: 0.4726 - val_loss: 0.2910 - val_mse: 0.2910 - val_mae: 0.4288
# Epoch 72/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3293 - mse: 0.3293 - mae: 0.4584 - val_loss: 0.2930 - val_mse: 0.2930 - val_mae: 0.4307
# Epoch 73/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3396 - mse: 0.3396 - mae: 0.4648 - val_loss: 0.2937 - val_mse: 0.2937 - val_mae: 0.4313
# Epoch 74/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3326 - mse: 0.3326 - mae: 0.4626 - val_loss: 0.2942 - val_mse: 0.2942 - val_mae: 0.4318
# Epoch 75/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3411 - mse: 0.3411 - mae: 0.4712 - val_loss: 0.2953 - val_mse: 0.2953 - val_mae: 0.4329
# Epoch 76/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3366 - mse: 0.3366 - mae: 0.4642 - val_loss: 0.2961 - val_mse: 0.2961 - val_mae: 0.4339
# Epoch 77/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3383 - mse: 0.3383 - mae: 0.4675 - val_loss: 0.2957 - val_mse: 0.2957 - val_mae: 0.4337
# Epoch 78/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3521 - mse: 0.3521 - mae: 0.4794 - val_loss: 0.2968 - val_mse: 0.2968 - val_mae: 0.4350
# Epoch 79/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3323 - mse: 0.3323 - mae: 0.4694 - val_loss: 0.2991 - val_mse: 0.2991 - val_mae: 0.4371
# Epoch 80/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3406 - mse: 0.3406 - mae: 0.4739 - val_loss: 0.3008 - val_mse: 0.3008 - val_mae: 0.4386
# Epoch 81/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3404 - mse: 0.3404 - mae: 0.4680 - val_loss: 0.3005 - val_mse: 0.3005 - val_mae: 0.4384
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5774 - mse: 0.5774 - mae: 0.6064
# Validation Scorefor fold 1: [0.5773692727088928, 0.5773692727088928, 0.6064035892486572]
# Epoch 1/100
# 4/4 [==============================] - 4s 124ms/step - loss: 0.3172 - mse: 0.3172 - mae: 0.4482 - val_loss: 0.3455 - val_mse: 0.3455 - val_mae: 0.4712
# Epoch 2/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3482 - mse: 0.3482 - mae: 0.4652 - val_loss: 0.3460 - val_mse: 0.3460 - val_mae: 0.4715
# Epoch 3/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3291 - mse: 0.3291 - mae: 0.4574 - val_loss: 0.3473 - val_mse: 0.3473 - val_mae: 0.4727
# Epoch 4/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2942 - mse: 0.2942 - mae: 0.4266 - val_loss: 0.3471 - val_mse: 0.3471 - val_mae: 0.4725
# Epoch 5/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.2915 - mse: 0.2915 - mae: 0.4340 - val_loss: 0.3472 - val_mse: 0.3472 - val_mae: 0.4723
# Epoch 6/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3091 - mse: 0.3091 - mae: 0.4468 - val_loss: 0.3479 - val_mse: 0.3479 - val_mae: 0.4726
# Epoch 7/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3114 - mse: 0.3114 - mae: 0.4510 - val_loss: 0.3481 - val_mse: 0.3481 - val_mae: 0.4725
# Epoch 8/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3195 - mse: 0.3195 - mae: 0.4561 - val_loss: 0.3482 - val_mse: 0.3482 - val_mae: 0.4723
# Epoch 9/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3199 - mse: 0.3199 - mae: 0.4431 - val_loss: 0.3485 - val_mse: 0.3485 - val_mae: 0.4726
# Epoch 10/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3196 - mse: 0.3196 - mae: 0.4515 - val_loss: 0.3505 - val_mse: 0.3505 - val_mae: 0.4742
# Epoch 11/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2907 - mse: 0.2907 - mae: 0.4303 - val_loss: 0.3520 - val_mse: 0.3520 - val_mae: 0.4753
# Epoch 12/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3061 - mse: 0.3061 - mae: 0.4494 - val_loss: 0.3531 - val_mse: 0.3531 - val_mae: 0.4762
# Epoch 13/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2961 - mse: 0.2961 - mae: 0.4336 - val_loss: 0.3543 - val_mse: 0.3543 - val_mae: 0.4769
# Epoch 14/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3119 - mse: 0.3119 - mae: 0.4475 - val_loss: 0.3561 - val_mse: 0.3561 - val_mae: 0.4785
# Epoch 15/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3007 - mse: 0.3007 - mae: 0.4372 - val_loss: 0.3580 - val_mse: 0.3580 - val_mae: 0.4800
# Epoch 16/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3088 - mse: 0.3088 - mae: 0.4504 - val_loss: 0.3579 - val_mse: 0.3579 - val_mae: 0.4797
# Epoch 17/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3408 - mse: 0.3408 - mae: 0.4662 - val_loss: 0.3601 - val_mse: 0.3601 - val_mae: 0.4815
# Epoch 18/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3215 - mse: 0.3215 - mae: 0.4565 - val_loss: 0.3597 - val_mse: 0.3597 - val_mae: 0.4809
# Epoch 19/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2942 - mse: 0.2942 - mae: 0.4292 - val_loss: 0.3612 - val_mse: 0.3612 - val_mae: 0.4818
# Epoch 20/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3232 - mse: 0.3232 - mae: 0.4578 - val_loss: 0.3622 - val_mse: 0.3622 - val_mae: 0.4826
# Epoch 21/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3037 - mse: 0.3037 - mae: 0.4384 - val_loss: 0.3625 - val_mse: 0.3625 - val_mae: 0.4829
# Epoch 22/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2980 - mse: 0.2980 - mae: 0.4340 - val_loss: 0.3634 - val_mse: 0.3634 - val_mae: 0.4838
# Epoch 23/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3063 - mse: 0.3063 - mae: 0.4465 - val_loss: 0.3646 - val_mse: 0.3646 - val_mae: 0.4850
# Epoch 24/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3280 - mse: 0.3280 - mae: 0.4586 - val_loss: 0.3654 - val_mse: 0.3654 - val_mae: 0.4855
# Epoch 25/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3142 - mse: 0.3142 - mae: 0.4472 - val_loss: 0.3644 - val_mse: 0.3644 - val_mae: 0.4847
# Epoch 26/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3052 - mse: 0.3052 - mae: 0.4387 - val_loss: 0.3625 - val_mse: 0.3625 - val_mae: 0.4838
# Epoch 27/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3284 - mse: 0.3284 - mae: 0.4600 - val_loss: 0.3625 - val_mse: 0.3625 - val_mae: 0.4845
# Epoch 28/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2947 - mse: 0.2947 - mae: 0.4405 - val_loss: 0.3622 - val_mse: 0.3622 - val_mae: 0.4850
# Epoch 29/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3195 - mse: 0.3195 - mae: 0.4477 - val_loss: 0.3628 - val_mse: 0.3628 - val_mae: 0.4856
# Epoch 30/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3074 - mse: 0.3074 - mae: 0.4399 - val_loss: 0.3627 - val_mse: 0.3627 - val_mae: 0.4850
# Epoch 31/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3181 - mse: 0.3181 - mae: 0.4565 - val_loss: 0.3634 - val_mse: 0.3634 - val_mae: 0.4856
# Epoch 32/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3302 - mse: 0.3302 - mae: 0.4549 - val_loss: 0.3640 - val_mse: 0.3640 - val_mae: 0.4860
# Epoch 33/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3229 - mse: 0.3229 - mae: 0.4562 - val_loss: 0.3646 - val_mse: 0.3646 - val_mae: 0.4861
# Epoch 34/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3157 - mse: 0.3157 - mae: 0.4467 - val_loss: 0.3657 - val_mse: 0.3657 - val_mae: 0.4871
# Epoch 35/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2974 - mse: 0.2974 - mae: 0.4361 - val_loss: 0.3661 - val_mse: 0.3661 - val_mae: 0.4874
# Epoch 36/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3073 - mse: 0.3073 - mae: 0.4399 - val_loss: 0.3671 - val_mse: 0.3671 - val_mae: 0.4883
# Epoch 37/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3129 - mse: 0.3129 - mae: 0.4390 - val_loss: 0.3667 - val_mse: 0.3667 - val_mae: 0.4879
# Epoch 38/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2950 - mse: 0.2950 - mae: 0.4357 - val_loss: 0.3672 - val_mse: 0.3672 - val_mae: 0.4881
# Epoch 39/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3097 - mse: 0.3097 - mae: 0.4486 - val_loss: 0.3671 - val_mse: 0.3671 - val_mae: 0.4882
# Epoch 40/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3360 - mse: 0.3360 - mae: 0.4591 - val_loss: 0.3682 - val_mse: 0.3682 - val_mae: 0.4891
# Epoch 41/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3127 - mse: 0.3127 - mae: 0.4459 - val_loss: 0.3694 - val_mse: 0.3694 - val_mae: 0.4904
# Epoch 42/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2971 - mse: 0.2971 - mae: 0.4446 - val_loss: 0.3710 - val_mse: 0.3710 - val_mae: 0.4912
# Epoch 43/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2970 - mse: 0.2970 - mae: 0.4281 - val_loss: 0.3732 - val_mse: 0.3732 - val_mae: 0.4925
# Epoch 44/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3047 - mse: 0.3047 - mae: 0.4369 - val_loss: 0.3741 - val_mse: 0.3741 - val_mae: 0.4928
# Epoch 45/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3156 - mse: 0.3156 - mae: 0.4429 - val_loss: 0.3735 - val_mse: 0.3735 - val_mae: 0.4923
# Epoch 46/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3240 - mse: 0.3240 - mae: 0.4477 - val_loss: 0.3739 - val_mse: 0.3739 - val_mae: 0.4922
# Epoch 47/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2959 - mse: 0.2959 - mae: 0.4347 - val_loss: 0.3731 - val_mse: 0.3731 - val_mae: 0.4915
# Epoch 48/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2804 - mse: 0.2804 - mae: 0.4208 - val_loss: 0.3744 - val_mse: 0.3744 - val_mae: 0.4921
# Epoch 49/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3140 - mse: 0.3140 - mae: 0.4482 - val_loss: 0.3760 - val_mse: 0.3760 - val_mae: 0.4928
# Epoch 50/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3096 - mse: 0.3096 - mae: 0.4418 - val_loss: 0.3772 - val_mse: 0.3772 - val_mae: 0.4933
# Epoch 51/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2801 - mse: 0.2801 - mae: 0.4198 - val_loss: 0.3770 - val_mse: 0.3770 - val_mae: 0.4927
# Epoch 52/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2880 - mse: 0.2880 - mae: 0.4264 - val_loss: 0.3771 - val_mse: 0.3771 - val_mae: 0.4924
# Epoch 53/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3300 - mse: 0.3300 - mae: 0.4565 - val_loss: 0.3768 - val_mse: 0.3768 - val_mae: 0.4920
# Epoch 54/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3127 - mse: 0.3127 - mae: 0.4435 - val_loss: 0.3762 - val_mse: 0.3762 - val_mae: 0.4915
# Epoch 55/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.2992 - mse: 0.2992 - mae: 0.4249 - val_loss: 0.3752 - val_mse: 0.3752 - val_mae: 0.4909
# Epoch 56/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3075 - mse: 0.3075 - mae: 0.4356 - val_loss: 0.3749 - val_mse: 0.3749 - val_mae: 0.4906
# Epoch 57/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3243 - mse: 0.3243 - mae: 0.4558 - val_loss: 0.3764 - val_mse: 0.3764 - val_mae: 0.4915
# Epoch 58/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2914 - mse: 0.2914 - mae: 0.4324 - val_loss: 0.3765 - val_mse: 0.3765 - val_mae: 0.4915
# Epoch 59/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3075 - mse: 0.3075 - mae: 0.4495 - val_loss: 0.3768 - val_mse: 0.3768 - val_mae: 0.4916
# Epoch 60/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2900 - mse: 0.2900 - mae: 0.4271 - val_loss: 0.3759 - val_mse: 0.3759 - val_mae: 0.4911
# Epoch 61/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2961 - mse: 0.2961 - mae: 0.4353 - val_loss: 0.3756 - val_mse: 0.3756 - val_mae: 0.4908
# Epoch 62/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2911 - mse: 0.2911 - mae: 0.4295 - val_loss: 0.3752 - val_mse: 0.3752 - val_mae: 0.4907
# Epoch 63/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2972 - mse: 0.2972 - mae: 0.4284 - val_loss: 0.3740 - val_mse: 0.3740 - val_mae: 0.4897
# Epoch 64/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2975 - mse: 0.2975 - mae: 0.4397 - val_loss: 0.3742 - val_mse: 0.3742 - val_mae: 0.4897
# Epoch 65/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3124 - mse: 0.3124 - mae: 0.4450 - val_loss: 0.3749 - val_mse: 0.3749 - val_mae: 0.4900
# Epoch 66/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3168 - mse: 0.3168 - mae: 0.4361 - val_loss: 0.3761 - val_mse: 0.3761 - val_mae: 0.4908
# Epoch 67/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2790 - mse: 0.2790 - mae: 0.4280 - val_loss: 0.3756 - val_mse: 0.3756 - val_mae: 0.4903
# Epoch 68/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3186 - mse: 0.3186 - mae: 0.4524 - val_loss: 0.3758 - val_mse: 0.3758 - val_mae: 0.4904
# Epoch 69/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2991 - mse: 0.2991 - mae: 0.4371 - val_loss: 0.3769 - val_mse: 0.3769 - val_mae: 0.4914
# Epoch 70/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2967 - mse: 0.2967 - mae: 0.4306 - val_loss: 0.3774 - val_mse: 0.3774 - val_mae: 0.4919
# Epoch 71/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2954 - mse: 0.2954 - mae: 0.4302 - val_loss: 0.3776 - val_mse: 0.3776 - val_mae: 0.4923
# Epoch 72/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2931 - mse: 0.2931 - mae: 0.4259 - val_loss: 0.3775 - val_mse: 0.3775 - val_mae: 0.4924
# Epoch 73/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3126 - mse: 0.3126 - mae: 0.4441 - val_loss: 0.3784 - val_mse: 0.3784 - val_mae: 0.4935
# Epoch 74/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2665 - mse: 0.2665 - mae: 0.4138 - val_loss: 0.3787 - val_mse: 0.3787 - val_mae: 0.4941
# Epoch 75/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2827 - mse: 0.2827 - mae: 0.4230 - val_loss: 0.3789 - val_mse: 0.3789 - val_mae: 0.4946
# Epoch 76/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2975 - mse: 0.2975 - mae: 0.4384 - val_loss: 0.3794 - val_mse: 0.3794 - val_mae: 0.4952
# Epoch 77/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2832 - mse: 0.2832 - mae: 0.4257 - val_loss: 0.3794 - val_mse: 0.3794 - val_mae: 0.4952
# Epoch 78/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3021 - mse: 0.3021 - mae: 0.4395 - val_loss: 0.3814 - val_mse: 0.3814 - val_mae: 0.4960
# Epoch 79/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3001 - mse: 0.3001 - mae: 0.4327 - val_loss: 0.3832 - val_mse: 0.3832 - val_mae: 0.4969
# Epoch 80/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2892 - mse: 0.2892 - mae: 0.4249 - val_loss: 0.3837 - val_mse: 0.3837 - val_mae: 0.4965
# Epoch 81/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2892 - mse: 0.2892 - mae: 0.4372 - val_loss: 0.3849 - val_mse: 0.3849 - val_mae: 0.4969
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5841 - mse: 0.5841 - mae: 0.6099
# Validation Scorefor fold 2: [0.5840792059898376, 0.5840792059898376, 0.6099281311035156]

# %%
test3_loss, test3_mse, test3_mae = model3.evaluate(X_test, y_test)

print(f'Test Loss: {test3_loss}')
print(f'Test MAE: {test3_mae}')
print(f'Test MSE: {test3_mse}')
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2616 - mse: 1.2616 - mae: 0.8931
# Test Loss: 1.2615548372268677
# Test MAE: 0.8930771946907043
# Test MSE: 1.2615548372268677

# %%
#extracting relevant informationfrom the training history
train_loss =history3.history['loss']
val_loss = history3.history['val_loss']

#Plotting Traing and validation cures
plt.figure(figsize=(10,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and validation curves')
plt.show()

# %%
#making predictions
y_pred3 = model3.predict(X_test)
y_pred3_= y_pred3.flatten()
residual3 = y_test - y_pred3_
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
#Plotting the Residual Plot
plt.figure(figsize=(8,6))
plt.scatter(y_pred3_, residual3,alpha=0.5)
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.grid(True)
plt.show()

# %%
#plotting a learning curve
hist_dict = history3.history
loss_values = hist_dict['loss']
val_loss_values = hist_dict["val_loss"]

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs,loss_values,'ro-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
from lifelines import GompertzFilter, WeibullAFTFilter

gompertz = GompertzFilter()
gempertz.fit()

weibull_aft = WeibullAFTFilter()
weibull_aft.fit()

time_points = [10, 20, 30]
gompertz_survival_prob = gompertz.predict_survival_function(time_points)
weibull_survival_prob = weibull_aft.predict_survival_function(pd.DataFrame({'time': time_points}))

plt.figure()
plt.step(gompertz_survival_prob.index, gompertz_survival_prob.values, label='Gompertz')
plt.step(weibull_survival_prob.index, weibull_survival_prob.values, label='Weibull AFT')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-48-e4a181f2780f> in <cell line: 1>()
# ----> 1 from lifelines import GompertzFilter, WeibullAFTFilter
#       2
#       3 gompertz = GompertzFilter()
#       4 gempertz.fit()
#       5
#
# ModuleNotFoundError: No module named 'lifelines'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#defining custom loss functions
def custom_loss(y_true, y_prd):
  T_pred = tf.math.exp(y_prd)

  #Gompertz loss
  G_Loss =tf.reduce_mean(C*(y_prd-tf.math.log()))

  #Weibull AFT los
  weibull = -tf.reduce_mean(C*(tf.math.log()-tf.math.log()))
