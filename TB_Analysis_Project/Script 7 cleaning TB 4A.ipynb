# %% [markdown]
# #**Cleaning the data**

# %% [markdown]
# ##Loading data

# %%
import pandas as pd

# %%
 #Loading data
file_path = "/content/4A.xlsx"
data = pd.read_excel(file_path)
data.head()
# Out:
#   INITIALS UNIT IP NUMBER  SEX  AGE     RELIGION DISTRICT OF RESIDENCE  \
# 0        6  NaN       NaN  NaN  NaN          NaN                   NaN
# 1       AV   GI   1861499    M   28  Pentacostal               kampala
# 2       AV   GI   1861453    M   80       moslem               kampala
# 3       AV   GI   1861416    M   30   Protestant           Nakasongola
# 4       AV   GI   1861726    F   40     catholic                 Busia
#
#      DATE OF ADMISSION    DATE OF DISCHARGE           WORKING DIAGNOSIS  \
# 0                  NaN                  NaN                         NaN
# 1  2010-12-01 00:00:00  2010-01-01 00:00:00           ISS,B/pneumonia,,
# 2  2010-11-30 00:00:00  2010-12-03 00:00:00  oesophagitis,B/pneumonia,,
# 3  2010-11-30 00:00:00  2010-12-05 00:00:00          ISS,Abdominal TB,,
# 4  2010-12-03 00:00:00  2010-12-04 00:00:00               HIV +ve,PID,,
#
#     ICD10 CODE            FINAL DIAGNOSIS   ICD10CODE  OUT COME  DAYS OF STAY  \
# 0          NaN                        NaN         NaN       NaN           NaN
# 1    Z21,J18,,              B/pneumonia,,       J18,,  IMPROVED           1.0
# 2    K20,J18,,  Oesophagitis,B/pneumonia,    K20,J18,  IMPROVED           3.0
# 3  Z21,A18.3,,          ISS,Abdominal TB,  Z21,A18.3,  IMPROVED           5.0
# 4  Z21,N73.9,,               HIV +ve,PID,  Z21,N73.9,  IMPROVED           1.0
#
#    NUMBER OF PREVIOUS ADMISSIONS DATE OF ENTRY MARITAL STATUS
# 0                            NaN           NaT            NaN
# 1                            1.0    2010-12-03              9
# 2                            3.0    2010-12-06              2
# 3                            5.0    2010-12-06              2
# 4                            1.0    2010-12-06              9

# %% [markdown]
# ##Initial

# %%
#Removing features which are not going to be used for prediction
col_to_delete = ['INITIALS', 'ICD10 CODE', 'ICD10CODE', 'FINAL DIAGNOSIS', 'DATE OF ENTRY']

data = data.drop(columns=col_to_delete)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35953 entries, 0 to 35952
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   UNIT                           35952 non-null  object
#  1   IP NUMBER                      35927 non-null  object
#  2   SEX                            35948 non-null  object
#  3   AGE                            35948 non-null  object
#  4   RELIGION                       35884 non-null  object
#  5   DISTRICT OF RESIDENCE          35949 non-null  object
#  6   DATE OF ADMISSION              35950 non-null  object
#  7   DATE OF DISCHARGE              35951 non-null  object
#  8   WORKING DIAGNOSIS              35952 non-null  object
#  9   OUT COME                       35951 non-null  object
#  10  DAYS OF STAY                   35950 non-null  float64
#  11  NUMBER OF PREVIOUS ADMISSIONS  35942 non-null  float64
#  12  MARITAL STATUS                 35941 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 3.6+ MB

# %%
data.shape
# Out:
# (32989, 15)

# %%
#data.dropna(subset='NUMBER OF PREVIOUS ADMISSIONS', inplace=True)

# %%
#converting the Date of admission column to DateTime format
data['DATE OF ADMISSION'] = pd.to_datetime(data['DATE OF ADMISSION'], errors='coerce')

#Extracting the month from the date and creating its column
data['MONTH OF ADMISSION'] = data['DATE OF ADMISSION'].dt.strftime('%B')

#Extracting the day of the week from the date and creating its column
data['DAY OF ADMISSION'] = data['DATE OF ADMISSION'].dt.strftime('%A')

#Extracting the year from the date and creating its column
data['YEAR OF ADMISSION'] = data['DATE OF ADMISSION'].dt.year

#converting the date of discaharge column to DateTime format
data['DATE OF DISCHARGE'] = pd.to_datetime(data['DATE OF DISCHARGE'], errors='coerce')

#Extracting the year from the date and creating its column
data['YEAR OF DISCHARGE'] = data['DATE OF DISCHARGE'].dt.year

#Computing the days of stay and creating its column
data['DURATION'] = (data['DATE OF DISCHARGE'] - data['DATE OF ADMISSION']).dt.days + 1

#Using boolean indexing to obtain only the samples with positive duration
data =data[data['DURATION'] >0]
data.shape
# Out:
# (35736, 18)

# %%
data['DURATION'].unique()
# Out:
# array([4.0000e+00, 6.0000e+00, 2.0000e+00, 3.0000e+00, 5.0000e+00,
#        1.0000e+00, 1.0000e+01, 7.0000e+00, 1.2000e+01, 8.0000e+00,
#        9.0000e+00, 1.1000e+01, 1.9000e+01, 1.7000e+01, 1.4000e+01,
#        1.8000e+01, 2.1000e+01, 1.3000e+01, 3.2000e+01, 3.5000e+01,
#        3.9000e+01, 1.5000e+01, 2.0000e+01, 2.3000e+01, 2.4000e+01,
#        3.4000e+01, 2.6000e+01, 2.8000e+01, 1.6000e+01, 3.6000e+01,
#        2.2000e+01, 3.3000e+01, 6.3000e+01, 2.5000e+01, 4.0000e+01,
#        2.9000e+01, 4.5000e+01, 4.1000e+01, 4.2000e+01, 4.3000e+01,
#        3.1000e+01, 3.8000e+01, 3.0000e+01, 2.7000e+01, 3.7200e+02,
#        3.7900e+02, 9.6000e+01, 5.5000e+01, 7.7000e+01, 1.3800e+02,
#        1.2400e+02, 3.7000e+01, 6.4000e+01, 5.1000e+01, 4.4000e+01,
#        5.2000e+01, 5.0000e+01, 7.1000e+01, 7.5000e+01, 4.9000e+01,
#        4.7000e+01, 9.4000e+01, 1.6500e+02, 5.3000e+01, 5.7000e+01,
#        3.6900e+02, 5.8000e+01, 1.2000e+02, 1.0200e+02, 1.0800e+02,
#        7.8000e+01, 8.2000e+01, 6.5000e+01, 9.0000e+01, 7.2000e+01,
#        6.6000e+01, 2.2500e+02, 6.7000e+01, 4.7550e+03, 1.1000e+02,
#        9.5000e+01, 1.2600e+02, 6.8000e+01, 2.4400e+02, 3.4300e+02,
#        5.4000e+01, 1.0600e+02, 3.1900e+02, 1.6200e+02, 4.8000e+01,
#        5.9000e+01, 9.3000e+01, 6.2000e+01, 6.9000e+01, 3.7600e+02,
#        1.1080e+03, 3.7000e+02, 3.7400e+02, 9.2000e+01, 3.5900e+02,
#        3.6800e+02, 3.2878e+04, 3.0900e+02, 4.6000e+01, 3.0000e+02,
#        3.2151e+04, 2.1300e+02, 1.3700e+02])

# %% [markdown]
# ##Survival columns

# %%
# # Create separate "Survival" columns for each week's task
# for week in range(1, 5):
#     data[f'Survival_Week {week}'] = (data['OUT COME'] == 'DIED') & (data['DURATION'] <= week * 7).astype(int)
#     condition = (data['OUT COME'] != 'DIED') & (data['DURATION'] < week * 7)
#     data.loc[condition, f'Survival_Week {week}'] = 0
# Out:
# <ipython-input-86-ab4a810487d1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'Survival_Week {week}'] = (data['OUT COME'] == 'DIED') & (data['DURATION'] <= week * 7).astype(int)
# <ipython-input-86-ab4a810487d1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'Survival_Week {week}'] = (data['OUT COME'] == 'DIED') & (data['DURATION'] <= week * 7).astype(int)
# <ipython-input-86-ab4a810487d1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'Survival_Week {week}'] = (data['OUT COME'] == 'DIED') & (data['DURATION'] <= week * 7).astype(int)
# <ipython-input-86-ab4a810487d1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'Survival_Week {week}'] = (data['OUT COME'] == 'DIED') & (data['DURATION'] <= week * 7).astype(int)

# %%
# # Explicitly convert "Survival" columns to integers (int)
# for week in range(1, 5):
#     data[f'Survival_Week {week}'] = data.loc[:,f'Survival_Week {week}'].astype(int)
# Out:
# <ipython-input-87-cd436bfc4fca>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'Survival_Week {week}'] = data.loc[:,f'Survival_Week {week}'].astype(int)

# %%
# data['Survival_Week 1'].value_counts()
# Out:
# 0    30743
# 1     4993
# Name: Survival_Week 1, dtype: int64

# %%
# data['Survival_Week 2'].value_counts()
# Out:
# 0    29173
# 1     6563
# Name: Survival_Week 2, dtype: int64

# %%
# data['Survival_Week 3'].value_counts()
# Out:
# 0    28700
# 1     7036
# Name: Survival_Week 3, dtype: int64

# %%
# data['Survival_Week 4'].value_counts()
# Out:
# 0    28555
# 1     7181
# Name: Survival_Week 4, dtype: int64

# %%
# data['DURATION'].values
# Out:
# array([4., 6., 2., ..., 4., 5., 4.])

# %%
# pd.set_option('display.max_columns', None)
# data.sample(5)
# Out:
#       UNIT IP NUMBER SEX AGE RELIGION DISTRICT OF RESIDENCE DATE OF ADMISSION  \
# 35835  IDM    470513   M  70      COU               KAYUNGA        2019-08-12
# 1523   IDM   1946440   M  39    C O U               LUWEERO        2011-08-10
# 1618   IDM   1947651   M  45        ?               KAMPALA        2011-08-22
# 15422   GI   2264450   M  23      COU               KAMPALA        2014-04-23
# 16048   GI   2278218   M  18      COU                MUKONO        2014-06-10
#
#       DATE OF DISCHARGE           WORKING DIAGNOSIS  OUT COME  DAYS OF STAY  \
# 35835        2019-08-20             HIV,ENCPHALITIS      DIED           8.0
# 1523         2011-08-20          PNEUMONIA,TOXO,ISS  IMPROVED          11.0
# 1618         2011-08-23  B/PNEUMONIA,MENINGITIS,HIV      DIED           2.0
# 15422        2014-04-30                        UGIB  IMPROVED           7.0
# 16048        2014-06-10              FOOD POISONING  IMPROVED           1.0
#
#        NUMBER OF PREVIOUS ADMISSIONS MARITAL STATUS MONTH OF ADMISSION  \
# 35835                            0.0              9             August
# 1523                            11.0              2             August
# 1618                             2.0              9             August
# 15422                            0.0              1              April
# 16048                            0.0              1               June
#
#       DAY OF ADMISSION  YEAR OF ADMISSION  YEAR OF DISCHARGE  DURATION  \
# 35835           Monday             2019.0             2019.0       9.0
# 1523         Wednesday             2011.0             2011.0      11.0
# 1618            Monday             2011.0             2011.0       2.0
# 15422        Wednesday             2014.0             2014.0       8.0
# 16048          Tuesday             2014.0             2014.0       1.0
#
#        Survival_Week 1  Survival_Week 2  Survival_Week 3  Survival_Week 4
# 35835                0                1                1                1
# 1523                 0                0                0                0
# 1618                 1                1                1                1
# 15422                0                0                0                0
# 16048                0                0                0                0

# %%
data.columns.values
# Out:
# array(['UNIT', 'IP NUMBER', 'SEX', 'AGE', 'RELIGION',
#        'DISTRICT OF RESIDENCE', 'DATE OF ADMISSION', 'DATE OF DISCHARGE',
#        'WORKING DIAGNOSIS', 'OUT COME', 'DAYS OF STAY',
#        'NUMBER OF PREVIOUS ADMISSIONS', 'MARITAL STATUS',
#        'MONTH OF ADMISSION', 'DAY OF ADMISSION', 'YEAR OF ADMISSION',
#        'YEAR OF DISCHARGE', 'DURATION'], dtype=object)

# %% [markdown]
# ##**Cleanig RELIGIONS**

# %%
data['RELIGION'].unique()
# Out:
# array(['moslem', 'Protestant', 'catholic', 'Catholic', 'SDA', 'C O U',
#        'Moslem', 'R/C', 'B/A', 'Islam', 'COU', '?', nan, 'S D A', 'R /C',
#        'P.A.G', 'PROTESTANT', 'cou', 'C/U', 'ISLAM', 'c o u', 'islam',
#        'ISALM', 'PAG', 'P A G', 'IsLAM', 'r/c', 'R/A', 'CO U', 'SAVED',
#        'CUO', 'JEHOVA', 'ORTHODOX', 'ILSAM', 'JAHOVAH', 'MOSLEM', 'PRO',
#        'OTHERS', 'OTHER', 'F', 'CATHOLIC', 'ISLMA', 'MESSEIANIC',
#        'IISLAM', 'JOHOVAH', 'ISLLAM', 'SLAM', 'JEHOVAH', 'PROT', 'B,A',
#        'R,C', 'ANGELLA', 'PROST', 'C.O.U', 'WAKISO', 'ANGLICAN', 'PGA',
#        'R/C.', 'ISLAM.', 'GOU', 'LSLAM', 'ANGLIAN'], dtype=object)

# %%
#Grouping religions into Anglican, Moslem, Pentecoatal, Catholic, Others and unknown
religions = {'Protestant':'COU', 'C O U':'COU','c o u': 'COU', 'C/U': 'COU', 'Islam':'ISLAM', 'CUO':'COU',
             'B/A':'PENTECOSTAL', 'SDA':'OTHERS','PRO':'OTHERS','PAG':'OTHERS', 'MOSLEM':'ISLAM',
             '?':'OTHERS', 'R/C':'CATHOLIC', 'islam':'ISLAM', 'PAG':'PENTECOSTAL', 'P A G':'PENTECOSTAL',
             'IsLAM':'ISLAM', 'r/c':'CATHOLIC', 'R/A':'CATHOLIC', 'CO U':'COU', 'SAVED':'PENTECOSTAL',
             'JEHOVA':'OTHERS', 'ORTHODOX':'OTHERS', 'ILSAM':'ISLAM', 'JAHOVAH':'OTHERS', 'PRO':'COU',
             'F':'OTHERS', 'ISLMA':'ISLAM', 'MESSEIANIC':'OTHERS', 'IISLAM':'ISLAM', 'ISAM':'ISLAM',
             'JOHOVAH':'OTHERS', 'ISLLAM':'ISLAM', 'SLAM':'ISLAM', 'JEHOVAH':'OTHERS', 'PROT':'COU',
             'B,A':'PENTECOSTAL', 'R,C':'CATHOLIC', 'ANGELLA':'COU', 'PROST':'COU', 'C.O.U':'COU',
             'ANGLICAN':'COU', 'PGA':'PENTECOSTAL', 'R/C.':'CATHOLIC', 'GOU':'COU', 'LSLAM':'ISLAM',
             'ANGLIAN':'COU', 'OTHER':'OTHERS',  'WAKISO':'OTHERS', 'ISALM':'ISLAM', 'P.A.G':'PENTECOSTAL',
             'cou':'COU','Pentacostal':'PENTECOSTAL', 'moslem':'ISLAM', 'catholic':'CATHOLIC',
             'Catholic':'CATHOLIC', 'Moslem':'ISLAM', 'S D A':'OTHERS', 'R /C':'CATHOLIC',
             'PROTESTANT':'COU','ISLAM.':'ISLAM'
             }
data['RELIGION'] = data['RELIGION'].replace(religions)

#Filling the empty ones with OTHERS
data = data.dropna(subset=['RELIGION'])

data['RELIGION'].unique()
# Out:
# array(['ISLAM', 'COU', 'CATHOLIC', 'OTHERS', 'PENTECOSTAL'], dtype=object)

# %% [markdown]
# ##**Cleaning AGE**

# %%
data['AGE'].unique()
# Out:
# array(['80', '30', '40', '45', '53', '20', '50', '39', '21', '32', '35',
#        '38', '22', '70', '16', '49', '13', '46', '36', '44', '47', '55',
#        '24', '25', '51', '28', '23', '54', '59', '60', '17', '26', '43',
#        '52', '33', '57', '58', '37', '87', '14', '41', '27', '48', '83',
#        '68', '18', '34', '76', '74', '42', '75', '65', '19', '82', '62',
#        '66', '63', '61', '86', '29', '69', '73', '85', '31', '89', '67',
#        '56', nan, '64', '15', '72', '90', '78', '84', '12', '11', '100',
#        '71', 'AD', '81', '79', '77', '91', '?', '93', '98', '25+', '40+',
#        '88', '95', '94', '96', '92', '60+', '70+', '30+', '97', '102',
#        '64+', '100+', '31.', '5', '10'], dtype=object)

# %%
#Removing all samples with empty age
data = data.dropna(subset=['AGE'])

#removing all samples with non-numeric and unclear age value
data = data[~data['AGE'].isin(['?', 'AD'])]
data['AGE'] = data['AGE'].replace({'31.':31, '25+':25,'40+':40,'60+':60,'70+':70,
                                 '30+':34,'64+':64,'100+':100})
#Converting age datatype to integer
data['AGE'] = data['AGE'].astype(int)

data['AGE'].unique()
# Out:
# array([ 80,  30,  40,  45,  53,  20,  50,  39,  21,  32,  35,  38,  22,
#         70,  16,  49,  13,  46,  36,  44,  47,  55,  24,  25,  51,  28,
#         23,  54,  59,  60,  17,  26,  43,  52,  33,  57,  58,  37,  87,
#         14,  41,  27,  48,  83,  68,  18,  34,  76,  74,  42,  75,  65,
#         19,  82,  62,  66,  63,  61,  86,  29,  69,  73,  85,  31,  89,
#         67,  56,  64,  15,  72,  90,  78,  84,  12,  11, 100,  71,  81,
#         79,  77,  91,  93,  98,  88,  95,  94,  96,  92,  97, 102,   5,
#         10])

# %%
print(data['AGE'].isna().sum())
# Out:
# 0

# %% [markdown]
# ##**Cleaning DISTRICT OF RESIDENCE**

# %%
data['DISTRICT OF RESIDENCE'].unique()
# Out:
# array(['kampala', 'Nakasongola', 'Busia', 'Kiruhura', 'Kampala', 'Rakai',
#        'Luwero', 'Mukono', 'MITYANA', 'KAMPALA', 'Wakiso', 'Kibale',
#        'Soroti', 'Mityana', 'Kabong', 'Gomba', 'Bukwo', 'Kayunga',
#        'Mpigi', 'Kabarole', nan, 'Kasese', 'Kamugi', 'Bokomasimbi',
#        'TORORO', 'WAKISO', 'LUWERO', 'MPIGI', 'KASESE', 'KAMULI',
#        'MUBENDE', 'RAKAI', 'BUIKWE', 'KABALE', 'KAMPALA.', 'MUKONO',
#        'MASAKA', 'JINJA', 'GOMBA', 'mpigi', 'KAMWENGE', 'BUVUMA',
#        'KIBOGA', 'BUNOMANSIBI', 'NTUNGAMO', 'BWIIKE', 'SEMBABULE',
#        'luwero', 'IGANGA', 'KAPALA', 'BUSIA', 'NAMATAMBA', 'NAMUTUMBA',
#        'MASINDI', 'RWENGO', 'MANAFA', 'RWEMIYAGA', 'KAGOMA', 'KYANKWANZI',
#        'KAYUNGA', 'KYAKWANZE', 'KISORO', 'KANUGU', 'NAKASEKE', 'BUYUKWE',
#        'RUKUNGIRI', 'KIRYANDONGO', 'PALLISA', 'ARUA', 'LYANTONDE',
#        'KALANGALA', 'KABAROLE', 'LUWUKA', 'KYENJOJO', 'MBALA-MANAFA',
#        'KMPALA', 'BUKASA', 'KALIRO', 'MOYI', 'PALISA', 'APAC', 'BUSHENYI',
#        'NTENJERU', 'KATAKWI', 'KIBALE', 'KISOROR', 'NAKASONGOLA', 'NEBBI',
#        'FORTPOTAL', 'HOIMA', 'KANUNGU', 'BULISA', 'GOMBE', 'BUKOMASIMBI',
#        'MAYUGE', 'MBALE', 'RUBIRIZI', 'KABERAMAIDO', 'KISOLO', 'NAKASEKA',
#        'BUKOMANSIBI', 'BUYENDE', 'PALIISA', 'KYEGEGWA', 'BUGIRI',
#        'LUWEERO', 'BUNDIBUJJO', 'ISINGIRO', 'BUTAMBALA', 'BUGEMBE',
#        'MPUNGA', 'KIBINGE', 'KISUBI', 'KASUBI', 'SOROTI', 'LUUKA',
#        'MUSANSI', 'MITOMA', 'KIBUKU', 'KIRUHURA', 'LIRA', 'KOBOKO',
#        'BUSHALI', 'NAMAYINGO', 'BULEMEZI', 'KABULLA', 'UNKNOWN',
#        'MBARARA', 'MAYUGWA', 'MUTYANA', 'BUTAMBA', 'IBANDA', 'MASAkA',
#        'RWANGO', 'AGAGO', 'BAVUMA', 'KYEGYERWA', '?', 'PAIDA', 'NAKIFUMA',
#        'KOLE', 'KIBAALE', 'BUTAREJA', 'KUMI', 'BUHWEJU', 'BUTELEJA',
#        'KYENJONJO', 'FORTPORTAL', 'ENTEBBE', 'KIBOGO', 'KYANKWASI',
#        'MPIIGI', 'AJUMANI', 'MUKON', 'KAMBU', 'KAKUNGU', 'KALUNGU',
#        'BULAMBULI', 'LUWENGO', 'SHEEMA', 'PADER', 'KALILO', 'BAMUNANIKA',
#        'TB ADHEKAMPALA', 'BULENGA', 'KIBAGO', 'MITYANA,', 'BWUKYE',
#        'MAYUGWE', 'DOKOLO', 'BUKEDIA', 'MUBERU', 'BUYIKWE',
#        'NAKASONGOGOLA', 'BUYANDE', 'KIGA', 'AMURIA', 'BALE', 'CONGO',
#        'FORT PORTAL', 'BUSAMBALA', 'BUSENYI', 'KYADONDO', 'BOMBO',
#        'BUTAMBARO', 'BUWOYA', 'MALABA', 'NAKASESKE', 'SIRONKO',
#        'KALESIZO', 'KIBINGO', 'LWENGO', 'KARAMOJONG', 'KABAALE',
#        'WAKASEKE', 'YUMBE', 'NAMAGOMBA', 'MANAFWA', 'NAMUTAMBA',
#        'KUYUNGA', 'KALINGU', 'SHEIMA', 'BUSIRO', 'RUNKUNGIRI', 'MITOME',
#        'WAKISO/MASINDI', 'BUGOMA', 'WKAISO', 'BUDYOPE', 'HIOMA',
#        'NTUNGAMU', 'LUGAZI', 'SULAGABA', 'TANZANIA', 'MAYUNGA',
#        'KIRYNADONGO', 'NAMUTIMBA', 'BUDAKA', 'SESE', 'NAKIFUNA',
#        'BUSHENY', 'KOPOKO', 'RUGUNGIRI', 'LAMWO', 'KIRIHURA', 'ZAIRE',
#        'BUGERERE', 'MAYONGO', 'KAPCHORWA', 'KAWEMPE', 'BUSIMBI',
#        'NSINGIRO', 'BUSOGA', 'APACH', 'MOYO', 'IKYAKKA', 'KIGEZI',
#        'NGORA', 'BATAMBALA', 'SEMUTO', 'KIWOKO', 'KOTIDO', 'KAKIRO',
#        'ABIM', 'ABIMA', 'KANONI', 'KITGUM', 'WAKISI', 'NAKASOSNGOLA',
#        'KIHURA', 'IGAANGA', 'RAKIA', 'KYAKA', 'KIBUGA', 'GULU',
#        'KYENGEGWA', 'KYANKWANSI', 'SEMBAMBULE', 'NAMULONGE', 'JUBA',
#        'SERERE', 'BUGAMBO', 'KASENGE', 'MITOMI', 'SIROKO', 'HKAMPALA',
#        'KASANDA', 'NAKSONGOLA', 'BUSHEMA', 'BUDIBUJO', 'MBIKO',
#        'NAMUTUNBA', 'KYAKWANZI', 'KARAGWE,T.Z', 'NYAMKOLI', 'LUZIRA',
#        'KAMWENGYE', 'BUNDIBUJO', 'KAWEMGE', 'KAWULO', 'KIRYANDOGO',
#        'KIVUHURA', 'BUDUDA', 'KIGALI', 'NAKAPIRIPIRI', 'BUYAGABO',
#        'MAYUGA', 'NTOROKO', 'GOLANAKASON', 'NSANGI', 'MUTONO', 'KIRUHUWA',
#        'BBAALE', 'KAMAWENGYE', 'BUTAMBALA/MPIGI', 'KYANKWANJI', 'BUSIRI',
#        'KIKUHURA', 'RUNDI', 'BUGABOLA', 'KIWEERO', 'ZOMBO', 'SSESE',
#        'MOROTO', 'PADAR', 'NAKASKE', 'BUSI ISLAND', 'BULAMBALA',
#        'KAMAPALA', 'SHOMA', 'KIIRA', 'KANONGO', 'wakiso', 'RUBUKA',
#        'MAKINDYE', 'BUNDIBUGYO', 'MUTOMA', 'NYANYARWANDA', 'MANYAGWA',
#        'SHEREMA', 'BUKWO', 'KAPIRIPIRI', 'BUKOMENSIMBI', 'NAMAYENGO',
#        'OYAM', 'WANSSE-SUDAN', 'KALWANA', 'KAYUNGU', 'SUDAN', 'KYANGA',
#        'KIKANDWA', 'RWEGO', 'NAMYINGO', 'FORT-PORTAL', 'AMOLATAR',
#        'BULWENZU', 'BUTAMBALE', 'BIGIRI', 'SSEMBABULE', 'ALEBTONG',
#        'LWEGO', 'BUTEMBA', 'BUKOMANSIMBI', 'BUKEDEA', 'BUKOMASINDE',
#        'BULERA', 'BUNYAMBO', 'MUYENDE', 'NAKESONGOLA', 'KIBULI',
#        'ADJUMANI', 'ALUR', 'BUSUNJU', 'LUBIRIZI', 'SAMBABULE', 'SINGO',
#        'KAPCHRWA', 'KENYA', 'MUBARARA', 'KIGUMBA', 'SSEMBEBULE', 'MADDU',
#        'NAMATUMBA', 'BUSUJJU', 'NTUNGAM0', 'BUYONDE', 'KAMPAL', 'B/A',
#        'BUTEMBALE', 'BULIISA', 'BUTALEJA', 'RWANDA', 'PAKWACH', 'KAYAKKA',
#        'SOUTH SUDAN', 'KABARORE', 'KAMABOGA', 'NAKASENGOLA', 'KYERWA',
#        'BUTANBALA', 'MITOOMA', 'SHEMA', 'OTUKE', 'FORT-PARTAL', 'SEMBALE',
#        'KAGADI', 'ZOKO', 'NKYANKWANZI', 'KYAKWALI', 'GAMBA', 'KALUNGI',
#        'KATORO', 'KIRANDONGO', 'PACKWACH', 'BIUKWE', 'KIBIITO', 'SEYA',
#        'MUTUKULA', 'AMURU', 'MASINDE', 'KYANKWANGI', 'LYATONDE',
#        'NTUNGAMOA', 'BUKOMERO', 'LUKIRIRI', 'KABEREMAIDO', 'KABARAMAIDO',
#        'KYAMPISI', 'NAMAYUMBA', 'SEM[BABULE', 'KAKIRI', 'AMUDATI',
#        'MIYANA', 'WAMWANYA', 'KABALORE', 'KYALWASI', 'KAYUUNGA',
#        'KAYONZA', 'AMUDAT', 'RUCHURU', 'KAMWANGYE', 'MPIG', 'KOOME',
#        'KIRYADONGO', 'LUWERA', 'MULAGO', 'BWEYOGERERE', 'KAMWKYA',
#        'BULEEBI', 'MUTUNGO', 'KIREKA', 'NAMUGONGO', 'KAKUMIRO', 'NSAMBYA',
#        'WAKIS', 'RUBANDA', 'SOROT', 'KAGACH', 'KIBORO', 'WOBULENZI',
#        'AMOLATER', 'KWEN', 'COU', 'KANKILARE', 'BUHEZU', 'BUKOMANSIS',
#        'KYOTERA', 'KAKUMIRU', 'KIRUHURU', 'BUHWEJJU', 'KYANKWAZI',
#        'KABULASOKE', 'WABULENZI', 'KIGADI', 'LYONTONDE', 'AMOLATOR',
#        'MOMBASA', 'RUKIGA', 'KIBOOGA', 'KYENGERA', 'MIYYANA', 'KYIBONGA',
#        'BWENKE', 'BUSIIRO', 'MUNKONO', 'KIRYANDONGA', 'KIYADONDO',
#        'KYEGAGWA', 'KANUNGO', 'BUKUMASIMBI', 'BUNDUBUGYO', 'BUTEEGA',
#        'BUTALENGU', 'KYANKWAGI', 'NWOOYA', 'KAGALI', 'BUHWENJU', 'BUTEBO',
#        'NAPARK', 'KABONG', 'KASSANDA', 'BANYANGABO', 'BUGWERI',
#        'KABERAMIADO', 'NWOYA', 'MUNYORO', 'WAKISA', 'NAMATUBA', 'BULISO',
#        'BUGERI', 'LWERO', 'NALUKOLONGO', 'OMORO', 'RUBAGA', 'KWANIA',
#        'AMOLATA', 'MARACHA', 'KYOTEGA', 'MUHOTI', 'IGANAGA', 'AMOLARTAR',
#        'KAYUNYI', 'BURUNDI', 'LYANTODE', 'NUKONO', 'LUEWERO',
#        'NAMBAYIMBA', 'KAMPLA', 'MUBEMDE', 'BULLISA', 'APAL', 'NAPAK'],
#       dtype=object)

# %%
missing = data['DISTRICT OF RESIDENCE'].isna().sum()
print(missing)
# Out:
# 1

# %%
#Deleting samples with no district of residence
data = data.dropna(subset=['DISTRICT OF RESIDENCE'])

data['REGION'] = data['DISTRICT OF RESIDENCE']

#Renaming Wrongly spelt districts
rename = {'RUGUNGIRI':'RUKUNGIRI', 'NSINGIRO':'ISINGIRO', 'MITOMA':'MITOOMA', 'KIRIHURA':'KIRUHURA',
          'KIRUHUWA':'KIRUHURA', 'KYANKWANSI':'KYANKWANZI', 'KYAKWANZI':'KYANKWANZI',
          'KAYUNYI':'KAYUNGA', 'LUWERO':'LUWEERO', 'MITYANA,':'MITYANA', 'KYENGERA':'WAKISO',
          'KAKUMIRU':'KAKUMIRO','BATAMBALA':'BUTAMBALA', 'BUKOMASIMBI':'BUKOMANSIMBI',
          'IGAANGA':'IGANGA', 'BUYUNKWE':'BUIKWE', 'KIBALE':'KIBAALE', 'KABAALE':'KABALE',
          'BUYAGABO':'BUNYANGABO', 'BULISA':'BULIISA', 'KIRYANDOGO':'KIRYANDONGO',
          'MUTONO':'MUKONO', 'MUBEMDE':'MUBENDE', 'NAMAGOMBA':'BUSIRO', 'TB ADHEKAMPALA':'KAMPALA',
          'MASINDE':'MASINDI','BUYUKWE':'BUIKWE','WAKISI':'WAKISO', 'WAKISO/MASINDI':'WAKISO',
          'BUSHALI':'BUSHENYI'
          }
data['REGION'] = data['REGION'].replace(rename)
# Out:
# <ipython-input-15-b21aae1cda0d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['REGION'] = data['DISTRICT OF RESIDENCE']
# <ipython-input-15-b21aae1cda0d>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['REGION'] = data['REGION'].replace(rename)

# %%
data['REGION'].unique()
# Out:
# array(['kampala', 'Nakasongola', 'Busia', 'Kiruhura', 'Kampala', 'Rakai',
#        'Luwero', 'Mukono', 'MITYANA', 'KAMPALA', 'Wakiso', 'Kibale',
#        'Soroti', 'Mityana', 'Kabong', 'Gomba', 'Bukwo', 'Kayunga',
#        'Mpigi', 'Kabarole', 'Kasese', 'Kamugi', 'Bokomasimbi', 'TORORO',
#        'WAKISO', 'LUWEERO', 'MPIGI', 'KASESE', 'KAMULI', 'MUBENDE',
#        'RAKAI', 'BUIKWE', 'KABALE', 'KAMPALA.', 'MUKONO', 'MASAKA',
#        'JINJA', 'GOMBA', 'mpigi', 'KAMWENGE', 'BUVUMA', 'KIBOGA',
#        'BUNOMANSIBI', 'NTUNGAMO', 'BWIIKE', 'SEMBABULE', 'luwero',
#        'IGANGA', 'KAPALA', 'BUSIA', 'NAMATAMBA', 'NAMUTUMBA', 'MASINDI',
#        'RWENGO', 'MANAFA', 'RWEMIYAGA', 'KAGOMA', 'KYANKWANZI', 'KAYUNGA',
#        'KYAKWANZE', 'KISORO', 'KANUGU', 'NAKASEKE', 'RUKUNGIRI',
#        'KIRYANDONGO', 'PALLISA', 'ARUA', 'LYANTONDE', 'KALANGALA',
#        'KABAROLE', 'LUWUKA', 'KYENJOJO', 'MBALA-MANAFA', 'KMPALA',
#        'BUKASA', 'KALIRO', 'MOYI', 'PALISA', 'APAC', 'BUSHENYI',
#        'NTENJERU', 'KATAKWI', 'KIBAALE', 'KISOROR', 'NAKASONGOLA',
#        'NEBBI', 'FORTPOTAL', 'HOIMA', 'KANUNGU', 'BULIISA', 'GOMBE',
#        'BUKOMANSIMBI', 'MAYUGE', 'MBALE', 'RUBIRIZI', 'KABERAMAIDO',
#        'KISOLO', 'NAKASEKA', 'BUKOMANSIBI', 'BUYENDE', 'PALIISA',
#        'KYEGEGWA', 'BUGIRI', 'BUNDIBUJJO', 'ISINGIRO', 'BUTAMBALA',
#        'BUGEMBE', 'MPUNGA', 'KIBINGE', 'KISUBI', 'KASUBI', 'SOROTI',
#        'LUUKA', 'MUSANSI', 'MITOOMA', 'KIBUKU', 'KIRUHURA', 'LIRA',
#        'KOBOKO', 'NAMAYINGO', 'BULEMEZI', 'KABULLA', 'UNKNOWN', 'MBARARA',
#        'MAYUGWA', 'MUTYANA', 'BUTAMBA', 'IBANDA', 'MASAkA', 'RWANGO',
#        'AGAGO', 'BAVUMA', 'KYEGYERWA', '?', 'PAIDA', 'NAKIFUMA', 'KOLE',
#        'BUTAREJA', 'KUMI', 'BUHWEJU', 'BUTELEJA', 'KYENJONJO',
#        'FORTPORTAL', 'ENTEBBE', 'KIBOGO', 'KYANKWASI', 'MPIIGI',
#        'AJUMANI', 'MUKON', 'KAMBU', 'KAKUNGU', 'KALUNGU', 'BULAMBULI',
#        'LUWENGO', 'SHEEMA', 'PADER', 'KALILO', 'BAMUNANIKA', 'BULENGA',
#        'KIBAGO', 'BWUKYE', 'MAYUGWE', 'DOKOLO', 'BUKEDIA', 'MUBERU',
#        'BUYIKWE', 'NAKASONGOGOLA', 'BUYANDE', 'KIGA', 'AMURIA', 'BALE',
#        'CONGO', 'FORT PORTAL', 'BUSAMBALA', 'BUSENYI', 'KYADONDO',
#        'BOMBO', 'BUTAMBARO', 'BUWOYA', 'MALABA', 'NAKASESKE', 'SIRONKO',
#        'KALESIZO', 'KIBINGO', 'LWENGO', 'KARAMOJONG', 'WAKASEKE', 'YUMBE',
#        'BUSIRO', 'MANAFWA', 'NAMUTAMBA', 'KUYUNGA', 'KALINGU', 'SHEIMA',
#        'RUNKUNGIRI', 'MITOME', 'BUGOMA', 'WKAISO', 'BUDYOPE', 'HIOMA',
#        'NTUNGAMU', 'LUGAZI', 'SULAGABA', 'TANZANIA', 'MAYUNGA',
#        'KIRYNADONGO', 'NAMUTIMBA', 'BUDAKA', 'SESE', 'NAKIFUNA',
#        'BUSHENY', 'KOPOKO', 'LAMWO', 'ZAIRE', 'BUGERERE', 'MAYONGO',
#        'KAPCHORWA', 'KAWEMPE', 'BUSIMBI', 'BUSOGA', 'APACH', 'MOYO',
#        'IKYAKKA', 'KIGEZI', 'NGORA', 'SEMUTO', 'KIWOKO', 'KOTIDO',
#        'KAKIRO', 'ABIM', 'ABIMA', 'KANONI', 'KITGUM', 'NAKASOSNGOLA',
#        'KIHURA', 'RAKIA', 'KYAKA', 'KIBUGA', 'GULU', 'KYENGEGWA',
#        'SEMBAMBULE', 'NAMULONGE', 'JUBA', 'SERERE', 'BUGAMBO', 'KASENGE',
#        'MITOMI', 'SIROKO', 'HKAMPALA', 'KASANDA', 'NAKSONGOLA', 'BUSHEMA',
#        'BUDIBUJO', 'MBIKO', 'NAMUTUNBA', 'KARAGWE,T.Z', 'NYAMKOLI',
#        'LUZIRA', 'KAMWENGYE', 'BUNDIBUJO', 'KAWEMGE', 'KAWULO',
#        'KIVUHURA', 'BUDUDA', 'KIGALI', 'NAKAPIRIPIRI', 'BUNYANGABO',
#        'MAYUGA', 'NTOROKO', 'GOLANAKASON', 'NSANGI', 'BBAALE',
#        'KAMAWENGYE', 'BUTAMBALA/MPIGI', 'KYANKWANJI', 'BUSIRI',
#        'KIKUHURA', 'RUNDI', 'BUGABOLA', 'KIWEERO', 'ZOMBO', 'SSESE',
#        'MOROTO', 'PADAR', 'NAKASKE', 'BUSI ISLAND', 'BULAMBALA',
#        'KAMAPALA', 'SHOMA', 'KIIRA', 'KANONGO', 'wakiso', 'RUBUKA',
#        'MAKINDYE', 'BUNDIBUGYO', 'MUTOMA', 'NYANYARWANDA', 'MANYAGWA',
#        'SHEREMA', 'BUKWO', 'KAPIRIPIRI', 'BUKOMENSIMBI', 'NAMAYENGO',
#        'OYAM', 'WANSSE-SUDAN', 'KALWANA', 'KAYUNGU', 'SUDAN', 'KYANGA',
#        'KIKANDWA', 'RWEGO', 'NAMYINGO', 'FORT-PORTAL', 'AMOLATAR',
#        'BULWENZU', 'BUTAMBALE', 'BIGIRI', 'SSEMBABULE', 'ALEBTONG',
#        'LWEGO', 'BUTEMBA', 'BUKEDEA', 'BUKOMASINDE', 'BULERA', 'BUNYAMBO',
#        'MUYENDE', 'NAKESONGOLA', 'KIBULI', 'ADJUMANI', 'ALUR', 'BUSUNJU',
#        'LUBIRIZI', 'SAMBABULE', 'SINGO', 'KAPCHRWA', 'KENYA', 'MUBARARA',
#        'KIGUMBA', 'SSEMBEBULE', 'MADDU', 'NAMATUMBA', 'BUSUJJU',
#        'NTUNGAM0', 'BUYONDE', 'KAMPAL', 'B/A', 'BUTEMBALE', 'BUTALEJA',
#        'RWANDA', 'PAKWACH', 'KAYAKKA', 'SOUTH SUDAN', 'KABARORE',
#        'KAMABOGA', 'NAKASENGOLA', 'KYERWA', 'BUTANBALA', 'SHEMA', 'OTUKE',
#        'FORT-PARTAL', 'SEMBALE', 'KAGADI', 'ZOKO', 'NKYANKWANZI',
#        'KYAKWALI', 'GAMBA', 'KALUNGI', 'KATORO', 'KIRANDONGO', 'PACKWACH',
#        'BIUKWE', 'KIBIITO', 'SEYA', 'MUTUKULA', 'AMURU', 'KYANKWANGI',
#        'LYATONDE', 'NTUNGAMOA', 'BUKOMERO', 'LUKIRIRI', 'KABEREMAIDO',
#        'KABARAMAIDO', 'KYAMPISI', 'NAMAYUMBA', 'SEM[BABULE', 'KAKIRI',
#        'AMUDATI', 'MIYANA', 'WAMWANYA', 'KABALORE', 'KYALWASI',
#        'KAYUUNGA', 'KAYONZA', 'AMUDAT', 'RUCHURU', 'KAMWANGYE', 'MPIG',
#        'KOOME', 'KIRYADONGO', 'LUWERA', 'MULAGO', 'BWEYOGERERE',
#        'KAMWKYA', 'BULEEBI', 'MUTUNGO', 'KIREKA', 'NAMUGONGO', 'KAKUMIRO',
#        'NSAMBYA', 'WAKIS', 'RUBANDA', 'SOROT', 'KAGACH', 'KIBORO',
#        'WOBULENZI', 'AMOLATER', 'KWEN', 'COU', 'KANKILARE', 'BUHEZU',
#        'BUKOMANSIS', 'KYOTERA', 'KIRUHURU', 'BUHWEJJU', 'KYANKWAZI',
#        'KABULASOKE', 'WABULENZI', 'KIGADI', 'LYONTONDE', 'AMOLATOR',
#        'MOMBASA', 'RUKIGA', 'KIBOOGA', 'MIYYANA', 'KYIBONGA', 'BWENKE',
#        'BUSIIRO', 'MUNKONO', 'KIRYANDONGA', 'KIYADONDO', 'KYEGAGWA',
#        'KANUNGO', 'BUKUMASIMBI', 'BUNDUBUGYO', 'BUTEEGA', 'BUTALENGU',
#        'KYANKWAGI', 'NWOOYA', 'KAGALI', 'BUHWENJU', 'BUTEBO', 'NAPARK',
#        'KABONG', 'KASSANDA', 'BANYANGABO', 'BUGWERI', 'KABERAMIADO',
#        'NWOYA', 'MUNYORO', 'WAKISA', 'NAMATUBA', 'BULISO', 'BUGERI',
#        'LWERO', 'NALUKOLONGO', 'OMORO', 'RUBAGA', 'KWANIA', 'AMOLATA',
#        'MARACHA', 'KYOTEGA', 'MUHOTI', 'IGANAGA', 'AMOLARTAR', 'BURUNDI',
#        'LYANTODE', 'NUKONO', 'LUEWERO', 'NAMBAYIMBA', 'KAMPLA', 'BULLISA',
#        'APAL', 'NAPAK'], dtype=object)

# %%
#Grouping the districts int regions ie northen, eastern, central, western and unknown

northern = {'ADJUMANI': 'NORTHERN', 'ARUA': 'NORTHERN', 'AMURU': 'NORTHERN',
            'APAC': 'NORTHERN', 'GULU': 'NORTHERN', 'KOBOKO':'NORTHERN', 'KOTIDO': 'NORTHERN',
            'LIRA': 'NORTHERN',  'NAPARK':'NORTHERN', 'NEBBI':'NORTHERN', 'MOROTO': 'NORTHERN'}
data['REGION'] = data['REGION'].replace(northern)

eastern = {'AMURIA':'EASTERN', 'BUDAKA':'EASTERN', 'BUGIRI':'EASTERN', 'TORORO':'EASTERN',
           'BUSIA':'EASTERN', 'BUYENDE':'EASTERN', 'BUYUKWE':'EASTERN', 'IGAANGA':'EASTERN',
           'IGANGA':'EASTERN', 'JINJA':'EASTERN', 'KABERAMAIDO':'EASTERN', 'KAMULI':'EASTERN',
           'KUMI':'EASTERN','MAYUGE':'EASTERN', 'MBALE':'EASTERN', 'MBIKO':'EASTERN',
           'NAMAYINGO':'EASTERN', 'NAMUTUMBA':'EASTERN', 'SOROTI':'EASTERN',
           }
data['REGION'] = data['REGION'].replace(eastern)

central = {'Kampala':'CENTRAL', 'Wakiso':'CENTRAL', 'BUSIRO':'CENTRAL', 'BUTAMBALA':'CENTRAL',
           'ENTEBBE':'CENTRAL', 'GOMBA':'CENTRAL', 'GOMBE':'CENTRAL', 'KAKUMIRO':'CENTRAL',
           'KALANGALA':'CENTRAL', 'KALUNGU':'CENTRAL', 'KALWANA':'CENTRAL', 'KAMPALA':'CENTRAL',
           'KASANDA':'CENTRAL', 'KAWEMPE':'CENTRAL', 'KAYUNGA':'CENTRAL',  'KYANKWANZI':'CENTRAL',
           'KYOTERA':'CENTRAL', 'LUWEERO':'CENTRAL', 'LWENGO':'CENTRAL', 'LYANTONDE':'CENTRAL',
           'MASAKA':'CENTRAL', 'MITYANA':'CENTRAL', 'MPIGI':'CENTRAL', 'MUBENDE':'CENTRAL',
           'MUKONO':'CENTRAL', 'NAKASEKE':'CENTRAL', 'Nakasongola':'CENTRAL', 'SEMBABULE':'CENTRAL',
           'SESE':'CENTRAL', 'WAKISO':'CENTRAL','BUKUMASIMBI':'CENTRAL',
           'KIBOGA':'CENTRAL', 'NAKASONGOLA':'CENTRAL', 'BUKOMANSIMBI':'CENTRAL', 'BUIKWE':'EASTERN'
           }
data['REGION'] = data['REGION'].replace(central)

western ={ 'BULIISA':'WESTERN', 'BUSHENYI':'WESTERN', 'BUNYANGABO':'WESTERN',
           'FORTPORTAL':'WESTERN', 'HOIMA':'WESTERN', 'KAGADI':'WESTERN', 'KIRYANDOGO':'WESTERN',
           'KIRYANDONGO':'WESTERN', 'KYEGEGWA':'WESTERN', 'KYENJOJO':'WESTERN', 'MASINDE':'WESTERN',
           'MASINDI':'WESTERN', 'BUHWEJU':'WESTERN', 'ISINGIRO':'WESTERN', 'KABALE':'WESTERN',
           'MBARARA':'WESTERN', 'KIBAALE':'WESTERN', 'KANUNGU':'WESTERN', 'MITOOMA':'WESTERN',
           'RUKUNGIRI':'WESTERN', 'KAMWENGE':'WESTERN', 'KABAALE':'WESTERN',
           'NTOROKO':'WESTERN', 'NTUNGAMO':'WESTERN', 'RAKAI':'WESTERN', 'KABAROLE':'WESTERN',
           'KIRUHURA':'WESTERN', 'SHEMA':'WESTERN', 'KASESE':'WESTERN'
          }
data['REGION'] = data['REGION'].replace(western)

unknown ={'?':'UNKNOWN', 'SULAGABA':'UNKNOWN', 'BWENKE':'UNKNOWN','SUDAN':'UNKNOWN',
          'GOLANAKASON':'UNKNOWN'}
data['REGION'] = data['REGION'].replace(unknown)


data['REGION'].unique()
# Out:
# array(['kampala', 'CENTRAL', 'Busia', 'Kiruhura', 'Rakai', 'Luwero',
#        'Mukono', 'Kibale', 'Soroti', 'Mityana', 'Kabong', 'Gomba',
#        'Bukwo', 'Kayunga', 'Mpigi', 'Kabarole', 'Kasese', 'Kamugi',
#        'Bokomasimbi', 'EASTERN', 'WESTERN', 'KAMPALA.', 'mpigi', 'BUVUMA',
#        'BUNOMANSIBI', 'BWIIKE', 'luwero', 'KAPALA', 'NAMATAMBA', 'RWENGO',
#        'MANAFA', 'RWEMIYAGA', 'KAGOMA', 'KYAKWANZE', 'KISORO', 'KANUGU',
#        'PALLISA', 'NORTHERN', 'LUWUKA', 'MBALA-MANAFA', 'KMPALA',
#        'BUKASA', 'KALIRO', 'MOYI', 'PALISA', 'NTENJERU', 'KATAKWI',
#        'KISOROR', 'FORTPOTAL', 'RUBIRIZI', 'KISOLO', 'NAKASEKA',
#        'BUKOMANSIBI', 'PALIISA', 'BUNDIBUJJO', 'BUGEMBE', 'MPUNGA',
#        'KIBINGE', 'KISUBI', 'KASUBI', 'LUUKA', 'MUSANSI', 'KIBUKU',
#        'BULEMEZI', 'KABULLA', 'UNKNOWN', 'MAYUGWA', 'MUTYANA', 'BUTAMBA',
#        'IBANDA', 'MASAkA', 'RWANGO', 'AGAGO', 'BAVUMA', 'KYEGYERWA',
#        'PAIDA', 'NAKIFUMA', 'KOLE', 'BUTAREJA', 'BUTELEJA', 'KYENJONJO',
#        'KIBOGO', 'KYANKWASI', 'MPIIGI', 'AJUMANI', 'MUKON', 'KAMBU',
#        'KAKUNGU', 'BULAMBULI', 'LUWENGO', 'SHEEMA', 'PADER', 'KALILO',
#        'BAMUNANIKA', 'BULENGA', 'KIBAGO', 'BWUKYE', 'MAYUGWE', 'DOKOLO',
#        'BUKEDIA', 'MUBERU', 'BUYIKWE', 'NAKASONGOGOLA', 'BUYANDE', 'KIGA',
#        'BALE', 'CONGO', 'FORT PORTAL', 'BUSAMBALA', 'BUSENYI', 'KYADONDO',
#        'BOMBO', 'BUTAMBARO', 'BUWOYA', 'MALABA', 'NAKASESKE', 'SIRONKO',
#        'KALESIZO', 'KIBINGO', 'KARAMOJONG', 'WAKASEKE', 'YUMBE',
#        'MANAFWA', 'NAMUTAMBA', 'KUYUNGA', 'KALINGU', 'SHEIMA',
#        'RUNKUNGIRI', 'MITOME', 'BUGOMA', 'WKAISO', 'BUDYOPE', 'HIOMA',
#        'NTUNGAMU', 'LUGAZI', 'TANZANIA', 'MAYUNGA', 'KIRYNADONGO',
#        'NAMUTIMBA', 'NAKIFUNA', 'BUSHENY', 'KOPOKO', 'LAMWO', 'ZAIRE',
#        'BUGERERE', 'MAYONGO', 'KAPCHORWA', 'BUSIMBI', 'BUSOGA', 'APACH',
#        'MOYO', 'IKYAKKA', 'KIGEZI', 'NGORA', 'SEMUTO', 'KIWOKO', 'KAKIRO',
#        'ABIM', 'ABIMA', 'KANONI', 'KITGUM', 'NAKASOSNGOLA', 'KIHURA',
#        'RAKIA', 'KYAKA', 'KIBUGA', 'KYENGEGWA', 'SEMBAMBULE', 'NAMULONGE',
#        'JUBA', 'SERERE', 'BUGAMBO', 'KASENGE', 'MITOMI', 'SIROKO',
#        'HKAMPALA', 'NAKSONGOLA', 'BUSHEMA', 'BUDIBUJO', 'NAMUTUNBA',
#        'KARAGWE,T.Z', 'NYAMKOLI', 'LUZIRA', 'KAMWENGYE', 'BUNDIBUJO',
#        'KAWEMGE', 'KAWULO', 'KIVUHURA', 'BUDUDA', 'KIGALI',
#        'NAKAPIRIPIRI', 'MAYUGA', 'NSANGI', 'BBAALE', 'KAMAWENGYE',
#        'BUTAMBALA/MPIGI', 'KYANKWANJI', 'BUSIRI', 'KIKUHURA', 'RUNDI',
#        'BUGABOLA', 'KIWEERO', 'ZOMBO', 'SSESE', 'PADAR', 'NAKASKE',
#        'BUSI ISLAND', 'BULAMBALA', 'KAMAPALA', 'SHOMA', 'KIIRA',
#        'KANONGO', 'wakiso', 'RUBUKA', 'MAKINDYE', 'BUNDIBUGYO', 'MUTOMA',
#        'NYANYARWANDA', 'MANYAGWA', 'SHEREMA', 'BUKWO', 'KAPIRIPIRI',
#        'BUKOMENSIMBI', 'NAMAYENGO', 'OYAM', 'WANSSE-SUDAN', 'KAYUNGU',
#        'KYANGA', 'KIKANDWA', 'RWEGO', 'NAMYINGO', 'FORT-PORTAL',
#        'AMOLATAR', 'BULWENZU', 'BUTAMBALE', 'BIGIRI', 'SSEMBABULE',
#        'ALEBTONG', 'LWEGO', 'BUTEMBA', 'BUKEDEA', 'BUKOMASINDE', 'BULERA',
#        'BUNYAMBO', 'MUYENDE', 'NAKESONGOLA', 'KIBULI', 'ALUR', 'BUSUNJU',
#        'LUBIRIZI', 'SAMBABULE', 'SINGO', 'KAPCHRWA', 'KENYA', 'MUBARARA',
#        'KIGUMBA', 'SSEMBEBULE', 'MADDU', 'NAMATUMBA', 'BUSUJJU',
#        'NTUNGAM0', 'BUYONDE', 'KAMPAL', 'B/A', 'BUTEMBALE', 'BUTALEJA',
#        'RWANDA', 'PAKWACH', 'KAYAKKA', 'SOUTH SUDAN', 'KABARORE',
#        'KAMABOGA', 'NAKASENGOLA', 'KYERWA', 'BUTANBALA', 'OTUKE',
#        'FORT-PARTAL', 'SEMBALE', 'ZOKO', 'NKYANKWANZI', 'KYAKWALI',
#        'GAMBA', 'KALUNGI', 'KATORO', 'KIRANDONGO', 'PACKWACH', 'BIUKWE',
#        'KIBIITO', 'SEYA', 'MUTUKULA', 'KYANKWANGI', 'LYATONDE',
#        'NTUNGAMOA', 'BUKOMERO', 'LUKIRIRI', 'KABEREMAIDO', 'KABARAMAIDO',
#        'KYAMPISI', 'NAMAYUMBA', 'SEM[BABULE', 'KAKIRI', 'AMUDATI',
#        'MIYANA', 'WAMWANYA', 'KABALORE', 'KYALWASI', 'KAYUUNGA',
#        'KAYONZA', 'AMUDAT', 'RUCHURU', 'KAMWANGYE', 'MPIG', 'KOOME',
#        'KIRYADONGO', 'LUWERA', 'MULAGO', 'BWEYOGERERE', 'KAMWKYA',
#        'BULEEBI', 'MUTUNGO', 'KIREKA', 'NAMUGONGO', 'NSAMBYA', 'WAKIS',
#        'RUBANDA', 'SOROT', 'KAGACH', 'KIBORO', 'WOBULENZI', 'AMOLATER',
#        'KWEN', 'COU', 'KANKILARE', 'BUHEZU', 'BUKOMANSIS', 'KIRUHURU',
#        'BUHWEJJU', 'KYANKWAZI', 'KABULASOKE', 'WABULENZI', 'KIGADI',
#        'LYONTONDE', 'AMOLATOR', 'MOMBASA', 'RUKIGA', 'KIBOOGA', 'MIYYANA',
#        'KYIBONGA', 'BUSIIRO', 'MUNKONO', 'KIRYANDONGA', 'KIYADONDO',
#        'KYEGAGWA', 'KANUNGO', 'BUNDUBUGYO', 'BUTEEGA', 'BUTALENGU',
#        'KYANKWAGI', 'NWOOYA', 'KAGALI', 'BUHWENJU', 'BUTEBO', 'KABONG',
#        'KASSANDA', 'BANYANGABO', 'BUGWERI', 'KABERAMIADO', 'NWOYA',
#        'MUNYORO', 'WAKISA', 'NAMATUBA', 'BULISO', 'BUGERI', 'LWERO',
#        'NALUKOLONGO', 'OMORO', 'RUBAGA', 'KWANIA', 'AMOLATA', 'MARACHA',
#        'KYOTEGA', 'MUHOTI', 'IGANAGA', 'AMOLARTAR', 'BURUNDI', 'LYANTODE',
#        'NUKONO', 'LUEWERO', 'NAMBAYIMBA', 'KAMPLA', 'BULLISA', 'APAL',
#        'NAPAK'], dtype=object)

# %%
data.sample(3)
# Out:
#       UNIT IP NUMBER SEX  AGE  RELIGION DISTRICT OF RESIDENCE  \
# 19305   GI     61798   M   32       COU                WAKISO
# 6775    GI   2059158   F   24  CATHOLIC               KAMPALA
# 31873  IDM    360003   M   37       COU                LUWERO
#
#       DATE OF ADMISSION DATE OF DISCHARGE WORKING DIAGNOSIS  OUT COME  \
# 19305        2015-02-17        2015-02-24          UGIB,IDA  IMPROVED
# 6775         2012-07-05        2012-07-29            GE,ISS  IMPROVED
# 31873        2018-06-09        2018-06-12       HIV,CCM,CKD      DIED
#
#        DAYS OF STAY  NUMBER OF PREVIOUS ADMISSIONS MARITAL STATUS  \
# 19305           7.0                            0.0              2
# 6775           24.0                           24.0              1
# 31873           3.0                            1.0              2
#
#       MONTH OF ADMISSION DAY OF ADMISSION  YEAR OF ADMISSION  \
# 19305           February          Tuesday             2015.0
# 6775                July         Thursday             2012.0
# 31873               June         Saturday             2018.0
#
#        YEAR OF DISCHARGE  DURATION   REGION
# 19305             2015.0       8.0  CENTRAL
# 6775              2012.0      25.0  CENTRAL
# 31873             2018.0       4.0  CENTRAL

# %% [markdown]
# ##Replicate those who died

# %%
data['OUT COME'].unique()
# Out:
# array(['IMPROVED', 'UNIMPROVED', 'DIED', 'RANAWAY', 'RUNAWAY', 'CURED',
#        'TRANSFER 6B', 'RUN AWAY', '`RANAWAY', 'IMPROBED', 'IMPPROVED',
#        'IMPROVE'], dtype=object)

# %%
# # Number of replications for "died" outcomes
# num_replications = 4

# # Identify rows with "died" outcome
# died_rows = data[data['OUT COME'] == 'DIED']

# # Replicate the rows
# replicated_data = pd.concat([data, died_rows] * (num_replications - 1), ignore_index=True)

# # Append replicated data to the original data
# rep_data = pd.concat([data, replicated_data], ignore_index=True)

# %%
# rep_data.shape
data.shape
# Out:
# (35485, 19)

# %%
# rep_data['Survival_Week 1'].value_counts()
# Out:
# 0    129097
# 1     34517
# Name: Survival_Week 1, dtype: int64

# %%
# rep_data['Survival_Week 2'].value_counts()
# Out:
# 0    118275
# 1     45339
# Name: Survival_Week 2, dtype: int64

# %%
# rep_data['Survival_Week 3'].value_counts()
# Out:
# 0    114992
# 1     48622
# Name: Survival_Week 3, dtype: int64

# %%
# rep_data['Survival_Week 4'].value_counts()
# Out:
# 0    113977
# 1     49637
# Name: Survival_Week 4, dtype: int64

# %% [markdown]
# ##**Rearranging data**

# %%
#Deleting features that are not needed
col_to_drop = ['DATE OF ADMISSION', 'DATE OF DISCHARGE', 'DAYS OF STAY','YEAR OF DISCHARGE', 'YEAR OF DISCHARGE']
data = data.drop(columns=col_to_drop)

data.head()
# Out:
#   UNIT IP NUMBER SEX  AGE  RELIGION DISTRICT OF RESIDENCE  \
# 2   GI   1861453   M   80     ISLAM               kampala
# 3   GI   1861416   M   30       COU           Nakasongola
# 4   GI   1861726   F   40  CATHOLIC                 Busia
# 5   GI   1861601   M   30  CATHOLIC               kampala
# 6   GI   1861688   F   45    OTHERS              Kiruhura
#
#             WORKING DIAGNOSIS  OUT COME  NUMBER OF PREVIOUS ADMISSIONS  \
# 2  oesophagitis,B/pneumonia,,  IMPROVED                            3.0
# 3          ISS,Abdominal TB,,  IMPROVED                            5.0
# 4               HIV +ve,PID,,  IMPROVED                            1.0
# 5           upper GI,HIV+ve,,  IMPROVED                            2.0
# 6            Enteric fever,,,  IMPROVED                            1.0
#
#   MARITAL STATUS MONTH OF ADMISSION DAY OF ADMISSION  YEAR OF ADMISSION  \
# 2              2           November          Tuesday             2010.0
# 3              2           November          Tuesday             2010.0
# 4              9           December           Friday             2010.0
# 5              2           December         Thursday             2010.0
# 6              4           December         Thursday             2010.0
#
#    DURATION    REGION
# 2       4.0   kampala
# 3       6.0   CENTRAL
# 4       2.0     Busia
# 5       3.0   kampala
# 6       2.0  Kiruhura

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35485 entries, 2 to 35952
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   UNIT                           35485 non-null  object
#  1   IP NUMBER                      35462 non-null  object
#  2   SEX                            35481 non-null  object
#  3   AGE                            35485 non-null  int64
#  4   RELIGION                       35485 non-null  object
#  5   DISTRICT OF RESIDENCE          35485 non-null  object
#  6   WORKING DIAGNOSIS              35485 non-null  object
#  7   OUT COME                       35485 non-null  object
#  8   NUMBER OF PREVIOUS ADMISSIONS  35476 non-null  float64
#  9   MARITAL STATUS                 35478 non-null  object
#  10  MONTH OF ADMISSION             35485 non-null  object
#  11  DAY OF ADMISSION               35485 non-null  object
#  12  YEAR OF ADMISSION              35485 non-null  float64
#  13  DURATION                       35485 non-null  float64
#  14  REGION                         35485 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 4.3+ MB

# %%
#Reseting the index of the new cleaned data
data.reset_index(drop=True)
# Out:
#       UNIT IP NUMBER SEX  AGE     RELIGION DISTRICT OF RESIDENCE  \
# 0       GI   1861453   M   80        ISLAM               kampala
# 1       GI   1861416   M   30          COU           Nakasongola
# 2       GI   1861726   F   40     CATHOLIC                 Busia
# 3       GI   1861601   M   30     CATHOLIC               kampala
# 4       GI   1861688   F   45       OTHERS              Kiruhura
# ...    ...       ...  ..  ...          ...                   ...
# 35480   GI    470145   F   54     CATHOLIC                WAKISO
# 35481  IDF    470767   F   24  PENTECOSTAL               KAMPALA
# 35482   GI    470801   M   44  PENTECOSTAL                 MPIGI
# 35483  IDM    470749   M   32     CATHOLIC                WAKISO
# 35484  IDM    470139   M   82     CATHOLIC                WAKISO
#
#                     WORKING DIAGNOSIS  OUT COME  \
# 0          oesophagitis,B/pneumonia,,  IMPROVED
# 1                  ISS,Abdominal TB,,  IMPROVED
# 2                       HIV +ve,PID,,  IMPROVED
# 3                   upper GI,HIV+ve,,  IMPROVED
# 4                    Enteric fever,,,  IMPROVED
# ...                               ...       ...
# 35480  HIV,INTRA-ABDOMINAL MALIGNANCY  IMPROVED
# 35481           HIV,ANAEMIA,PNEUMONIA  IMPROVED
# 35482                   DYSPEPSIS,PUD  IMPROVED
# 35483            MALARIA,OTITIS MEDIA  IMPROVED
# 35484                              GE  IMPROVED
#
#        NUMBER OF PREVIOUS ADMISSIONS MARITAL STATUS MONTH OF ADMISSION  \
# 0                                3.0              2           November
# 1                                5.0              2           November
# 2                                1.0              9           December
# 3                                2.0              2           December
# 4                                1.0              4           December
# ...                              ...            ...                ...
# 35480                            0.0              2               July
# 35481                            0.0              3             August
# 35482                            2.0              2             August
# 35483                            0.0              2             August
# 35484                            0.0              9             August
#
#       DAY OF ADMISSION  YEAR OF ADMISSION  DURATION    REGION
# 0              Tuesday             2010.0       4.0   kampala
# 1              Tuesday             2010.0       6.0   CENTRAL
# 2               Friday             2010.0       2.0     Busia
# 3             Thursday             2010.0       3.0   kampala
# 4             Thursday             2010.0       2.0  Kiruhura
# ...                ...                ...       ...       ...
# 35480           Monday             2019.0      24.0   CENTRAL
# 35481          Tuesday             2019.0       4.0   CENTRAL
# 35482        Wednesday             2019.0       4.0   CENTRAL
# 35483           Monday             2019.0       5.0   CENTRAL
# 35484           Monday             2019.0       4.0   CENTRAL
#
# [35485 rows x 15 columns]

# %% [markdown]
# ##Cleaning IP NUMBER

# %%
print(data['IP NUMBER'].isna().sum())
# Out:
# 23

# %%
#Identifying the duplicate IP NUMBER
duplicate_val = data[data['IP NUMBER'].duplicated(keep=False)]['IP NUMBER']
print(duplicate_val)

#Removing samples with non-numerical IP NUMBER
data = data[data['IP NUMBER']  != 'a' ]
data = data[data['IP NUMBER']  != 'vf' ]
# Out:
# 60       1838011
# 63       1868072
# 66       1868750
# 107      1869731
# 132      1869731
#           ...
# 35905     468117
# 35924     419221
# 35929     470378
# 35939     469932
# 35943     469818
# Name: IP NUMBER, Length: 4585, dtype: object

# %%
#Deleting Samples of the duplicate IP NUMBER to retain one
data= data.drop_duplicates(subset='IP NUMBER')

# %%
duplicate_val1 = data[data['IP NUMBER'].duplicated(keep=False)]['IP NUMBER']
print(duplicate_val1)
# Out:
# Series([], Name: IP NUMBER, dtype: object)

# %% [markdown]
# ##SEX cleaning

# %%
data['NUMBER OF PREVIOUS ADMISSIONS'].unique()
# Out:
# array([ 3.,  5.,  1.,  2.,  4.,  9.,  6., 11.,  7.,  8., 10., 16., 13.,
#        17., 20., 12., 31., 34., 14., 23., 22., 21., 48., 42., 18., 15.,
#        25., 19.,  0., 24., 62., 27., 39., 29., 44., 40., 32., 26., 28.,
#        30., 37., 33., 36., 41., 96., 55., 45., 50., 35., 52., 49., nan,
#        92., 38., 46.])

# %%
print(data['NUMBER OF PREVIOUS ADMISSIONS'].isna().sum())
# Out:
# 0

# %%
data.dropna(subset='NUMBER OF PREVIOUS ADMISSIONS', inplace=True)
data.dropna(subset='SEX', inplace=True)
data['SEX'] = data['SEX'].replace({'f':'F'})
data['SEX'].unique()

# %%
print(data['SEX'].isna().sum())
# Out:
# 0

# %% [markdown]
# ##Cleaning TB

# %%
#Selecting the types of TB
data['TB'] = data['WORKING DIAGNOSIS'].astype(str).apply(lambda x: ','.join([Val for Val in x.split(',') if 'TB' in Val]))

# %%
#Selecting all other working diagnosis except TB
data['ADDITIONAL WORKING DIAGNOSIS'] = data['WORKING DIAGNOSIS'].astype(str).apply(lambda x: ','.join([Val for Val in x.split(',') if 'TB' not in Val]))

# %%
data['TB'].unique()
# Out:
# array(['', 'Abdominal TB', 'Disseminated TB', 'INTESTINAL TB', 'Abd TB',
#        'PTB', 'MILIARY PTB', 'POSSIBLE PTB', 'ABDOMINAL TB', 'ABD TB',
#        'TB ABDOMEN', 'TB', 'INTRA ABD TB', 'DISSEMINATED TB',
#        'ABDOMEN TB', 'ABDOMINAL TB,PTB', 'TB MENINGITIS', 'EPTB',
#        'EXTRA PULMONARY TB', 'DISSEMINATED TB,ABD TB', 'TB ADERITIS',
#        'TBM', 'ADB TB', 'PTB,ABD TB', 'PTB,RENAL TB', 'INTRA-ABD TB',
#        'TB ADENITIS', 'TB ADERRITIS', 'TB  ADENITIS', 'PTB,TBM',
#        'TB PERICARDITIS,PTB', 'TBADERITIS', 'ABD TB,PTB', 'TB,PTB',
#        'TB ADHERITIS', 'TB IRIS', 'ABDOMIMAL TB', 'DTB', 'DISEMINATED TB',
#        'TB LYMPHAOENITIS', 'DISSEMINATED TB,ABD.TB',
#        'DISSEMINATED TB,TBM', 'TB.IRIS', 'DISSEMINATED TB,ABDOMINAL TB',
#        'TB.ADENITIS', 'ABD.TB', 'ISS WITH BRONCHPNEUMONIA R/O PTB',
#        'PTB,ABDOMINAL TB', 'TB.ABDOMEN', 'ADB.TB', 'PTB ', 'ABD.TB.ISS',
#        'TB SPINE', 'PLEURAL TB', 'ABDOMNAL TB', 'TBM,DISSEMINATED TB',
#        'MILIARY TB', 'MILIARY TB,TBM', 'DISSEMINATE TB',
#        'PTB,EPTB ABDOMEN', 'TB PENCARDITIS', 'TB DISSEMINATED', 'MTB',
#        'TBA', 'DTB,ABD TB', 'PTB,DTB', 'DTB,TBM', 'TBM,TB',
#        'DISSEMINATED TB,TB PERITONITIS', 'DISSEM TB', 'TB ABDOMINAL',
#        'TB LYMPHADEMITITIS', 'TB ADRENOLITIS', 'ABDOMINAL TB,TB',
#        'DISSMINATED TB', 'MILLARY TB', 'ABDO.TB', 'TB IRISH', 'TB-IRIS',
#        'DISSEMINATEEED TB', 'DISSEMINATED TB, TBM', 'DISSEMINATED TB,PTB',
#        'IRIS TB', 'MILLIARY TB', 'PULMONARY TB', 'PTB,DISSEMINTED TB',
#        'TBM,PTB', 'DISSEMINTED TB', 'TB ORCHITIS', 'DISSEMINATED  TB',
#        ' PTB', 'TB ADENTIS', 'TB PERICARDITIS', 'TB ADHERENCE',
#        'TB LYMPHADENITIS', 'TB ADENITIS,TBM', 'MTB,PTB', 'TB M',
#        'SPINAL TB', 'DISEEMINATED TB', 'PTB.PSYCHOSIS',
#        'INTRA-ABDOMINAL TB', 'PTB,KIDNEY TB', 'TB SPINAL CORD,TBM',
#        'PTB,DISSEMINATED TB', 'TB IRIS,TBM', 'PTB,DISS.TB',
#        'TB,DISSEMINATED TB', 'DISS TB', 'TB,TBM', 'TB PERITONITIS',
#        'TB ULCER', 'DISSEIMINATED TB', 'ABD.TB,PTB', 'ABDOMINAL TBM',
#        'TB ADENITIS,DISSEMINATED TB', 'PTB,ABD.TB',
#        'ABDOMINAL TB,ORAL TB', 'TB ADENITIS,ABD.TB', 'TBM,TB SPINE',
#        'TBM,PTB,DISSEMINATED TB', 'DISSEMINATED TB,PTB,TBM',
#        'TB PERICARDIOSIS'], dtype=object)

# %%
data['TB_type'] = data['TB']

# %%
#Grouping the TB types into Abdominal_TB, Disseminated TB,CNS_TB,Other TBs, PTB, IRIS TB
tb_types = {'Abdominal TB':'Abdominal_TB', 'INTESTINAL TB':'Abdominal_TB', 'Abd TB':'Abdominal_TB',
            'MILIARY PTB':'Disseminated TB', 'POSSIBLE PTB':'PTB', 'ABDOMINAL TB':'Abdominal_TB',
            'TB':'Other TBs', 'INTRA ABD TB':'Abdominal_TB', 'DISSEMINATED TB':'Disseminated TB',
            'ABDOMAL TB':'Abdominal_TB', 'TB MENINGITIS':'Other TBs', 'ADB TB':'Abdominal_TB',
            'EPTB':'Disseminated TB', 'EXTRA PULMONARY TB':'Disseminated TB',
            'INTRA-ABD TB':'Abdominal_TB', 'ABD TB':'Abdominal_TB', 'TB ABDOMEN':'Abdominal_TB',
            'TB ADENITIS':'Other TBs', 'TB ADERRITIS':'Other TBs', 'TB  ADENITIS':'Other TBs',
            'TBADERITIS':'Other TBs','TB ADHERITIS':'Other TBs', 'TB IRIS':'TB iris',
            'ABDOMIMAL TB':'Abdominal_TB', 'DTB':'Disseminated TB', 'DISEMINATED TB':'Disseminated TB',
            'ISSEMINATED TB,TBM':'Disseminated TB', 'ABDOMEN TB':'Abdominal_TB',
            'TB.IRIS':'TB iris', 'TB.ADENITIS':'Other TBs', 'ABD.TB':'Abdominal_TB',
            'ISS WITH BRONCHPNEUMONIA R/O PTB':'Disseminated TB', 'TB.ABDOMEN':'Abdominal_TB',
            'PTB ':'PTB', 'ABD.TB.ISS':'Disseminated TB', 'TB SPINE':'CNS_TB',
            'PLEURAL TB':'PTB', 'ABDOMNAL TB':'Abdominal_TB', 'ADB.TB':'Abdominal_TB',
            'MILIARY TB':'Disseminated TB','DISSEMINATE TB':'Disseminated TB', 'TBM':'CNS_TB',
            'TB PENCARDITIS':'Other TBs', 'TB DISSEMINATED':'Disseminated TB',
            'MTB':'CNS_TB', 'TBA':'Abdominal_TB', 'TB LYMPHAOENITIS':'Disseminated TB',
            'DISSEM TB':'Disseminated TB', 'TB ABDOMINAL':'Abdominal_TB', 'TB LYMPHADEMITITIS':'Other TBs',
            'TB ADRENOLITIS':'Other TBs','DISSMINATED TB':'Disseminated TB', 'TB ADERITIS':'Other TBs',
            'MILLARY TB':'Disseminated TB', 'ABDO.TB':'Abdominal_TB', 'TB IRISH':'TB iris', 'TB-IRIS':'TB iris',
            'DISSEMINATEEED TB':'Disseminated TB','IRIS TB':'TB iris', 'MILLIARY TB':'Disseminated TB',
            'PULMONARY TB':'PTB', 'DISSEMINTED TB':'Disseminated TB', 'TB ORCHITIS':'Other TBs',
            ' PTB':'PTB', 'TB ADENTIS':'Other TBs', 'TB PERICARDITIS':'Other TBs', 'TB LYMPHADENITIS':'Other TBs',
            'TB M':'CNS_TB', 'SPINAL TB':'CNS_TB', 'DISEEMINATED TB':'Disseminated TB',
            'PTB.PSYCHOSIS':'Other TBs', 'INTRA-ABDOMINAL TB':'Abdominal_TB', 'DISS TB':'Disseminated TB',
            'TB PERITONITIS':'Abdominal_TB', 'TB ULCER':'Other TBs', 'TB LYMPHODENITIS':'Other TBs',
            'DISSEIMINATED TB':'Disseminated TB', 'ABDOMINAL TBM':'Disseminated TB',
            'TB PERICARDIOSIS':'Disseminated TB', 'DISSEMINATED  TB':'Disseminated TB',
            'TB ADENITIS,DISSEMINATED TB':'Disseminated TB', 'PTB,ABD.TB':'Disseminated TB', 'TB,PTB':'PTB',
            'ABDOMINAL TB,ORAL TB':'Abdominal_TB', 'TB ADENITIS,ABD.TB':'Disseminated TB', 'TBM,TB SPINE':'CNS_TB',
            'TBM,PTB,DISSEMINATED TB':'Disseminated TB', 'DISSEMINATED TB,PTB,TBM':'Disseminated TB',
            'ABD.TB,PTB':'Disseminated TB', 'TB,DISSEMINATED TB':'Disseminated TB', 'PTB,KIDNEY TB':'Disseminated TB',
            'TB SPINAL CORD,TBM':'CNS_TB', 'TB IRIS,TBM':'Disseminated TB', 'PTB,DISS.TB':'Disseminated TB',
            'TB,TBM':'Disseminated TB', 'PTB,DISSEMINTED TB':'Disseminated TB', 'TBM,PTB':'Disseminated TB',
            'DISSEMINATED TB,PTB':'Disseminated TB',  'MILIARY TB,TBM':'Disseminated TB',
            'ABDOMINAL TB,TB':'Abdominal_TB', 'MTB,PTB':'Disseminated TB','PTB,EPTB ABDOMEN':'Disseminated TB',
            'ABD TB,PTB':'Disseminated TB', 'DISSEMINATED TB,ABDOMINAL TB':'Disseminated TB',
            'PTB,DTB':'Disseminated TB','PTB,ABD TB':'Disseminated TB', 'PTB,RENAL TB':'PTB',
            'TB PERICARDITIS,PTB':'Disseminated TB', 'TBM,TB':'CNS_TB', 'PTB,TBM':'PTB',
            'PTB,ABDOMINAL TB':'Disseminated TB', 'DISSEMINATED TB, TBM':'Disseminated TB', 'DTB,ABD TB':'Disseminated TB',
            'DTB,TBM':'Disseminated TB', 'DISSEMINATED TB,TB PERITONITIS':'Disseminated TB',
            'PTB,DISSEMINATED TB':'Disseminated TB', 'TBM,DISSEMINATED TB':'Disseminated TB',
            'DISSEMINATED TB,ABD TB':'Disseminated TB', 'ABDOMINAL TB,PTB':'Abdominal_TB',
            'DISSEMINATED TB,ABD.TB':'Disseminated TB', 'DISSEMINATED TB,TBM':'Disseminated TB',
            'TB ADENITIS,TBM':'Other TBs', 'TB ADHERENCE':'Other TBs','RESPIRATORY TB':'Other TBs',
            'CNS_TB':'Other TBs', 'TB MENINGITIS,DISSEMINATED TB':'Disseminated TB',
            'TB PERICANDITIS':'Other TBs', 'DISSEMINATED TB,TB':'Disseminated TB', 'PTB,TB IRIS':'Other TBs',
            'TB ASCITES':'Other TBs', 'ABD  TB':'Other TBs', '.TBM':'CNS_TB'
}
data['TB_type'] = data['TB_type'].replace(tb_types)

col = data.pop('TB_type')
data.insert(9, col.name, col)
data = data[data['TB_type'] !='']
data = data.drop(columns='TB')

# %%
data['TB_type'].unique()
# Out:
# array(['Abdominal_TB', 'Disseminated TB', 'PTB', 'Other TBs', 'CNS_TB',
#        'TB iris'], dtype=object)

# %%
data.sample(10)
# Out:
#       UNIT IP NUMBER SEX  AGE     RELIGION DISTRICT OF RESIDENCE  \
# 3224   IDM   1985643   M   36       OTHERS                WAKISO
# 33104  IDF    419548   F   21  PENTECOSTAL               KAMPALA
# 6772   IDM   2060084   M   28     CATHOLIC                MASAKA
# 3838    GI  19999942   M   32          COU               KAMPALA
# 24796  IDF    201280   F   20          COU               KAMPALA
# 1373   IDM   1945799   M   37     CATHOLIC                WAKISO
# 8813   IDM   2102590   M   32     CATHOLIC               KAMPALA
# 14949  IDM   2255511   M   38          COU               KAMPALA
# 28164  IDF    281281   F   35     CATHOLIC                WAKISO
# 10805  IDM   2154536   M   36     CATHOLIC               KAMPALA
#
#                                WORKING DIAGNOSIS  OUT COME  \
# 3224                           PTB,PSYCHOSIS,ISS  IMPROVED
# 33104                                    HIV,TBM  IMPROVED
# 6772                                      TB,ISS  IMPROVED
# 3838   DISSEMINATED TB,ALCOHOLIC LIVER CIRRHOSIS      DIED
# 24796                      TB IRIS,LYMPHADENITIS  IMPROVED
# 1373                                  ABD TB,ISS  IMPROVED
# 8813                                     PTB,ISS  IMPROVED
# 14949                                    HIV,PTB  IMPROVED
# 28164   HIV,ORAL CANDIDIASIS,DISSEMINATED TB,PTB  IMPROVED
# 10805                         PTB,ANAEMIA,GE,HIV      DIED
#
#        NUMBER OF PREVIOUS ADMISSIONS          TB_type MARITAL STATUS  \
# 3224                             1.0              PTB              2
# 33104                            0.0           CNS_TB              1
# 6772                            13.0        Other TBs              9
# 3838                             5.0  Disseminated TB              9
# 24796                            0.0          TB iris              9
# 1373                             9.0     Abdominal_TB              9
# 8813                             0.0              PTB              2
# 14949                            0.0              PTB              9
# 28164                            0.0  Disseminated TB              9
# 10805                            0.0              PTB              9
#
#       MONTH OF ADMISSION DAY OF ADMISSION  YEAR OF ADMISSION  DURATION  \
# 3224            December           Monday             2011.0       2.0
# 33104            October        Wednesday             2018.0       9.0
# 6772                July         Saturday             2012.0      14.0
# 3838             January         Saturday             2012.0       6.0
# 24796              April         Thursday             2016.0      16.0
# 1373              August        Wednesday             2011.0       9.0
# 8813            December          Tuesday             2012.0       3.0
# 14949              March          Tuesday             2014.0      10.0
# 28164                May           Monday             2017.0      11.0
# 10805                May           Friday             2013.0       2.0
#
#         REGION ADDITIONAL WORKING DIAGNOSIS
# 3224   CENTRAL                PSYCHOSIS,ISS
# 33104  CENTRAL                          HIV
# 6772   CENTRAL                          ISS
# 3838   CENTRAL    ALCOHOLIC LIVER CIRRHOSIS
# 24796  CENTRAL                LYMPHADENITIS
# 1373   CENTRAL                          ISS
# 8813   CENTRAL                          ISS
# 14949  CENTRAL                          HIV
# 28164  CENTRAL         HIV,ORAL CANDIDIASIS
# 10805  CENTRAL               ANAEMIA,GE,HIV

# %% [markdown]
# ##Filtering

# %%
data['WORKING DIAGNOSIS'].unique()
# Out:
# array(['ISS,Abdominal TB,,', 'ISS Stage I&II,Disseminated TB,,',
#        'myeloproliferat,Malaria,INTESTINAL TB,', ...,
#        'HIV,ABDOMINAL TB,PUD', 'HIV,TB,DYSPHAGIA',
#        'HIV,DISSEMINATED TB,CKD'], dtype=object)

# %%
data.shape
# Out:
# (4092, 17)

# %%
#filtering to get samples with all kinds of TB as the working diagnosis
df_TBw = data[data['WORKING DIAGNOSIS'].str.contains('TB', na=False)]
df_TBw.shape
# Out:
# (4092, 17)

# %%
df_TBw.head()
# Out:
#     UNIT IP NUMBER SEX  AGE  RELIGION DISTRICT OF RESIDENCE  \
# 3     GI   1861416   M   30       COU           Nakasongola
# 31    GI   1868011   F   46       COU               Kampala
# 73    GI   1868840   M   80     ISLAM                Wakiso
# 95    GI   1851080   M   22  CATHOLIC               KAMPALA
# 150   GI   1870478   F   18       COU               KAMPALA
#
#                           WORKING DIAGNOSIS  OUT COME  \
# 3                        ISS,Abdominal TB,,  IMPROVED
# 31         ISS Stage I&II,Disseminated TB,,  IMPROVED
# 73   myeloproliferat,Malaria,INTESTINAL TB,  IMPROVED
# 95                                Abd TB,,,  IMPROVED
# 150                                  PTB,,,  IMPROVED
#
#      NUMBER OF PREVIOUS ADMISSIONS          TB_type MARITAL STATUS  \
# 3                              5.0     Abdominal_TB              2
# 31                             3.0  Disseminated TB              2
# 73                             7.0     Abdominal_TB              4
# 95                             8.0     Abdominal_TB              9
# 150                            4.0              PTB              1
#
#     MONTH OF ADMISSION DAY OF ADMISSION  YEAR OF ADMISSION  DURATION   REGION  \
# 3             November          Tuesday             2010.0       6.0  CENTRAL
# 31            December           Monday             2010.0       4.0  CENTRAL
# 73            December        Wednesday             2010.0       8.0  CENTRAL
# 95            December           Monday             2010.0       9.0  CENTRAL
# 150            January         Thursday             2011.0       5.0  CENTRAL
#
#     ADDITIONAL WORKING DIAGNOSIS
# 3                          ISS,,
# 31              ISS Stage I&II,,
# 73      myeloproliferat,Malaria,
# 95                            ,,
# 150                           ,,

# %% [markdown]
# ##Addittional  working diagnosis

# %%
#function to compute the number of other diagnosis in a sample other than any kind of TB
def count_extra_elements(cell):
  elements = [element.strip() for element in cell.split(',') if element.strip()!='']
  return len(elements)

#Computing the additional working diagnosis and creating a row for it
df_TBw['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'] = df_TBw['ADDITIONAL WORKING DIAGNOSIS'].apply(count_extra_elements)

#Removing samples with missing values
df_TBw.dropna(subset=['NUMBER OF PREVIOUS ADMISSIONS'], inplace=True)
df_TBw.head()
# Out:
#     UNIT IP NUMBER SEX  AGE  RELIGION DISTRICT OF RESIDENCE  \
# 3     GI   1861416   M   30       COU           Nakasongola
# 31    GI   1868011   F   46       COU               Kampala
# 73    GI   1868840   M   80     ISLAM                Wakiso
# 95    GI   1851080   M   22  CATHOLIC               KAMPALA
# 150   GI   1870478   F   18       COU               KAMPALA
#
#                           WORKING DIAGNOSIS  OUT COME  \
# 3                        ISS,Abdominal TB,,  IMPROVED
# 31         ISS Stage I&II,Disseminated TB,,  IMPROVED
# 73   myeloproliferat,Malaria,INTESTINAL TB,  IMPROVED
# 95                                Abd TB,,,  IMPROVED
# 150                                  PTB,,,  IMPROVED
#
#      NUMBER OF PREVIOUS ADMISSIONS          TB_type MARITAL STATUS  \
# 3                              5.0     Abdominal_TB              2
# 31                             3.0  Disseminated TB              2
# 73                             7.0     Abdominal_TB              4
# 95                             8.0     Abdominal_TB              9
# 150                            4.0              PTB              1
#
#     MONTH OF ADMISSION DAY OF ADMISSION  YEAR OF ADMISSION  DURATION   REGION  \
# 3             November          Tuesday             2010.0       6.0  CENTRAL
# 31            December           Monday             2010.0       4.0  CENTRAL
# 73            December        Wednesday             2010.0       8.0  CENTRAL
# 95            December           Monday             2010.0       9.0  CENTRAL
# 150            January         Thursday             2011.0       5.0  CENTRAL
#
#     ADDITIONAL WORKING DIAGNOSIS  NUMBER OF ADDITIONAL WORKING DIAGNOSIS
# 3                          ISS,,                                       1
# 31              ISS Stage I&II,,                                       1
# 73      myeloproliferat,Malaria,                                       2
# 95                            ,,                                       0
# 150                           ,,                                       0

# %%
# Convert specified columns to integers
df_TBw['YEAR OF ADMISSION'] = df_TBw['YEAR OF ADMISSION'].astype(int)
df_TBw['DURATION'] = df_TBw['DURATION'].astype(int)
df_TBw['NUMBER OF PREVIOUS ADMISSIONS'] = df_TBw['NUMBER OF PREVIOUS ADMISSIONS'].astype(int)

# %%
df_TBw.head()
# Out:
#     UNIT IP NUMBER SEX  AGE  RELIGION DISTRICT OF RESIDENCE  \
# 3     GI   1861416   M   30       COU           Nakasongola
# 31    GI   1868011   F   46       COU               Kampala
# 73    GI   1868840   M   80     ISLAM                Wakiso
# 95    GI   1851080   M   22  CATHOLIC               KAMPALA
# 150   GI   1870478   F   18       COU               KAMPALA
#
#                           WORKING DIAGNOSIS  OUT COME  \
# 3                        ISS,Abdominal TB,,  IMPROVED
# 31         ISS Stage I&II,Disseminated TB,,  IMPROVED
# 73   myeloproliferat,Malaria,INTESTINAL TB,  IMPROVED
# 95                                Abd TB,,,  IMPROVED
# 150                                  PTB,,,  IMPROVED
#
#      NUMBER OF PREVIOUS ADMISSIONS          TB_type MARITAL STATUS  \
# 3                                5     Abdominal_TB              2
# 31                               3  Disseminated TB              2
# 73                               7     Abdominal_TB              4
# 95                               8     Abdominal_TB              9
# 150                              4              PTB              1
#
#     MONTH OF ADMISSION DAY OF ADMISSION  YEAR OF ADMISSION  DURATION   REGION  \
# 3             November          Tuesday               2010         6  CENTRAL
# 31            December           Monday               2010         4  CENTRAL
# 73            December        Wednesday               2010         8  CENTRAL
# 95            December           Monday               2010         9  CENTRAL
# 150            January         Thursday               2011         5  CENTRAL
#
#     ADDITIONAL WORKING DIAGNOSIS  NUMBER OF ADDITIONAL WORKING DIAGNOSIS
# 3                          ISS,,                                       1
# 31              ISS Stage I&II,,                                       1
# 73      myeloproliferat,Malaria,                                       2
# 95                            ,,                                       0
# 150                           ,,                                       0

# %% [markdown]
# ##Arranging columns

# %%
col = ['IP NUMBER','UNIT',	'SEX','AGE','MARITAL STATUS',	'RELIGION',	'DISTRICT OF RESIDENCE', 'REGION',	'WORKING DIAGNOSIS',
       'ADDITIONAL WORKING DIAGNOSIS',	'NUMBER OF ADDITIONAL WORKING DIAGNOSIS', 'TB_type',
       'NUMBER OF PREVIOUS ADMISSIONS', 'DAY OF ADMISSION',	'MONTH OF ADMISSION',	'YEAR OF ADMISSION',	'DURATION', 'OUT COME']
df1_TB= df_TBw[col]

# %%
df1_TB.head()
# Out:
#     IP NUMBER UNIT SEX  AGE MARITAL STATUS  RELIGION DISTRICT OF RESIDENCE  \
# 3     1861416   GI   M   30              2       COU           Nakasongola
# 31    1868011   GI   F   46              2       COU               Kampala
# 73    1868840   GI   M   80              4     ISLAM                Wakiso
# 95    1851080   GI   M   22              9  CATHOLIC               KAMPALA
# 150   1870478   GI   F   18              1       COU               KAMPALA
#
#       REGION                       WORKING DIAGNOSIS  \
# 3    CENTRAL                      ISS,Abdominal TB,,
# 31   CENTRAL        ISS Stage I&II,Disseminated TB,,
# 73   CENTRAL  myeloproliferat,Malaria,INTESTINAL TB,
# 95   CENTRAL                               Abd TB,,,
# 150  CENTRAL                                  PTB,,,
#
#     ADDITIONAL WORKING DIAGNOSIS  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  \
# 3                          ISS,,                                       1
# 31              ISS Stage I&II,,                                       1
# 73      myeloproliferat,Malaria,                                       2
# 95                            ,,                                       0
# 150                           ,,                                       0
#
#              TB_type  NUMBER OF PREVIOUS ADMISSIONS DAY OF ADMISSION  \
# 3       Abdominal_TB                              5          Tuesday
# 31   Disseminated TB                              3           Monday
# 73      Abdominal_TB                              7        Wednesday
# 95      Abdominal_TB                              8           Monday
# 150              PTB                              4         Thursday
#
#     MONTH OF ADMISSION  YEAR OF ADMISSION  DURATION  OUT COME
# 3             November               2010         6  IMPROVED
# 31            December               2010         4  IMPROVED
# 73            December               2010         8  IMPROVED
# 95            December               2010         9  IMPROVED
# 150            January               2011         5  IMPROVED

# %% [markdown]
# ##Replicating rows

# %%
df_TBw['OUT COME'].value_counts()
# Out:
# OUT COME
# IMPROVED      2696
# DIED          1311
# UNIMPROVED      46
# RANAWAY         35
# CURED            1
# RUN AWAY         1
# RUNAWAY          1
# IMPPROVED        1
# Name: count, dtype: int64

# %%
df_TBw.shape
# Out:
# (4092, 18)

# %%
df_TBw.to_csv('TB_Analysis.csv', index=False)

# %%
# # Replicate each row 4 times
# replicated_df = df_TBw.loc[df_TBw.index.repeat(2)].reset_index(drop=True)

# %%
# replicated_df.shape
# Out:
# (43788, 22)

# %% [markdown]
# ##Saving file

# %%
replicated_df.to_excel('4A_TB_cleaned_classification.xlsx', index=False)

# %% [markdown]
# ##Visualization

# %%
import matplotlib.pyplot as plt

#counting the DIED outcomes
died_outcomes = df_TB[df_TB['OUT COME'] == 'DIED'].groupby('DURATION').size()
died_outcomes = died_outcomes.sort_index()

#counting the total outcomes
total_outcomes = df_TB.groupby('DURATION').size()

##computing the proportion of DIED proportion
proportion = died_outcomes / total_outcomes

#Plotting Number of "DIED" outcomes vs. DURATION
fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.bar(died_outcomes.index, died_outcomes.values, width=2, label='Number of "DIED" outcomes' )
ax1.set_xlabel('DURATION')
ax1.set_ylabel('Number of "DIED" outcomes', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.set_title('Bar Chart: Number of "DIED" outcomes vs. DURATION')

ax2 = ax1.twinx()

ax2.plot(died_outcomes.index, died_outcomes.values,color='tab:red', linestyle='-', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:red')

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-9ae3429475c7> in <cell line: 4>()
#       2
#       3 #counting the DIED outcomes
# ----> 4 died_outcomes = df_TB[df_TB['OUT COME'] == 'DIED'].groupby('DURATION').size()
#       5 died_outcomes = died_outcomes.sort_index()
#       6
#
# NameError: name 'df_TB' is not defined

# %%
#Plotting for Proportion of "DIED" Outcomes vs. Duration'
proportion = proportion.sort_index()

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.bar(proportion.index, proportion.values, width=2, label='Number of "DIED" outcomes' )
ax1.set_xlabel('DURATION')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()

ax2.plot(proportion.index, proportion.values,color='tab:red', marker='o')
ax2.set_ylabel('Proportion of "DIED" outcome')
ax2.set_title('Line Plot: Proportion of "DIED" Outcomes vs. Duration', color='tab:red')
ax1.tick_params(axis='y', labelcolor='tab:red')

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()
