# %% [markdown]
# <h1>Preparing Data</h1>

# %%
import pandas as pd

# %%
dataset = pd.read_excel('4A_TB_cleaned.xlsx')

# %%
dataset.head()
# Out:
#   UNIT IP NUMBER SEX  AGE RELIGION DISTRICT OF RESIDENCE  \
# 0   GI   1861416   M   30      COU           Nakasongola
# 1   GI   1861416   M   30      COU           Nakasongola
# 2   GI   1861416   M   30      COU           Nakasongola
# 3   GI   1861416   M   30      COU           Nakasongola
# 4   GI   1868011   F   46      COU               Kampala
#
#                   WORKING DIAGNOSIS  OUT COME  NUMBER OF PREVIOUS ADMISSIONS  \
# 0                ISS,Abdominal TB,,  IMPROVED                              5
# 1                ISS,Abdominal TB,,  IMPROVED                              5
# 2                ISS,Abdominal TB,,  IMPROVED                              5
# 3                ISS,Abdominal TB,,  IMPROVED                              5
# 4  ISS Stage I&II,Disseminated TB,,  IMPROVED                              3
#
#            TB_type MARITAL STATUS MONTH OF ADMISSION DAY OF ADMISSION  \
# 0     Abdominal_TB              2           November          Tuesday
# 1     Abdominal_TB              2           November          Tuesday
# 2     Abdominal_TB              2           November          Tuesday
# 3     Abdominal_TB              2           November          Tuesday
# 4  Disseminated TB              2           December           Monday
#
#    YEAR OF ADMISSION  DURATION   REGION ADDITIONAL WORKING DIAGNOSIS  \
# 0               2010         6  CENTRAL                        ISS,,
# 1               2010         6  CENTRAL                        ISS,,
# 2               2010         6  CENTRAL                        ISS,,
# 3               2010         6  CENTRAL                        ISS,,
# 4               2010         4  CENTRAL             ISS Stage I&II,,
#
#    NUMBER OF ADDITIONAL WORKING DIAGNOSIS
# 0                                       1
# 1                                       1
# 2                                       1
# 3                                       1
# 4                                       1

# %%
dataset = pd.concat([dataset] * 4, ignore_index=True)

# %%
dataset.shape
# Out:
# (65472, 18)

# %%
num_weeks = 4

# Converting duration to whole weeks (assuming 7 days per week)
dataset['Duration (weeks)'] = dataset['DURATION'].apply(lambda x: int(x // 7 + (x % 7 > 0)))

# function to identify the last week of appearance
def get_last_week(row):
  if row['OUT COME'] != 'DIED':
    return min(row['Duration (weeks)'], num_weeks)
  else:
    return 0

dataset['Last Week'] = dataset.apply(get_last_week, axis=1)

# %%
for week in range(1, num_weeks + 1):
  # Checking for non-deaths and appearance within the week
  mask = (dataset['OUT COME'] != 'DIED') & (dataset['Last Week'] >= week)
  dataset.loc[mask, f'Week_{week}'] = 0
  
    
  #Checking for deaths within the week and below
  dead_mask = (dataset['OUT COME'] == 'DIED') & ((dataset['DURATION'] / 7) <= week)
  dataset.loc[dead_mask, f'Week_{week}'] = 1 

  dead_later_mask = (dataset['OUT COME'] == 'DIED') & ((dataset['DURATION'] / 7) > week)
  dataset.loc[dead_later_mask, f'Week_{week}'] = 0   

dataset.drop('Last Week', axis=1, inplace=True)

# %%
dataset.sample(10)
# Out:
#       UNIT IP NUMBER SEX  AGE     RELIGION DISTRICT OF RESIDENCE  \
# 37635  IDF   2180881   F   32  PENTECOSTAL               KAMPALA
# 46211  IDM    361802   M   39  PENTECOSTAL               KAMPALA
# 45641  IDM    340996   M   31     CATHOLIC               KAMPALA
# 60816  IDM    279792   M   26     CATHOLIC               KAMPALA
# 48351  IDF    457934   F   56          COU            KYANKWANZI
# 12548  IDF    308925   F   44  PENTECOSTAL                WAKISO
# 11497  IDM    260615   M   17          COU               KAMPALA
# 21405  IDF   2187387   F   13       OTHERS               KAMPALA
# 60013  IDM    232570   M   33          COU               KAMPALA
# 30257  IDF    381894   F   55          COU               KAMPALA
#
#              WORKING DIAGNOSIS  OUT COME  NUMBER OF PREVIOUS ADMISSIONS  \
# 37635               HIV,ABD.TB  IMPROVED                              0
# 46211                  HIV,PTB  IMPROVED                              0
# 45641          HIV,ANAEMIA,PTB      DIED                              0
# 60816  DISSEMINATED TB,ANAEMIA  IMPROVED                              0
# 48351                      TBM  IMPROVED                              0
# 12548         HIV,ABDOMINAL TB  IMPROVED                              0
# 11497              HIV,CCM,PTB  IMPROVED                              0
# 21405  DISSEMINATED TB,MALARIA  IMPROVED                              0
# 60013                  HIV,PTB  IMPROVED                              0
# 30257          HIV,PTB,ANAEMIA      DIED                              0
#
#                TB_type  ... YEAR OF ADMISSION DURATION   REGION  \
# 37635     Abdominal_TB  ...              2013       20  CENTRAL
# 46211              PTB  ...              2018        4  CENTRAL
# 45641              PTB  ...              2017        3  CENTRAL
# 60816  Disseminated TB  ...              2017        7  CENTRAL
# 48351           CNS_TB  ...              2019        9  CENTRAL
# 12548     Abdominal_TB  ...              2017        5  CENTRAL
# 11497              PTB  ...              2017       20  CENTRAL
# 21405  Disseminated TB  ...              2013        9  CENTRAL
# 60013              PTB  ...              2016        7  CENTRAL
# 30257              PTB  ...              2018        3  CENTRAL
#
#        ADDITIONAL WORKING DIAGNOSIS  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  \
# 37635                           HIV                                       1
# 46211                           HIV                                       1
# 45641                   HIV,ANAEMIA                                       2
# 60816                       ANAEMIA                                       1
# 48351                           NaN                                       0
# 12548                           HIV                                       1
# 11497                       HIV,CCM                                       2
# 21405                       MALARIA                                       1
# 60013                           HIV                                       1
# 30257                   HIV,ANAEMIA                                       2
#
#       Duration (weeks) Week_1  Week_2  Week_3  Week_4
# 37635                3    0.0     0.0     0.0     NaN
# 46211                1    0.0     NaN     NaN     NaN
# 45641                1    1.0     1.0     1.0     1.0
# 60816                1    0.0     NaN     NaN     NaN
# 48351                2    0.0     0.0     NaN     NaN
# 12548                1    0.0     NaN     NaN     NaN
# 11497                3    0.0     0.0     0.0     NaN
# 21405                2    0.0     0.0     NaN     NaN
# 60013                1    0.0     NaN     NaN     NaN
# 30257                1    1.0     1.0     1.0     1.0
#
# [10 rows x 23 columns]

# %%
#Deleting features which are not going to be used
features_to_remove = ['UNIT','DISTRICT OF RESIDENCE','WORKING DIAGNOSIS',
                      'ADDITIONAL WORKING DIAGNOSIS', 'MARITAL STATUS', 'IP NUMBER', 'Duration (weeks)']
dataset.drop(features_to_remove, axis = 1, inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65472 entries, 0 to 65471
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   SEX                                     65472 non-null  object
#  1   AGE                                     65472 non-null  int64
#  2   RELIGION                                65472 non-null  object
#  3   OUT COME                                65472 non-null  object
#  4   NUMBER OF PREVIOUS ADMISSIONS           65472 non-null  int64
#  5   TB_type                                 65472 non-null  object
#  6   MONTH OF ADMISSION                      65472 non-null  object
#  7   DAY OF ADMISSION                        65472 non-null  object
#  8   YEAR OF ADMISSION                       65472 non-null  int64
#  9   DURATION                                65472 non-null  int64
#  10  REGION                                  65472 non-null  object
#  11  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  65472 non-null  int64
#  12  Week_1                                  65472 non-null  float64
#  13  Week_2                                  41200 non-null  float64
#  14  Week_3                                  26608 non-null  float64
#  15  Week_4                                  22976 non-null  float64
# dtypes: float64(4), int64(5), object(7)
# memory usage: 8.0+ MB

# %%
dataset.head()
# Out:
#   SEX  AGE RELIGION  OUT COME  NUMBER OF PREVIOUS ADMISSIONS          TB_type  \
# 0   M   30      COU  IMPROVED                              5     Abdominal_TB
# 1   M   30      COU  IMPROVED                              5     Abdominal_TB
# 2   M   30      COU  IMPROVED                              5     Abdominal_TB
# 3   M   30      COU  IMPROVED                              5     Abdominal_TB
# 4   F   46      COU  IMPROVED                              3  Disseminated TB
#
#   MONTH OF ADMISSION DAY OF ADMISSION  YEAR OF ADMISSION  DURATION   REGION  \
# 0           November          Tuesday               2010         6  CENTRAL
# 1           November          Tuesday               2010         6  CENTRAL
# 2           November          Tuesday               2010         6  CENTRAL
# 3           November          Tuesday               2010         6  CENTRAL
# 4           December           Monday               2010         4  CENTRAL
#
#    NUMBER OF ADDITIONAL WORKING DIAGNOSIS  Week_1  Week_2  Week_3  Week_4
# 0                                       1     0.0     NaN     NaN     NaN
# 1                                       1     0.0     NaN     NaN     NaN
# 2                                       1     0.0     NaN     NaN     NaN
# 3                                       1     0.0     NaN     NaN     NaN
# 4                                       1     0.0     NaN     NaN     NaN

# %%
#dataset.to_excel('4A_TB_Prepared1.xlsx', index=False)

# %% [markdown]
# <h1>Data Preprocessing</h1>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dataset['MONTH OF ADMISSION'].unique()
# Out:
# array(['November', 'December', 'January', 'February', 'March', 'April',
#        'May', 'June', 'July', 'August', 'September', 'October'],
#       dtype=object)

# %%
dataset['DAY OF ADMISSION'].unique()
# Out:
# array(['Tuesday', 'Monday', 'Wednesday', 'Thursday', 'Sunday', 'Friday',
#        'Saturday'], dtype=object)

# %%
# dictionary for month encoding 
month_mapping = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6,
                 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}

# dictionary for day of week encoding 
day_mapping = {'Sunday': 1, 'Monday': 2, 'Tuesday': 3, 'Wednesday': 4, 'Thursday': 5, 'Friday': 6, 'Saturday':76 }

dataset['Month of Admission'] = dataset['MONTH OF ADMISSION'].map(month_mapping)
dataset['Day of Admission'] = dataset['DAY OF ADMISSION'].map(day_mapping)

dataset.drop(columns=['MONTH OF ADMISSION', 'DAY OF ADMISSION'], inplace=True)

# %%
textual_columns = ['SEX', 'RELIGION', 'TB_type', 'REGION']

# Encoding textual data
encoder = LabelEncoder()
for col in textual_columns:
  dataset[col] = encoder.fit_transform(dataset[col])

# %%
dataset.head(20)
# Out:
#     SEX  AGE  RELIGION  OUT COME  NUMBER OF PREVIOUS ADMISSIONS  TB_type  \
# 0     1   30         1  IMPROVED                              5        0
# 1     1   30         1  IMPROVED                              5        0
# 2     1   30         1  IMPROVED                              5        0
# 3     1   30         1  IMPROVED                              5        0
# 4     0   46         1  IMPROVED                              3        2
# 5     0   46         1  IMPROVED                              3        2
# 6     0   46         1  IMPROVED                              3        2
# 7     0   46         1  IMPROVED                              3        2
# 8     1   80         2  IMPROVED                              7        0
# 9     1   80         2  IMPROVED                              7        0
# 10    1   80         2  IMPROVED                              7        0
# 11    1   80         2  IMPROVED                              7        0
# 12    1   22         0  IMPROVED                              8        0
# 13    1   22         0  IMPROVED                              8        0
# 14    1   22         0  IMPROVED                              8        0
# 15    1   22         0  IMPROVED                              8        0
# 16    0   18         1  IMPROVED                              4        4
# 17    0   18         1  IMPROVED                              4        4
# 18    0   18         1  IMPROVED                              4        4
# 19    0   18         1  IMPROVED                              4        4
#
#     YEAR OF ADMISSION  DURATION  REGION  \
# 0                2010         6       0
# 1                2010         6       0
# 2                2010         6       0
# 3                2010         6       0
# 4                2010         4       0
# 5                2010         4       0
# 6                2010         4       0
# 7                2010         4       0
# 8                2010         8       0
# 9                2010         8       0
# 10               2010         8       0
# 11               2010         8       0
# 12               2010         9       0
# 13               2010         9       0
# 14               2010         9       0
# 15               2010         9       0
# 16               2011         5       0
# 17               2011         5       0
# 18               2011         5       0
# 19               2011         5       0
#
#     NUMBER OF ADDITIONAL WORKING DIAGNOSIS  Week_1  Week_2  Week_3  Week_4  \
# 0                                        1     0.0     NaN     NaN     NaN
# 1                                        1     0.0     NaN     NaN     NaN
# 2                                        1     0.0     NaN     NaN     NaN
# 3                                        1     0.0     NaN     NaN     NaN
# 4                                        1     0.0     NaN     NaN     NaN
# 5                                        1     0.0     NaN     NaN     NaN
# 6                                        1     0.0     NaN     NaN     NaN
# 7                                        1     0.0     NaN     NaN     NaN
# 8                                        2     0.0     0.0     NaN     NaN
# 9                                        2     0.0     0.0     NaN     NaN
# 10                                       2     0.0     0.0     NaN     NaN
# 11                                       2     0.0     0.0     NaN     NaN
# 12                                       0     0.0     0.0     NaN     NaN
# 13                                       0     0.0     0.0     NaN     NaN
# 14                                       0     0.0     0.0     NaN     NaN
# 15                                       0     0.0     0.0     NaN     NaN
# 16                                       0     0.0     NaN     NaN     NaN
# 17                                       0     0.0     NaN     NaN     NaN
# 18                                       0     0.0     NaN     NaN     NaN
# 19                                       0     0.0     NaN     NaN     NaN
#
#     Month of Admission  Day of Admission
# 0                   11                 3
# 1                   11                 3
# 2                   11                 3
# 3                   11                 3
# 4                   12                 2
# 5                   12                 2
# 6                   12                 2
# 7                   12                 2
# 8                   12                 4
# 9                   12                 4
# 10                  12                 4
# 11                  12                 4
# 12                  12                 2
# 13                  12                 2
# 14                  12                 2
# 15                  12                 2
# 16                   1                 5
# 17                   1                 5
# 18                   1                 5
# 19                   1                 5

# %%
dataset.shape
# Out:
# (65472, 16)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

dataset['AGE'].plot(kind='hist', bins=20, title='AGE')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from matplotlib import pyplot as plt
#       2 import seaborn as sns
#       4 dataset['AGE'].plot(kind='hist', bins=20, title='AGE')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
dataset.groupby('RELIGION').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
dataset.plot(kind='scatter', x='DURATION', y='NUMBER OF ADDITIONAL WORKING DIAGNOSIS', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
dataset.plot(kind='scatter', x='YEAR OF ADMISSION', y='DURATION', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
dataset.plot(kind='scatter', x='AGE', y='NUMBER OF PREVIOUS ADMISSIONS', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
columns = ['SEX', 'AGE', 'RELIGION', 'NUMBER OF PREVIOUS ADMISSIONS', 'TB_type', 'DURATION',
           'REGION', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS', 'Month of Admission', 'Day of Admission']
correlation_matrix = dataset[columns].corr()

plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='coolwarm')
plt.colorbar()

for i in range(len(columns)):
  for j in range(len(columns)):
    plt.text(i, j, "{:.2f}".format(correlation_matrix.iloc[i, j]), ha='center', va='center')

plt.xticks(range(len(columns)), columns, rotation=45, ha='right')
plt.yticks(range(len(columns)), columns)
plt.title('Correlation Matrix')
plt.show()

# %%
dataset.head()
# Out:
#    SEX  AGE  RELIGION  OUT COME  NUMBER OF PREVIOUS ADMISSIONS  TB_type  \
# 0    1   30         1  IMPROVED                              5        0
# 1    1   30         1  IMPROVED                              5        0
# 2    1   30         1  IMPROVED                              5        0
# 3    1   30         1  IMPROVED                              5        0
# 4    0   46         1  IMPROVED                              3        2
#
#    YEAR OF ADMISSION  DURATION  REGION  \
# 0               2010         6       0
# 1               2010         6       0
# 2               2010         6       0
# 3               2010         6       0
# 4               2010         4       0
#
#    NUMBER OF ADDITIONAL WORKING DIAGNOSIS  Week_1  Week_2  Week_3  Week_4  \
# 0                                       1     0.0     NaN     NaN     NaN
# 1                                       1     0.0     NaN     NaN     NaN
# 2                                       1     0.0     NaN     NaN     NaN
# 3                                       1     0.0     NaN     NaN     NaN
# 4                                       1     0.0     NaN     NaN     NaN
#
#    Month of Admission  Day of Admission
# 0                  11                 3
# 1                  11                 3
# 2                  11                 3
# 3                  11                 3
# 4                  12                 2

# %%
dataset['SEX'].unique()
# Out:
# array([1, 0])

# %%
dataset['AGE'].unique()
# Out:
# array([30, 46, 80, 22, 18, 24, 57, 37, 29, 25, 33, 32, 50, 36, 19, 43, 34,
#        16, 31, 40, 39, 28, 47, 35, 56, 48, 23, 59, 17, 38, 45, 52, 13, 42,
#        41, 49, 67, 27, 21, 14, 44, 63, 26, 65, 20, 61, 83, 70, 60, 64, 55,
#        62, 54, 58, 85, 53, 15, 86, 51, 75, 73, 72, 68, 77, 93, 82, 66, 81,
#        96, 90, 71], dtype=int64)

# %%
dataset['RELIGION'].unique()
# Out:
# array([1, 2, 0, 4, 3])

# %%
dataset['NUMBER OF PREVIOUS ADMISSIONS'].unique()
# Out:
# array([ 5,  3,  7,  8,  4,  2,  6,  1, 10,  9, 13, 14, 11, 20, 27, 17, 12,
#        19, 22, 18, 23, 15, 31, 25, 42, 44, 29, 26, 16, 41, 28, 21, 37, 24,
#        92,  0], dtype=int64)

# %%
dataset['TB_type'].unique()
# Out:
# array([0, 2, 4, 3, 1, 5])

# %%
dataset['YEAR OF ADMISSION'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
#       dtype=int64)

# %%
dataset['REGION'].unique()
# Out:
# array([0, 1, 4, 2, 3])

# %%
dataset['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'].unique()
# Out:
# array([1, 2, 0, 3, 4, 5], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

#Normalizing and Standardizing continuous features
normalise_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS','NUMBER OF ADDITIONAL WORKING DIAGNOSIS', 'YEAR OF ADMISSION', 'DURATION', 'Month of Admission', 'Day of Admission']
scaler = MinMaxScaler()
dataset[normalise_features] = scaler.fit_transform(dataset[normalise_features])

# %%
dataset.head()
# Out:
#    SEX       AGE  RELIGION  OUT COME  NUMBER OF PREVIOUS ADMISSIONS  TB_type  \
# 0    1  0.204819         1  IMPROVED                       0.054348        0
# 1    1  0.204819         1  IMPROVED                       0.054348        0
# 2    1  0.204819         1  IMPROVED                       0.054348        0
# 3    1  0.204819         1  IMPROVED                       0.054348        0
# 4    0  0.397590         1  IMPROVED                       0.032609        2
#
#    YEAR OF ADMISSION  DURATION  REGION  \
# 0                0.0  0.020576       0
# 1                0.0  0.020576       0
# 2                0.0  0.020576       0
# 3                0.0  0.020576       0
# 4                0.0  0.012346       0
#
#    NUMBER OF ADDITIONAL WORKING DIAGNOSIS  Week_1  Week_2  Week_3  Week_4  \
# 0                                     0.2     0.0     NaN     NaN     NaN
# 1                                     0.2     0.0     NaN     NaN     NaN
# 2                                     0.2     0.0     NaN     NaN     NaN
# 3                                     0.2     0.0     NaN     NaN     NaN
# 4                                     0.2     0.0     NaN     NaN     NaN
#
#    Month of Admission  Day of Admission
# 0            0.909091          0.026667
# 1            0.909091          0.026667
# 2            0.909091          0.026667
# 3            0.909091          0.026667
# 4            1.000000          0.013333

# %% [markdown]
# <h1>Training</h1>

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import TimeSeriesSplit
# import tensorflow as tf
from tensorflow import keras

# %%
# Separate features and target variables
target_variables = {}
features = {}

for week in range(1, 5):
  week_column = f'Week_{week}'  
  filtered_data = dataset[dataset[week_column].notna()]  
  target_variables[week] = filtered_data[week_column]    
  features[week] = filtered_data.drop(columns=['Week_1', 'Week_2', 'Week_3', 'Week_4', 'OUT COME'])

# %%
target_variables[1].shape
# Out:
# (65472,)

# %%
features[1].sample(4)
# Out:
#        SEX       AGE  RELIGION  NUMBER OF PREVIOUS ADMISSIONS  TB_type  \
# 33035    1  0.265060         1                       0.184783        4
# 63086    0  0.108434         3                       0.000000        4
# 15258    0  0.168675         1                       0.000000        4
# 55818    1  0.216867         1                       0.000000        2
#
#        YEAR OF ADMISSION  DURATION  REGION  \
# 33035           0.111111  0.065844       0
# 63086           0.888889  0.078189       0
# 15258           1.000000  0.053498       0
# 55818           0.444444  0.037037       0
#
#        NUMBER OF ADDITIONAL WORKING DIAGNOSIS  Month of Admission  \
# 33035                                     0.4            0.545455
# 63086                                     0.4            0.363636
# 15258                                     0.2            0.090909
# 55818                                     0.4            0.363636
#
#        Day of Admission
# 33035          0.040000
# 63086          1.000000
# 15258          0.026667
# 55818          0.053333

# %%
# neural network model for logistic regression
def logistic_regression_model(input_dim):
    inputs = keras.Input(shape=(input_dim,))
    outputs = keras.layers.Dense(1, activation='sigmoid')(inputs)
    model = keras.Model(inputs, outputs)

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

accuracy_scores = [] # list to store accuracy for each week
auc_scores = []  # list to store AUC for each week
training_losses = []
validation_losses = []

# %%
# Initializing models for each week using a loop
num_weeks = 4
models = []

for week in range(1, 5):
  models[week] = logistic_regression_model(input_dim=features[week].shape[1])


num_epochs = 20
batch_size = 64
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 6
#       3 models = []
#       5 for week in range(1, 5):
# ----> 6   models[week] = logistic_regression_model(input_dim=features[week].shape[1])
#       9 num_epochs = 20
#      10 batch_size = 64
#
# Cell In[46], line 3, in logistic_regression_model(input_dim)
#       2 def logistic_regression_model(input_dim):
# ----> 3     inputs = keras.Input(shape=(input_dim,))
#       4     outputs = keras.layers.Dense(1, activation='sigmoid')(inputs)
#       5     model = keras.Model(inputs, outputs)
#
# NameError: name 'keras' is not defined

# %%
# Define time-based split for training and testing (optional)
tscv = TimeSeriesSplit(n_splits=3, test_size=1)  # Adjust n_splits and test_size as needed

# Define and fit models for each week as a separate task
for week, target in target_variables.items():
  model = models[week]  
  for train_index, test_index in tscv.split(features[week]):
    X_train, X_test = features[week].iloc[train_index], features[week].iloc[test_index]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

    
    history = model.fit(X_train, y_train[:, week], epochs=num_epochs, batch_size=batch_size, validation_data=(X_test, y_test[:, week]))

    y_pred = model.predict(X_test)
    y_pred_binary = (y_pred > 0.5).astype(int)
    accuracy = accuracy_score(y_test[:, week], y_pred_binary)
    print(f'Accuracy for Week {week}: {accuracy}')

    auc = roc_auc_score(y_test[:, week], y_pred)  # Calculate AUC
    print(f'AUC for Week {week}: {auc}')

    # Store the accuracy and AUC in their respective lists
    accuracy_scores.append(accuracy)
    auc_scores.append(auc)

    # Extracting training and validation loss
    training_losses.append(history.history['loss'])
    validation_losses.append(history.history['val_loss'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 7
#       4 # Define and fit models for each week as a separate task
#       5 # models = {}
#       6 for week, target in target_variables.items():
# ----> 7   model = models[week]
#       8   for train_index, test_index in tscv.split(features[week]):
#       9     X_train, X_test = features[week].iloc[train_index], features[week].iloc[test_index]
#
# IndexError: list index out of range
