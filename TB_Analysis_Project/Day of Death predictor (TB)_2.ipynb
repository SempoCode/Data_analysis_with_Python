# %%
#Importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ##Data Loading

# %%
#Loading data
path = '/content/4A_cleaned_6.xlsx'
data =pd.read_excel(path)
data.head(2)
# Out:
#   UNIT IP NUMBER SEX  AGE RELIGION DISTRICT OF RESIDENCE  \
# 0   GI   1861416   M   30      COU           Nakasongola
# 1   GI   1868011   F   46      COU               Kampala
#
#                   WORKING DIAGNOSIS  OUT COME  NUMBER OF PREVIOUS ADMISSIONS  \
# 0                ISS,Abdominal TB,,  IMPROVED                              5
# 1  ISS Stage I&II,Disseminated TB,,  IMPROVED                              3
#
#            TB_type MARITAL STATUS MONTH OF ADMISSION DAY OF ADMISSION  \
# 0     Abdominal_TB              2           November          Tuesday
# 1  Disseminated TB              2           December           Monday
#
#    YEAR OF ADMISSION  DURATION   REGION ADDITIONAL WORKING DIAGNOSIS  \
# 0               2010         5  CENTRAL                        ISS,,
# 1               2010         3  CENTRAL             ISS Stage I&II,,
#
#    NUMBER OF ADDITIONAL WORKING DIAGNOSIS
# 0                                       1
# 1                                       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4005 entries, 0 to 4004
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   UNIT                                    4005 non-null   object
#  1   IP NUMBER                               4005 non-null   object
#  2   SEX                                     4005 non-null   object
#  3   AGE                                     4005 non-null   int64
#  4   RELIGION                                4005 non-null   object
#  5   DISTRICT OF RESIDENCE                   4005 non-null   object
#  6   WORKING DIAGNOSIS                       4005 non-null   object
#  7   OUT COME                                4005 non-null   object
#  8   NUMBER OF PREVIOUS ADMISSIONS           4005 non-null   int64
#  9   TB_type                                 4005 non-null   object
#  10  MARITAL STATUS                          4002 non-null   object
#  11  MONTH OF ADMISSION                      4005 non-null   object
#  12  DAY OF ADMISSION                        4005 non-null   object
#  13  YEAR OF ADMISSION                       4005 non-null   int64
#  14  DURATION                                4005 non-null   int64
#  15  REGION                                  4005 non-null   object
#  16  ADDITIONAL WORKING DIAGNOSIS            3827 non-null   object
#  17  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  4005 non-null   int64
# dtypes: int64(5), object(13)
# memory usage: 563.3+ KB

# %% [markdown]
# ##**Data Preprocessing**

# %%
#Deleting features which are not going to be used
features_to_remove = ['IP NUMBER', 'UNIT', 'DISTRICT OF RESIDENCE','WORKING DIAGNOSIS' ,'ADDITIONAL WORKING DIAGNOSIS',
                'MARITAL STATUS']
data = data.drop(columns = features_to_remove)

# %%
#filtering out only patients with "DIED" outcome
data = data[data['OUT COME'] == 'DIED']

# %%
#Encoding categorical features
non_features = ['YEAR OF ADMISSION', 'DURATION', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS','AGE','NUMBER OF PREVIOUS ADMISSIONS']
data1 = data.drop(columns=non_features)

text_columns = data1.select_dtypes(include=['object']).columns

data2 = pd.get_dummies(data, columns=text_columns)

# %%
data2['NUMBER OF PREVIOUS ADMISSIONS'].unique()
# Out:
# array([ 2,  4,  5,  1,  7,  6,  9, 20, 11, 13,  3,  8, 15, 14, 10, 18, 16,
#        22, 21, 25, 12, 26, 23, 92,  0])

# %%
data2['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'] = data2['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'].astype(float)
data2['AGE'] = data2['AGE'].astype(float)

# %%
data2.sample(4)
# Out:
#        AGE  NUMBER OF PREVIOUS ADMISSIONS  YEAR OF ADMISSION  DURATION  \
# 848   49.0                              0               2012         7
# 2453  39.0                              0               2016         3
# 1663  27.0                              0               2014         5
# 3124  48.0                              0               2017         6
#
#       NUMBER OF ADDITIONAL WORKING DIAGNOSIS  SEX_F  SEX_M  RELIGION_CATHOLIC  \
# 848                                      2.0      1      0                  0
# 2453                                     2.0      1      0                  1
# 1663                                     2.0      1      0                  1
# 3124                                     1.0      1      0                  1
#
#       RELIGION_COU  RELIGION_ISLAM  ...  DAY OF ADMISSION_Saturday  \
# 848              0               0  ...                          0
# 2453             0               0  ...                          0
# 1663             0               0  ...                          0
# 3124             0               0  ...                          0
#
#       DAY OF ADMISSION_Sunday  DAY OF ADMISSION_Thursday  \
# 848                         0                          0
# 2453                        0                          0
# 1663                        0                          0
# 3124                        0                          0
#
#       DAY OF ADMISSION_Tuesday  DAY OF ADMISSION_Wednesday  REGION_CENTRAL  \
# 848                          0                           1               1
# 2453                         1                           0               1
# 1663                         0                           0               1
# 3124                         0                           0               1
#
#       REGION_EASTERN  REGION_NORTHERN  REGION_SOUTHERN  REGION_WESTERN
# 848                0                0                0               0
# 2453               0                0                0               0
# 1663               0                0                0               0
# 3124               0                0                0               0
#
# [4 rows x 43 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1280 entries, 5 to 4001
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   AGE                                     1280 non-null   float64
#  1   NUMBER OF PREVIOUS ADMISSIONS           1280 non-null   int64
#  2   YEAR OF ADMISSION                       1280 non-null   int64
#  3   DURATION                                1280 non-null   int64
#  4   NUMBER OF ADDITIONAL WORKING DIAGNOSIS  1280 non-null   float64
#  5   SEX_F                                   1280 non-null   uint8
#  6   SEX_M                                   1280 non-null   uint8
#  7   RELIGION_CATHOLIC                       1280 non-null   uint8
#  8   RELIGION_COU                            1280 non-null   uint8
#  9   RELIGION_ISLAM                          1280 non-null   uint8
#  10  RELIGION_OTHERS                         1280 non-null   uint8
#  11  RELIGION_PENTECOSTAL                    1280 non-null   uint8
#  12  OUT COME_DIED                           1280 non-null   uint8
#  13  TB_type_Abdominal_TB                    1280 non-null   uint8
#  14  TB_type_CNS_TB                          1280 non-null   uint8
#  15  TB_type_Disseminated TB                 1280 non-null   uint8
#  16  TB_type_Other TBs                       1280 non-null   uint8
#  17  TB_type_PTB                             1280 non-null   uint8
#  18  TB_type_TB iris                         1280 non-null   uint8
#  19  MONTH OF ADMISSION_April                1280 non-null   uint8
#  20  MONTH OF ADMISSION_August               1280 non-null   uint8
#  21  MONTH OF ADMISSION_December             1280 non-null   uint8
#  22  MONTH OF ADMISSION_February             1280 non-null   uint8
#  23  MONTH OF ADMISSION_January              1280 non-null   uint8
#  24  MONTH OF ADMISSION_July                 1280 non-null   uint8
#  25  MONTH OF ADMISSION_June                 1280 non-null   uint8
#  26  MONTH OF ADMISSION_March                1280 non-null   uint8
#  27  MONTH OF ADMISSION_May                  1280 non-null   uint8
#  28  MONTH OF ADMISSION_November             1280 non-null   uint8
#  29  MONTH OF ADMISSION_October              1280 non-null   uint8
#  30  MONTH OF ADMISSION_September            1280 non-null   uint8
#  31  DAY OF ADMISSION_Friday                 1280 non-null   uint8
#  32  DAY OF ADMISSION_Monday                 1280 non-null   uint8
#  33  DAY OF ADMISSION_Saturday               1280 non-null   uint8
#  34  DAY OF ADMISSION_Sunday                 1280 non-null   uint8
#  35  DAY OF ADMISSION_Thursday               1280 non-null   uint8
#  36  DAY OF ADMISSION_Tuesday                1280 non-null   uint8
#  37  DAY OF ADMISSION_Wednesday              1280 non-null   uint8
#  38  REGION_CENTRAL                          1280 non-null   uint8
#  39  REGION_EASTERN                          1280 non-null   uint8
#  40  REGION_NORTHERN                         1280 non-null   uint8
#  41  REGION_SOUTHERN                         1280 non-null   uint8
#  42  REGION_WESTERN                          1280 non-null   uint8
# dtypes: float64(2), int64(3), uint8(38)
# memory usage: 107.5 KB

# %%
from scipy.stats import skew
import seaborn as sns

#Visualizing skeness of the continuous features
continuous_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS','DURATION']
for col in continuous_features:
  print(col)
  print(skew(data2[col]))

  plt.figure()
  sns.distplot(data2[col])
  plt.show()
# Out:
# NUMBER OF ADDITIONAL WORKING DIAGNOSIS
# 0.47439393814030534
# <ipython-input-11-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])
# DURATION
# 1.4494220658069628
# <ipython-input-11-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])

# %%
#Visualizing Correlation among the continuous features nluding the target
continuous_features_target = ['AGE','NUMBER OF PREVIOUS ADMISSIONS', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS', 'DURATION']
plt.figure(figsize=(12,4))
sns.heatmap(data2[continuous_features_target].corr(), annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Heatmap of continuous Features Correlation')
plt.show()

# %%
#Transforming the continuous features
transform_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS','DURATION']
for col in transform_features:
  data2[col] = np.log1p(data2[col])

#Second transformation
data2['NUMBER OF PREVIOUS ADMISSIONS'] = np.log1p(data2['NUMBER OF PREVIOUS ADMISSIONS'])

# %%
#Normalizing and Standardizing continuous features
normalise_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS','NUMBER OF ADDITIONAL WORKING DIAGNOSIS']
scaler = MinMaxScaler()
data2[normalise_features] = scaler.fit_transform(data2[normalise_features])

# %%
#Plotting Density plot
import seaborn as sns

continuous_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS','NUMBER OF ADDITIONAL WORKING DIAGNOSIS','DURATION']

fig, axes = plt.subplots(1, len(continuous_features), figsize=(15, 5))

for i, col in enumerate(continuous_features):
  sns.kdeplot(data[col], fill=True,ax=axes[i])
  axes[i].set_title(f'Density Plot for {col}')
  axes[i].set_xlabel('Values')
  axes[i].set_ylabel('Density')
# plt.figure(figsize=(8,9))
# plt.bar(data['AGE'])
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data2.sample(2)
# Out:
#           AGE  NUMBER OF PREVIOUS ADMISSIONS  YEAR OF ADMISSION  DURATION  \
# 865  0.624704                       0.000000               2013  2.079442
# 186  0.237358                       0.715021               2011  2.397895
#
#      NUMBER OF ADDITIONAL WORKING DIAGNOSIS  SEX_F  SEX_M  RELIGION_CATHOLIC  \
# 865                                0.773706      0      1                  1
# 186                                0.773706      1      0                  0
#
#      RELIGION_COU  RELIGION_ISLAM  ...  DAY OF ADMISSION_Saturday  \
# 865             0               0  ...                          1
# 186             1               0  ...                          0
#
#      DAY OF ADMISSION_Sunday  DAY OF ADMISSION_Thursday  \
# 865                        0                          0
# 186                        0                          0
#
#      DAY OF ADMISSION_Tuesday  DAY OF ADMISSION_Wednesday  REGION_CENTRAL  \
# 865                         0                           0               1
# 186                         0                           1               1
#
#      REGION_EASTERN  REGION_NORTHERN  REGION_SOUTHERN  REGION_WESTERN
# 865               0                0                0               0
# 186               0                0                0               0
#
# [2 rows x 43 columns]

# %%
data2['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'].unique()
# Out:
# array([0.38685281, 0.61314719, 0.77370561, 1.        , 0.8982444 ,
#        0.        ])

# %%
data2.shape
# Out:
# (1280, 43)

# %%
#Saving Preprocced data
data.to_excel('preprocessed1_TB-4a.xlsx', index=False)

# %% [markdown]
# ##Data Splitting

# %%
data2['YEAR OF ADMISSION'].unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
#counting occurence of each year
year_count = data2['YEAR OF ADMISSION'].value_counts().sort_index()

#Plotting the Chart
plt.bar(year_count.index, year_count.values)

#Labelling
plt.xlabel('Year of admission')
plt.ylabel('Count')
plt.title('Year of admission Distribution')

#Labelling the bins
for year, count in zip(year_count.index, year_count.values):
  plt.text(year, count, str(year), ha='center', va='bottom')

#Show the Plot
plt.show()

# %%
#Splitting dataset into training and testing set
train_df = data2[data['YEAR OF ADMISSION'] <= 2016]

test_df = data2[data['YEAR OF ADMISSION'] > 2016]
#extracting features and targets

non_train_feature = ['YEAR OF ADMISSION',	'DURATION']

X_train = train_df.drop(columns=non_train_feature)
y_train = train_df['DURATION']

X_test = test_df.drop(columns=non_train_feature)
y_test = test_df['DURATION']

#Splitting data into training and testing sets
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %% [markdown]
# #**MODEL TRAINING**

# %%
import tensorflow as tf
from tensorflow import keras

tf.random.set_seed(42)

# %% [markdown]
# ##**Model1**

# %%
#neural network Architecture(ANN)
model1 = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(500, activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(5, activation='relu'),
    keras.layers.Dense(1, activation='linear')
])

model1.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse','mae'])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 500)               21000
#
#  dense_1 (Dense)             (None, 15)                7515
#
#  dense_2 (Dense)             (None, 10)                160
#
#  dense_3 (Dense)             (None, 5)                 55
#
#  dense_4 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 28736 (112.25 KB)
# Trainable params: 28736 (112.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#model1 training and validation
history1 = model1.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 2s 14ms/step - loss: 3.4515 - mse: 3.4515 - mae: 1.7149 - val_loss: 3.7348 - val_mse: 3.7348 - val_mae: 1.8134
# Epoch 2/100
# 23/23 [==============================] - 0s 6ms/step - loss: 3.3515 - mse: 3.3515 - mae: 1.6873 - val_loss: 3.6532 - val_mse: 3.6532 - val_mae: 1.7910
# Epoch 3/100
# 23/23 [==============================] - 0s 5ms/step - loss: 3.2755 - mse: 3.2755 - mae: 1.6659 - val_loss: 3.5728 - val_mse: 3.5728 - val_mae: 1.7687
# Epoch 4/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.2009 - mse: 3.2009 - mae: 1.6445 - val_loss: 3.4935 - val_mse: 3.4935 - val_mae: 1.7463
# Epoch 5/100
# 23/23 [==============================] - 0s 5ms/step - loss: 3.1279 - mse: 3.1279 - mae: 1.6232 - val_loss: 3.4156 - val_mse: 3.4156 - val_mae: 1.7241
# Epoch 6/100
# 23/23 [==============================] - 0s 5ms/step - loss: 3.0561 - mse: 3.0561 - mae: 1.6021 - val_loss: 3.3401 - val_mse: 3.3401 - val_mae: 1.7023
# Epoch 7/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.9862 - mse: 2.9862 - mae: 1.5814 - val_loss: 3.2660 - val_mse: 3.2660 - val_mae: 1.6806
# Epoch 8/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.9182 - mse: 2.9182 - mae: 1.5605 - val_loss: 3.1927 - val_mse: 3.1927 - val_mae: 1.6589
# Epoch 9/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.8508 - mse: 2.8508 - mae: 1.5397 - val_loss: 3.1211 - val_mse: 3.1211 - val_mae: 1.6374
# Epoch 10/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.7845 - mse: 2.7845 - mae: 1.5193 - val_loss: 3.0516 - val_mse: 3.0516 - val_mae: 1.6162
# Epoch 11/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.7206 - mse: 2.7206 - mae: 1.4990 - val_loss: 2.9822 - val_mse: 2.9822 - val_mae: 1.5948
# Epoch 12/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.6573 - mse: 2.6573 - mae: 1.4787 - val_loss: 2.9147 - val_mse: 2.9147 - val_mae: 1.5737
# Epoch 13/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.5956 - mse: 2.5956 - mae: 1.4585 - val_loss: 2.8488 - val_mse: 2.8488 - val_mae: 1.5528
# Epoch 14/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.5352 - mse: 2.5352 - mae: 1.4385 - val_loss: 2.7844 - val_mse: 2.7844 - val_mae: 1.5321
# Epoch 15/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.4761 - mse: 2.4761 - mae: 1.4187 - val_loss: 2.7218 - val_mse: 2.7218 - val_mae: 1.5118
# Epoch 16/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.4186 - mse: 2.4186 - mae: 1.3994 - val_loss: 2.6601 - val_mse: 2.6601 - val_mae: 1.4914
# Epoch 17/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.3625 - mse: 2.3625 - mae: 1.3798 - val_loss: 2.5991 - val_mse: 2.5991 - val_mae: 1.4710
# Epoch 18/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3071 - mse: 2.3071 - mae: 1.3602 - val_loss: 2.5399 - val_mse: 2.5399 - val_mae: 1.4509
# Epoch 19/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.2531 - mse: 2.2531 - mae: 1.3412 - val_loss: 2.4821 - val_mse: 2.4821 - val_mae: 1.4310
# Epoch 20/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.2005 - mse: 2.2005 - mae: 1.3222 - val_loss: 2.4253 - val_mse: 2.4253 - val_mae: 1.4112
# Epoch 21/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.1491 - mse: 2.1491 - mae: 1.3032 - val_loss: 2.3694 - val_mse: 2.3694 - val_mae: 1.3914
# Epoch 22/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.0984 - mse: 2.0984 - mae: 1.2845 - val_loss: 2.3155 - val_mse: 2.3155 - val_mae: 1.3720
# Epoch 23/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.0494 - mse: 2.0494 - mae: 1.2659 - val_loss: 2.2618 - val_mse: 2.2618 - val_mae: 1.3524
# Epoch 24/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.0011 - mse: 2.0011 - mae: 1.2474 - val_loss: 2.2103 - val_mse: 2.2103 - val_mae: 1.3334
# Epoch 25/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.9544 - mse: 1.9544 - mae: 1.2292 - val_loss: 2.1598 - val_mse: 2.1598 - val_mae: 1.3145
# Epoch 26/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.9089 - mse: 1.9089 - mae: 1.2109 - val_loss: 2.1095 - val_mse: 2.1095 - val_mae: 1.2953
# Epoch 27/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.8639 - mse: 1.8639 - mae: 1.1930 - val_loss: 2.0613 - val_mse: 2.0613 - val_mae: 1.2767
# Epoch 28/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.8205 - mse: 1.8205 - mae: 1.1748 - val_loss: 2.0133 - val_mse: 2.0133 - val_mae: 1.2579
# Epoch 29/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.7777 - mse: 1.7777 - mae: 1.1571 - val_loss: 1.9672 - val_mse: 1.9672 - val_mae: 1.2395
# Epoch 30/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1.7362 - mse: 1.7362 - mae: 1.1397 - val_loss: 1.9224 - val_mse: 1.9224 - val_mae: 1.2214
# Epoch 31/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.6961 - mse: 1.6961 - mae: 1.1221 - val_loss: 1.8778 - val_mse: 1.8778 - val_mae: 1.2031
# Epoch 32/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.6563 - mse: 1.6563 - mae: 1.1049 - val_loss: 1.8352 - val_mse: 1.8352 - val_mae: 1.1854
# Epoch 33/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.6179 - mse: 1.6179 - mae: 1.0878 - val_loss: 1.7926 - val_mse: 1.7926 - val_mae: 1.1674
# Epoch 34/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.5802 - mse: 1.5802 - mae: 1.0708 - val_loss: 1.7516 - val_mse: 1.7516 - val_mae: 1.1498
# Epoch 35/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.5439 - mse: 1.5439 - mae: 1.0558 - val_loss: 1.7112 - val_mse: 1.7112 - val_mae: 1.1352
# Epoch 36/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.5082 - mse: 1.5082 - mae: 1.0434 - val_loss: 1.6723 - val_mse: 1.6723 - val_mae: 1.1208
# Epoch 37/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.4738 - mse: 1.4738 - mae: 1.0310 - val_loss: 1.6334 - val_mse: 1.6334 - val_mae: 1.1063
# Epoch 38/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.4397 - mse: 1.4397 - mae: 1.0184 - val_loss: 1.5965 - val_mse: 1.5965 - val_mae: 1.0922
# Epoch 39/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.4071 - mse: 1.4071 - mae: 1.0065 - val_loss: 1.5604 - val_mse: 1.5604 - val_mae: 1.0783
# Epoch 40/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3754 - mse: 1.3754 - mae: 0.9944 - val_loss: 1.5247 - val_mse: 1.5247 - val_mae: 1.0643
# Epoch 41/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3441 - mse: 1.3441 - mae: 0.9823 - val_loss: 1.4904 - val_mse: 1.4904 - val_mae: 1.0505
# Epoch 42/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.3139 - mse: 1.3139 - mae: 0.9704 - val_loss: 1.4569 - val_mse: 1.4569 - val_mae: 1.0370
# Epoch 43/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1.2845 - mse: 1.2845 - mae: 0.9588 - val_loss: 1.4240 - val_mse: 1.4240 - val_mae: 1.0234
# Epoch 44/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2559 - mse: 1.2559 - mae: 0.9469 - val_loss: 1.3917 - val_mse: 1.3917 - val_mae: 1.0098
# Epoch 45/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1.2281 - mse: 1.2281 - mae: 0.9354 - val_loss: 1.3605 - val_mse: 1.3605 - val_mae: 0.9965
# Epoch 46/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.2011 - mse: 1.2011 - mae: 0.9240 - val_loss: 1.3307 - val_mse: 1.3307 - val_mae: 0.9836
# Epoch 47/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.1751 - mse: 1.1751 - mae: 0.9127 - val_loss: 1.3010 - val_mse: 1.3010 - val_mae: 0.9705
# Epoch 48/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.1497 - mse: 1.1497 - mae: 0.9018 - val_loss: 1.2722 - val_mse: 1.2722 - val_mae: 0.9576
# Epoch 49/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1.1251 - mse: 1.1251 - mae: 0.8905 - val_loss: 1.2444 - val_mse: 1.2444 - val_mae: 0.9449
# Epoch 50/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.1011 - mse: 1.1011 - mae: 0.8796 - val_loss: 1.2177 - val_mse: 1.2177 - val_mae: 0.9325
# Epoch 51/100
# 23/23 [==============================] - 0s 4ms/step - loss: 1.0780 - mse: 1.0780 - mae: 0.8689 - val_loss: 1.1911 - val_mse: 1.1911 - val_mae: 0.9199
# Epoch 52/100
# 23/23 [==============================] - 0s 5ms/step - loss: 1.0556 - mse: 1.0556 - mae: 0.8580 - val_loss: 1.1650 - val_mse: 1.1650 - val_mae: 0.9074
# Epoch 53/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0334 - mse: 1.0334 - mae: 0.8473 - val_loss: 1.1406 - val_mse: 1.1406 - val_mae: 0.8954
# Epoch 54/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.0123 - mse: 1.0123 - mae: 0.8369 - val_loss: 1.1165 - val_mse: 1.1165 - val_mae: 0.8834
# Epoch 55/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9920 - mse: 0.9920 - mae: 0.8265 - val_loss: 1.0926 - val_mse: 1.0926 - val_mae: 0.8713
# Epoch 56/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.9719 - mse: 0.9719 - mae: 0.8162 - val_loss: 1.0698 - val_mse: 1.0698 - val_mae: 0.8595
# Epoch 57/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.9527 - mse: 0.9527 - mae: 0.8059 - val_loss: 1.0472 - val_mse: 1.0472 - val_mae: 0.8476
# Epoch 58/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.9341 - mse: 0.9341 - mae: 0.7959 - val_loss: 1.0258 - val_mse: 1.0258 - val_mae: 0.8362
# Epoch 59/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.9162 - mse: 0.9162 - mae: 0.7861 - val_loss: 1.0050 - val_mse: 1.0050 - val_mae: 0.8248
# Epoch 60/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8990 - mse: 0.8990 - mae: 0.7763 - val_loss: 0.9850 - val_mse: 0.9850 - val_mae: 0.8147
# Epoch 61/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8823 - mse: 0.8823 - mae: 0.7692 - val_loss: 0.9653 - val_mse: 0.9653 - val_mae: 0.8070
# Epoch 62/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8660 - mse: 0.8660 - mae: 0.7630 - val_loss: 0.9465 - val_mse: 0.9465 - val_mae: 0.7996
# Epoch 63/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8505 - mse: 0.8505 - mae: 0.7566 - val_loss: 0.9280 - val_mse: 0.9280 - val_mae: 0.7921
# Epoch 64/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.8352 - mse: 0.8352 - mae: 0.7505 - val_loss: 0.9100 - val_mse: 0.9100 - val_mae: 0.7846
# Epoch 65/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8205 - mse: 0.8205 - mae: 0.7446 - val_loss: 0.8926 - val_mse: 0.8926 - val_mae: 0.7773
# Epoch 66/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.8064 - mse: 0.8064 - mae: 0.7385 - val_loss: 0.8755 - val_mse: 0.8755 - val_mae: 0.7700
# Epoch 67/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7927 - mse: 0.7927 - mae: 0.7327 - val_loss: 0.8591 - val_mse: 0.8591 - val_mae: 0.7628
# Epoch 68/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7795 - mse: 0.7795 - mae: 0.7269 - val_loss: 0.8434 - val_mse: 0.8434 - val_mae: 0.7558
# Epoch 69/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7670 - mse: 0.7670 - mae: 0.7211 - val_loss: 0.8283 - val_mse: 0.8283 - val_mae: 0.7490
# Epoch 70/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7549 - mse: 0.7549 - mae: 0.7152 - val_loss: 0.8136 - val_mse: 0.8136 - val_mae: 0.7421
# Epoch 71/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7431 - mse: 0.7431 - mae: 0.7098 - val_loss: 0.7996 - val_mse: 0.7996 - val_mae: 0.7356
# Epoch 72/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7320 - mse: 0.7320 - mae: 0.7042 - val_loss: 0.7857 - val_mse: 0.7857 - val_mae: 0.7288
# Epoch 73/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7211 - mse: 0.7211 - mae: 0.6990 - val_loss: 0.7722 - val_mse: 0.7722 - val_mae: 0.7222
# Epoch 74/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7106 - mse: 0.7106 - mae: 0.6934 - val_loss: 0.7593 - val_mse: 0.7593 - val_mae: 0.7157
# Epoch 75/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7004 - mse: 0.7004 - mae: 0.6881 - val_loss: 0.7474 - val_mse: 0.7474 - val_mae: 0.7096
# Epoch 76/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6911 - mse: 0.6911 - mae: 0.6831 - val_loss: 0.7348 - val_mse: 0.7348 - val_mae: 0.7030
# Epoch 77/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6817 - mse: 0.6817 - mae: 0.6778 - val_loss: 0.7230 - val_mse: 0.7230 - val_mae: 0.6967
# Epoch 78/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6726 - mse: 0.6726 - mae: 0.6728 - val_loss: 0.7125 - val_mse: 0.7125 - val_mae: 0.6910
# Epoch 79/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6644 - mse: 0.6644 - mae: 0.6679 - val_loss: 0.7015 - val_mse: 0.7015 - val_mae: 0.6849
# Epoch 80/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6563 - mse: 0.6563 - mae: 0.6629 - val_loss: 0.6912 - val_mse: 0.6912 - val_mae: 0.6791
# Epoch 81/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6486 - mse: 0.6486 - mae: 0.6581 - val_loss: 0.6813 - val_mse: 0.6813 - val_mae: 0.6733
# Epoch 82/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6412 - mse: 0.6412 - mae: 0.6535 - val_loss: 0.6718 - val_mse: 0.6718 - val_mae: 0.6676
# Epoch 83/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6341 - mse: 0.6341 - mae: 0.6489 - val_loss: 0.6627 - val_mse: 0.6627 - val_mae: 0.6621
# Epoch 84/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6273 - mse: 0.6273 - mae: 0.6442 - val_loss: 0.6534 - val_mse: 0.6534 - val_mae: 0.6564
# Epoch 85/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6207 - mse: 0.6207 - mae: 0.6400 - val_loss: 0.6447 - val_mse: 0.6447 - val_mae: 0.6522
# Epoch 86/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6144 - mse: 0.6144 - mae: 0.6374 - val_loss: 0.6364 - val_mse: 0.6364 - val_mae: 0.6490
# Epoch 87/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6085 - mse: 0.6085 - mae: 0.6352 - val_loss: 0.6286 - val_mse: 0.6286 - val_mae: 0.6460
# Epoch 88/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6029 - mse: 0.6029 - mae: 0.6330 - val_loss: 0.6212 - val_mse: 0.6212 - val_mae: 0.6431
# Epoch 89/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5976 - mse: 0.5976 - mae: 0.6309 - val_loss: 0.6137 - val_mse: 0.6137 - val_mae: 0.6401
# Epoch 90/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5925 - mse: 0.5925 - mae: 0.6288 - val_loss: 0.6066 - val_mse: 0.6066 - val_mae: 0.6371
# Epoch 91/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5876 - mse: 0.5876 - mae: 0.6268 - val_loss: 0.6004 - val_mse: 0.6004 - val_mae: 0.6345
# Epoch 92/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5831 - mse: 0.5831 - mae: 0.6248 - val_loss: 0.5938 - val_mse: 0.5938 - val_mae: 0.6316
# Epoch 93/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5787 - mse: 0.5787 - mae: 0.6229 - val_loss: 0.5878 - val_mse: 0.5878 - val_mae: 0.6290
# Epoch 94/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5745 - mse: 0.5745 - mae: 0.6209 - val_loss: 0.5817 - val_mse: 0.5817 - val_mae: 0.6263
# Epoch 95/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5705 - mse: 0.5705 - mae: 0.6190 - val_loss: 0.5757 - val_mse: 0.5757 - val_mae: 0.6235
# Epoch 96/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5666 - mse: 0.5666 - mae: 0.6171 - val_loss: 0.5703 - val_mse: 0.5703 - val_mae: 0.6210
# Epoch 97/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5631 - mse: 0.5631 - mae: 0.6152 - val_loss: 0.5648 - val_mse: 0.5648 - val_mae: 0.6183
# Epoch 98/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5596 - mse: 0.5596 - mae: 0.6134 - val_loss: 0.5601 - val_mse: 0.5601 - val_mae: 0.6160
# Epoch 99/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5565 - mse: 0.5565 - mae: 0.6118 - val_loss: 0.5554 - val_mse: 0.5554 - val_mae: 0.6137
# Epoch 100/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5535 - mse: 0.5535 - mae: 0.6100 - val_loss: 0.5507 - val_mse: 0.5507 - val_mae: 0.6112

# %%
#Evaluating the model's performance
test_loss, test_mse, test_mae = model1.evaluate(X_test, y_test)

print(f'Test Loss: {test_loss}')
print(f'Test MSE: {test_mse}')
print(f'Test MAE: {test_mae}')
# Out:
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5155 - mse: 0.5155 - mae: 0.5848
# Test Loss: 0.5155056715011597
# Test MSE: 0.5155056715011597
# Test MAE: 0.5847861170768738

# %%
#extracting relevant informationfrom the training history
train_loss =history1.history['loss']
val_loss = history1.history['val_loss']

#Plotting Traing and validation cures
plt.figure(figsize=(10,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and validation curves')
plt.show()

# %%
#making predictions
y_pred1 = model1.predict(X_test)

#Changing the shape of the results and getting the loss
y_pred1_= y_pred1.flatten()
residual1 = y_test - y_pred1_
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
#Plotting the Residual Plot
plt.figure(figsize=(8,6))
plt.scatter(y_pred1_, residual1,alpha=0.5)
plt.title('Residual Plot 1')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.grid(True)
plt.show()

# %%
#plotting a learning curve
hist_dict = history1.history
loss_values = hist_dict['loss']
val_loss_values = hist_dict["val_loss"]

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs,loss_values,'ro-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##**Model2**

# %%
#A more complex model architecture (ANN)
model2 = keras.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(X_train.shape[1],), kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(256, activation='relu', kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(128, activation='relu', kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu', kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal'),
    keras.layers.Dense(1, activation='linear')
])

model2.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 512)               21504
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dense_10 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 199937 (781.00 KB)
# Trainable params: 198017 (773.50 KB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________

# %%
history2=model2.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 3s 26ms/step - loss: 3.3554 - mae: 1.3926 - mse: 3.3554 - val_loss: 3.0401 - val_mae: 1.5985 - val_mse: 3.0401
# Epoch 2/100
# 23/23 [==============================] - 0s 18ms/step - loss: 2.0853 - mae: 1.1341 - mse: 2.0853 - val_loss: 2.6488 - val_mae: 1.4802 - val_mse: 2.6488
# Epoch 3/100
# 23/23 [==============================] - 0s 15ms/step - loss: 1.8278 - mae: 1.0616 - mse: 1.8278 - val_loss: 2.2415 - val_mae: 1.3366 - val_mse: 2.2415
# Epoch 4/100
# 23/23 [==============================] - 0s 16ms/step - loss: 1.4060 - mae: 0.9481 - mse: 1.4060 - val_loss: 1.8260 - val_mae: 1.1770 - val_mse: 1.8260
# Epoch 5/100
# 23/23 [==============================] - 0s 13ms/step - loss: 1.2392 - mae: 0.8765 - mse: 1.2392 - val_loss: 1.4753 - val_mae: 1.0362 - val_mse: 1.4753
# Epoch 6/100
# 23/23 [==============================] - 0s 14ms/step - loss: 1.1761 - mae: 0.8682 - mse: 1.1761 - val_loss: 1.2614 - val_mae: 0.9431 - val_mse: 1.2614
# Epoch 7/100
# 23/23 [==============================] - 0s 14ms/step - loss: 1.1058 - mae: 0.8180 - mse: 1.1058 - val_loss: 1.0950 - val_mae: 0.8666 - val_mse: 1.0950
# Epoch 8/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.9808 - mae: 0.7912 - mse: 0.9808 - val_loss: 0.9954 - val_mae: 0.8227 - val_mse: 0.9954
# Epoch 9/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.9625 - mae: 0.7695 - mse: 0.9625 - val_loss: 0.9531 - val_mae: 0.8040 - val_mse: 0.9531
# Epoch 10/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.9149 - mae: 0.7706 - mse: 0.9149 - val_loss: 0.9261 - val_mae: 0.7943 - val_mse: 0.9261
# Epoch 11/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.9126 - mae: 0.7600 - mse: 0.9126 - val_loss: 0.8624 - val_mae: 0.7655 - val_mse: 0.8624
# Epoch 12/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.9550 - mae: 0.7705 - mse: 0.9550 - val_loss: 0.8668 - val_mae: 0.7651 - val_mse: 0.8668
# Epoch 13/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8739 - mae: 0.7496 - mse: 0.8739 - val_loss: 0.8703 - val_mae: 0.7661 - val_mse: 0.8703
# Epoch 14/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8225 - mae: 0.7280 - mse: 0.8225 - val_loss: 0.8547 - val_mae: 0.7579 - val_mse: 0.8547
# Epoch 15/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8747 - mae: 0.7530 - mse: 0.8747 - val_loss: 0.8046 - val_mae: 0.7356 - val_mse: 0.8046
# Epoch 16/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8250 - mae: 0.7268 - mse: 0.8250 - val_loss: 0.8002 - val_mae: 0.7343 - val_mse: 0.8002
# Epoch 17/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7749 - mae: 0.7070 - mse: 0.7749 - val_loss: 0.7699 - val_mae: 0.7192 - val_mse: 0.7699
# Epoch 18/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7669 - mae: 0.6958 - mse: 0.7669 - val_loss: 0.7631 - val_mae: 0.7170 - val_mse: 0.7631
# Epoch 19/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7802 - mae: 0.7080 - mse: 0.7802 - val_loss: 0.8287 - val_mae: 0.7473 - val_mse: 0.8287
# Epoch 20/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7520 - mae: 0.7086 - mse: 0.7520 - val_loss: 0.8124 - val_mae: 0.7371 - val_mse: 0.8124
# Epoch 21/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.8039 - mae: 0.7082 - mse: 0.8039 - val_loss: 0.7891 - val_mae: 0.7272 - val_mse: 0.7891
# Epoch 22/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.7260 - mae: 0.6857 - mse: 0.7260 - val_loss: 0.7866 - val_mae: 0.7282 - val_mse: 0.7866
# Epoch 23/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.7243 - mae: 0.6871 - mse: 0.7243 - val_loss: 0.7782 - val_mae: 0.7245 - val_mse: 0.7782
# Epoch 24/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.7368 - mae: 0.6961 - mse: 0.7368 - val_loss: 0.8195 - val_mae: 0.7448 - val_mse: 0.8195
# Epoch 25/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7256 - mae: 0.6857 - mse: 0.7256 - val_loss: 0.7798 - val_mae: 0.7220 - val_mse: 0.7798
# Epoch 26/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7359 - mae: 0.6856 - mse: 0.7359 - val_loss: 0.7979 - val_mae: 0.7295 - val_mse: 0.7979
# Epoch 27/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7195 - mae: 0.6872 - mse: 0.7195 - val_loss: 0.7882 - val_mae: 0.7212 - val_mse: 0.7882
# Epoch 28/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7268 - mae: 0.6882 - mse: 0.7268 - val_loss: 0.7569 - val_mae: 0.7084 - val_mse: 0.7569
# Epoch 29/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6537 - mae: 0.6516 - mse: 0.6537 - val_loss: 0.7944 - val_mae: 0.7259 - val_mse: 0.7944
# Epoch 30/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6684 - mae: 0.6708 - mse: 0.6684 - val_loss: 0.7297 - val_mae: 0.6964 - val_mse: 0.7297
# Epoch 31/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6513 - mae: 0.6479 - mse: 0.6513 - val_loss: 0.7402 - val_mae: 0.7018 - val_mse: 0.7402
# Epoch 32/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6932 - mae: 0.6625 - mse: 0.6932 - val_loss: 0.7568 - val_mae: 0.7097 - val_mse: 0.7568
# Epoch 33/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6687 - mae: 0.6557 - mse: 0.6687 - val_loss: 0.6943 - val_mae: 0.6779 - val_mse: 0.6943
# Epoch 34/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6348 - mae: 0.6471 - mse: 0.6348 - val_loss: 0.6863 - val_mae: 0.6708 - val_mse: 0.6863
# Epoch 35/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6460 - mae: 0.6579 - mse: 0.6460 - val_loss: 0.6892 - val_mae: 0.6725 - val_mse: 0.6892
# Epoch 36/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6757 - mae: 0.6592 - mse: 0.6757 - val_loss: 0.7019 - val_mae: 0.6807 - val_mse: 0.7019
# Epoch 37/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6419 - mae: 0.6403 - mse: 0.6419 - val_loss: 0.6621 - val_mae: 0.6612 - val_mse: 0.6621
# Epoch 38/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6607 - mae: 0.6552 - mse: 0.6607 - val_loss: 0.6951 - val_mae: 0.6784 - val_mse: 0.6951
# Epoch 39/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6259 - mae: 0.6424 - mse: 0.6259 - val_loss: 0.7019 - val_mae: 0.6809 - val_mse: 0.7019
# Epoch 40/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6370 - mae: 0.6411 - mse: 0.6370 - val_loss: 0.7075 - val_mae: 0.6848 - val_mse: 0.7075
# Epoch 41/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6501 - mae: 0.6451 - mse: 0.6501 - val_loss: 0.7314 - val_mae: 0.6956 - val_mse: 0.7314
# Epoch 42/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6077 - mae: 0.6293 - mse: 0.6077 - val_loss: 0.7527 - val_mae: 0.7086 - val_mse: 0.7527
# Epoch 43/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6265 - mae: 0.6468 - mse: 0.6265 - val_loss: 0.7029 - val_mae: 0.6840 - val_mse: 0.7029
# Epoch 44/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6135 - mae: 0.6272 - mse: 0.6135 - val_loss: 0.6823 - val_mae: 0.6738 - val_mse: 0.6823
# Epoch 45/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5976 - mae: 0.6285 - mse: 0.5976 - val_loss: 0.6964 - val_mae: 0.6801 - val_mse: 0.6964
# Epoch 46/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5882 - mae: 0.6244 - mse: 0.5882 - val_loss: 0.6994 - val_mae: 0.6825 - val_mse: 0.6994
# Epoch 47/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6045 - mae: 0.6274 - mse: 0.6045 - val_loss: 0.6782 - val_mae: 0.6727 - val_mse: 0.6782
# Epoch 48/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5949 - mae: 0.6149 - mse: 0.5949 - val_loss: 0.6754 - val_mae: 0.6713 - val_mse: 0.6754
# Epoch 49/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6153 - mae: 0.6333 - mse: 0.6153 - val_loss: 0.6631 - val_mae: 0.6631 - val_mse: 0.6631
# Epoch 50/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5912 - mae: 0.6245 - mse: 0.5912 - val_loss: 0.6399 - val_mae: 0.6515 - val_mse: 0.6399
# Epoch 51/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5978 - mae: 0.6200 - mse: 0.5978 - val_loss: 0.6446 - val_mae: 0.6548 - val_mse: 0.6446
# Epoch 52/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5804 - mae: 0.6055 - mse: 0.5804 - val_loss: 0.6551 - val_mae: 0.6591 - val_mse: 0.6551
# Epoch 53/100
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5755 - mae: 0.6178 - mse: 0.5755 - val_loss: 0.6726 - val_mae: 0.6669 - val_mse: 0.6726
# Epoch 54/100
# 23/23 [==============================] - 0s 16ms/step - loss: 0.5796 - mae: 0.6189 - mse: 0.5796 - val_loss: 0.6649 - val_mae: 0.6655 - val_mse: 0.6649
# Epoch 55/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5721 - mae: 0.6101 - mse: 0.5721 - val_loss: 0.6633 - val_mae: 0.6641 - val_mse: 0.6633
# Epoch 56/100
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5759 - mae: 0.6168 - mse: 0.5759 - val_loss: 0.7017 - val_mae: 0.6821 - val_mse: 0.7017
# Epoch 57/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.6296 - mae: 0.6430 - mse: 0.6296 - val_loss: 0.6717 - val_mae: 0.6660 - val_mse: 0.6717
# Epoch 58/100
# 23/23 [==============================] - 0s 17ms/step - loss: 0.5643 - mae: 0.6069 - mse: 0.5643 - val_loss: 0.6404 - val_mae: 0.6519 - val_mse: 0.6404
# Epoch 59/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5541 - mae: 0.6006 - mse: 0.5541 - val_loss: 0.6574 - val_mae: 0.6627 - val_mse: 0.6574
# Epoch 60/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5654 - mae: 0.6076 - mse: 0.5654 - val_loss: 0.6555 - val_mae: 0.6619 - val_mse: 0.6555
# Epoch 61/100
# 23/23 [==============================] - 0s 21ms/step - loss: 0.5724 - mae: 0.6175 - mse: 0.5724 - val_loss: 0.6546 - val_mae: 0.6611 - val_mse: 0.6546
# Epoch 62/100
# 23/23 [==============================] - 0s 18ms/step - loss: 0.5613 - mae: 0.6114 - mse: 0.5613 - val_loss: 0.6559 - val_mae: 0.6615 - val_mse: 0.6559
# Epoch 63/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5712 - mae: 0.6142 - mse: 0.5712 - val_loss: 0.6635 - val_mae: 0.6654 - val_mse: 0.6635
# Epoch 64/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5588 - mae: 0.6066 - mse: 0.5588 - val_loss: 0.6680 - val_mae: 0.6674 - val_mse: 0.6680
# Epoch 65/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5386 - mae: 0.5989 - mse: 0.5386 - val_loss: 0.6696 - val_mae: 0.6673 - val_mse: 0.6696
# Epoch 66/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5454 - mae: 0.5969 - mse: 0.5454 - val_loss: 0.6822 - val_mae: 0.6741 - val_mse: 0.6822
# Epoch 67/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5512 - mae: 0.5983 - mse: 0.5512 - val_loss: 0.7122 - val_mae: 0.6897 - val_mse: 0.7122
# Epoch 68/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5301 - mae: 0.5831 - mse: 0.5301 - val_loss: 0.6952 - val_mae: 0.6813 - val_mse: 0.6952
# Epoch 69/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5571 - mae: 0.6140 - mse: 0.5571 - val_loss: 0.6685 - val_mae: 0.6676 - val_mse: 0.6685
# Epoch 70/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5144 - mae: 0.5807 - mse: 0.5144 - val_loss: 0.6794 - val_mae: 0.6745 - val_mse: 0.6794
# Epoch 71/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5503 - mae: 0.5993 - mse: 0.5503 - val_loss: 0.6964 - val_mae: 0.6830 - val_mse: 0.6964
# Epoch 72/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5460 - mae: 0.6006 - mse: 0.5460 - val_loss: 0.6765 - val_mae: 0.6732 - val_mse: 0.6765
# Epoch 73/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5268 - mae: 0.5862 - mse: 0.5268 - val_loss: 0.6990 - val_mae: 0.6846 - val_mse: 0.6990
# Epoch 74/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5405 - mae: 0.5991 - mse: 0.5405 - val_loss: 0.7050 - val_mae: 0.6885 - val_mse: 0.7050
# Epoch 75/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5378 - mae: 0.5948 - mse: 0.5378 - val_loss: 0.7224 - val_mae: 0.6968 - val_mse: 0.7224
# Epoch 76/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5489 - mae: 0.5914 - mse: 0.5489 - val_loss: 0.6738 - val_mae: 0.6735 - val_mse: 0.6738
# Epoch 77/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5407 - mae: 0.5975 - mse: 0.5407 - val_loss: 0.6830 - val_mae: 0.6769 - val_mse: 0.6830
# Epoch 78/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5309 - mae: 0.5889 - mse: 0.5309 - val_loss: 0.6849 - val_mae: 0.6769 - val_mse: 0.6849
# Epoch 79/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5473 - mae: 0.6027 - mse: 0.5473 - val_loss: 0.6680 - val_mae: 0.6679 - val_mse: 0.6680
# Epoch 80/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4939 - mae: 0.5725 - mse: 0.4939 - val_loss: 0.6977 - val_mae: 0.6828 - val_mse: 0.6977
# Epoch 81/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5287 - mae: 0.5852 - mse: 0.5287 - val_loss: 0.6999 - val_mae: 0.6853 - val_mse: 0.6999
# Epoch 82/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5102 - mae: 0.5776 - mse: 0.5102 - val_loss: 0.6504 - val_mae: 0.6619 - val_mse: 0.6504
# Epoch 83/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5301 - mae: 0.5938 - mse: 0.5301 - val_loss: 0.6624 - val_mae: 0.6675 - val_mse: 0.6624
# Epoch 84/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5233 - mae: 0.5801 - mse: 0.5233 - val_loss: 0.6450 - val_mae: 0.6571 - val_mse: 0.6450
# Epoch 85/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5190 - mae: 0.5782 - mse: 0.5190 - val_loss: 0.6451 - val_mae: 0.6576 - val_mse: 0.6451
# Epoch 86/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5209 - mae: 0.5866 - mse: 0.5209 - val_loss: 0.6700 - val_mae: 0.6705 - val_mse: 0.6700
# Epoch 87/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5110 - mae: 0.5740 - mse: 0.5110 - val_loss: 0.6693 - val_mae: 0.6708 - val_mse: 0.6693
# Epoch 88/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5232 - mae: 0.5899 - mse: 0.5232 - val_loss: 0.6722 - val_mae: 0.6735 - val_mse: 0.6722
# Epoch 89/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5012 - mae: 0.5730 - mse: 0.5012 - val_loss: 0.6736 - val_mae: 0.6743 - val_mse: 0.6736
# Epoch 90/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5296 - mae: 0.5891 - mse: 0.5296 - val_loss: 0.6653 - val_mae: 0.6703 - val_mse: 0.6653
# Epoch 91/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4782 - mae: 0.5571 - mse: 0.4782 - val_loss: 0.6886 - val_mae: 0.6819 - val_mse: 0.6886
# Epoch 92/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5139 - mae: 0.5762 - mse: 0.5139 - val_loss: 0.6779 - val_mae: 0.6767 - val_mse: 0.6779
# Epoch 93/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5183 - mae: 0.5802 - mse: 0.5183 - val_loss: 0.6960 - val_mae: 0.6864 - val_mse: 0.6960
# Epoch 94/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5015 - mae: 0.5689 - mse: 0.5015 - val_loss: 0.6763 - val_mae: 0.6756 - val_mse: 0.6763
# Epoch 95/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5017 - mae: 0.5715 - mse: 0.5017 - val_loss: 0.6989 - val_mae: 0.6892 - val_mse: 0.6989
# Epoch 96/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5094 - mae: 0.5768 - mse: 0.5094 - val_loss: 0.7269 - val_mae: 0.7033 - val_mse: 0.7269
# Epoch 97/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4910 - mae: 0.5683 - mse: 0.4910 - val_loss: 0.6955 - val_mae: 0.6863 - val_mse: 0.6955
# Epoch 98/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4913 - mae: 0.5744 - mse: 0.4913 - val_loss: 0.6919 - val_mae: 0.6850 - val_mse: 0.6919
# Epoch 99/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4973 - mae: 0.5664 - mse: 0.4973 - val_loss: 0.6773 - val_mae: 0.6771 - val_mse: 0.6773
# Epoch 100/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4984 - mae: 0.5693 - mse: 0.4984 - val_loss: 0.7002 - val_mae: 0.6895 - val_mse: 0.7002

# %%
#Evaluating
test_loss, test_mae, test_mse = model2.evaluate(X_test, y_test)

print(f'Test Loss: {test_loss}')
print(f'Test MAE: {test_mae}')
print(f'Test MSE: {test_mse}')
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6042 - mae: 0.6341 - mse: 0.6042
# Test Loss: 0.6042442917823792
# Test MAE: 0.634082019329071
# Test MSE: 0.6042442917823792

# %%
#extracting relevant informationfrom the training history
train_loss =history2.history['loss']
val_loss = history2.history['val_loss']

#Plotting Traing and validation cures
plt.figure(figsize=(10,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and validation curves')
plt.show()

# %%
#making predictions
y_pred2 = model2.predict(X_test)
y_pred2_= y_pred2.flatten()
residual2 = y_test - y_pred2_
# Out:
# 12/12 [==============================] - 0s 3ms/step

# %%
#Plotting the Residual Plot
plt.figure(figsize=(8,6))
plt.scatter(y_pred2_, residual2,alpha=0.5)
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.grid(True)
plt.show()

# %%
#plotting a learning curve
hist_dict = history2.history
loss_values = hist_dict['loss']
val_loss_values = hist_dict["val_loss"]

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs,loss_values,'ro-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##**Model3**

# %%
#creating a neural network model for model3
input_layer = tf.keras.layers.Input(shape=(X_train.shape[1],))
hidden_layer1 = tf.keras.layers.Dense(64, activation='relu')(input_layer)
hidden_layer2 = tf.keras.layers.Dense(20, activation='relu')(hidden_layer1)
output_layer = tf.keras.layers.Dense(1, activation='linear',)(hidden_layer2)

model3 = tf.keras.Model(inputs=input_layer, outputs=output_layer)

# %%
#implementing Cross-validation
from sklearn.model_selection import KFold
from tensorflow.keras.optimizers import Adam

folds = 4
cross_val = KFold(n_splits=folds, shuffle=True, random_state=42)

i = 0

for train_index, test_index in cross_val.split(X_train, y_train):
  X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
  y_train_fold, y_test_fold = y_train.iloc[train_index],y_train.iloc[test_index]

 # optim = Adam(learning_rate=0.01)
  model3.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse','mae'])

  history3 = model3.fit(X_train_fold, y_train_fold, epochs=50, batch_size=150, validation_data=(X_test_fold, y_test_fold))

  score = model3.evaluate(X_test, y_test)
  i+=1
  print("Validation Scorefor fold {}: {}".format(i, score))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 51ms/step - loss: 0.0147 - mse: 0.0147 - mae: 0.0875 - val_loss: 0.0089 - val_mse: 0.0089 - val_mae: 0.0702
# Epoch 2/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0096 - mse: 0.0096 - mae: 0.0693 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0634
# Epoch 3/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0542 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0450
# Epoch 4/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0467 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0374
# Epoch 5/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0407 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0433
# Epoch 6/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0365 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0346
# Epoch 7/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0320 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0332
# Epoch 8/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0311 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0388
# Epoch 9/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0294 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0317
# Epoch 10/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0238 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0334
# Epoch 11/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0221 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0321
# Epoch 12/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0215 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0359
# Epoch 13/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0251 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0329
# Epoch 14/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0225 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0364
# Epoch 15/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0203 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0339
# Epoch 16/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0200 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0353
# Epoch 17/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0223 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0367
# Epoch 18/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0243 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0386
# Epoch 19/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0227 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0355
# Epoch 20/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0188 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0364
# Epoch 21/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0197 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0368
# Epoch 22/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0209 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0388
# Epoch 23/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0220 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0357
# Epoch 24/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0187 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0422
# Epoch 25/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0233 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0401
# Epoch 26/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0233 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0376
# Epoch 27/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0211 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0397
# Epoch 28/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0235 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0379
# Epoch 29/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0223 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0423
# Epoch 30/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0251 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0417
# Epoch 31/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0232 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0397
# Epoch 32/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0252 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0417
# Epoch 33/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0272 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0418
# Epoch 34/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0239 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0407
# Epoch 35/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0235 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0454
# Epoch 36/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0250 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0436
# Epoch 37/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0224 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0423
# Epoch 38/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0199 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0424
# Epoch 39/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0181 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0418
# Epoch 40/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0191 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0423
# Epoch 41/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0244 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0420
# Epoch 42/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0248 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0425
# Epoch 43/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0255 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0421
# Epoch 44/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0237 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0409
# Epoch 45/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0220 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0427
# Epoch 46/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0228 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0429
# Epoch 47/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0266 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0436
# Epoch 48/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0303 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0412
# Epoch 49/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0266 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0454
# Epoch 50/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0256 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0424
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3381 - mse: 1.3381 - mae: 0.9361
# Validation Scorefor fold 1: [1.338089108467102, 1.338089108467102, 0.9360881447792053]
# Epoch 1/50
# 5/5 [==============================] - 1s 60ms/step - loss: 0.0170 - mse: 0.0170 - mae: 0.0852 - val_loss: 0.0181 - val_mse: 0.0181 - val_mae: 0.1123
# Epoch 2/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0119 - mse: 0.0119 - mae: 0.0834 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0622
# Epoch 3/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0653 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0405
# Epoch 4/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0559 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0452
# Epoch 5/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0522 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0510
# Epoch 6/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0435 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0502
# Epoch 7/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0411 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0563
# Epoch 8/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0384 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0489
# Epoch 9/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0333 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0373
# Epoch 10/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0277 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0367
# Epoch 11/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0277 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0410
# Epoch 12/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0275 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0438
# Epoch 13/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0244 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0385
# Epoch 14/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0233 - val_loss: 0.0086 - val_mse: 0.0086 - val_mae: 0.0401
# Epoch 15/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0236 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0429
# Epoch 16/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0236 - val_loss: 0.0086 - val_mse: 0.0086 - val_mae: 0.0391
# Epoch 17/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0222 - val_loss: 0.0090 - val_mse: 0.0090 - val_mae: 0.0404
# Epoch 18/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0211 - val_loss: 0.0090 - val_mse: 0.0090 - val_mae: 0.0440
# Epoch 19/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0217 - val_loss: 0.0091 - val_mse: 0.0091 - val_mae: 0.0389
# Epoch 20/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0205 - val_loss: 0.0096 - val_mse: 0.0096 - val_mae: 0.0431
# Epoch 21/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0201 - val_loss: 0.0095 - val_mse: 0.0095 - val_mae: 0.0411
# Epoch 22/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0191 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0438
# Epoch 23/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0194 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0420
# Epoch 24/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0229 - val_loss: 0.0106 - val_mse: 0.0106 - val_mae: 0.0456
# Epoch 25/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0222 - val_loss: 0.0104 - val_mse: 0.0104 - val_mae: 0.0429
# Epoch 26/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0184 - val_loss: 0.0102 - val_mse: 0.0102 - val_mae: 0.0420
# Epoch 27/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0168 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0428
# Epoch 28/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0163 - val_loss: 0.0106 - val_mse: 0.0106 - val_mae: 0.0432
# Epoch 29/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0175 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0419
# Epoch 30/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0206 - val_loss: 0.0105 - val_mse: 0.0105 - val_mae: 0.0490
# Epoch 31/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0224 - val_loss: 0.0106 - val_mse: 0.0106 - val_mae: 0.0450
# Epoch 32/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0184 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0438
# Epoch 33/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0177 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0448
# Epoch 34/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0176 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0458
# Epoch 35/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0182 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0466
# Epoch 36/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0222 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0438
# Epoch 37/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0196 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0451
# Epoch 38/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0174 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0469
# Epoch 39/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0183 - val_loss: 0.0114 - val_mse: 0.0114 - val_mae: 0.0523
# Epoch 40/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0234 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0465
# Epoch 41/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0182 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0449
# Epoch 42/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0155 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0456
# Epoch 43/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0138 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0456
# Epoch 44/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0152 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0469
# Epoch 45/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0150 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0468
# Epoch 46/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0171 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0451
# Epoch 47/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0189 - val_loss: 0.0114 - val_mse: 0.0114 - val_mae: 0.0474
# Epoch 48/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0182 - val_loss: 0.0121 - val_mse: 0.0121 - val_mae: 0.0508
# Epoch 49/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0239 - val_loss: 0.0114 - val_mse: 0.0114 - val_mae: 0.0473
# Epoch 50/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0183 - val_loss: 0.0115 - val_mse: 0.0115 - val_mae: 0.0467
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3429 - mse: 1.3429 - mae: 0.9396
# Validation Scorefor fold 2: [1.342930793762207, 1.342930793762207, 0.9395920038223267]
# Epoch 1/50
# 5/5 [==============================] - 2s 50ms/step - loss: 0.0192 - mse: 0.0192 - mae: 0.1035 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0397
# Epoch 2/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0115 - mse: 0.0115 - mae: 0.0733 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0683
# Epoch 3/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0090 - mse: 0.0090 - mae: 0.0662 - val_loss: 0.0102 - val_mse: 0.0102 - val_mae: 0.0717
# Epoch 4/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0567 - val_loss: 0.0099 - val_mse: 0.0099 - val_mae: 0.0720
# Epoch 5/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0490 - val_loss: 0.0089 - val_mse: 0.0089 - val_mae: 0.0535
# Epoch 6/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0394 - val_loss: 0.0088 - val_mse: 0.0088 - val_mae: 0.0518
# Epoch 7/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0356 - val_loss: 0.0092 - val_mse: 0.0092 - val_mae: 0.0437
# Epoch 8/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0339 - val_loss: 0.0094 - val_mse: 0.0094 - val_mae: 0.0433
# Epoch 9/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0297 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0486
# Epoch 10/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0264 - val_loss: 0.0105 - val_mse: 0.0105 - val_mae: 0.0436
# Epoch 11/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0237 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0466
# Epoch 12/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0215 - val_loss: 0.0113 - val_mse: 0.0113 - val_mae: 0.0448
# Epoch 13/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0198 - val_loss: 0.0118 - val_mse: 0.0118 - val_mae: 0.0459
# Epoch 14/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0211 - val_loss: 0.0125 - val_mse: 0.0125 - val_mae: 0.0492
# Epoch 15/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0180 - val_loss: 0.0123 - val_mse: 0.0123 - val_mae: 0.0451
# Epoch 16/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0163 - val_loss: 0.0126 - val_mse: 0.0126 - val_mae: 0.0455
# Epoch 17/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0173 - val_loss: 0.0131 - val_mse: 0.0131 - val_mae: 0.0483
# Epoch 18/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0180 - val_loss: 0.0138 - val_mse: 0.0138 - val_mae: 0.0530
# Epoch 19/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0205 - val_loss: 0.0136 - val_mse: 0.0136 - val_mae: 0.0481
# Epoch 20/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0209 - val_loss: 0.0146 - val_mse: 0.0146 - val_mae: 0.0540
# Epoch 21/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0272 - val_loss: 0.0144 - val_mse: 0.0144 - val_mae: 0.0515
# Epoch 22/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0191 - val_loss: 0.0149 - val_mse: 0.0149 - val_mae: 0.0537
# Epoch 23/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0197 - val_loss: 0.0151 - val_mse: 0.0151 - val_mae: 0.0512
# Epoch 24/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0177 - val_loss: 0.0150 - val_mse: 0.0150 - val_mae: 0.0507
# Epoch 25/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0165 - val_loss: 0.0153 - val_mse: 0.0153 - val_mae: 0.0517
# Epoch 26/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0144 - val_loss: 0.0160 - val_mse: 0.0160 - val_mae: 0.0547
# Epoch 27/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0162 - val_loss: 0.0158 - val_mse: 0.0158 - val_mae: 0.0519
# Epoch 28/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0152 - val_loss: 0.0163 - val_mse: 0.0163 - val_mae: 0.0531
# Epoch 29/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0160 - val_loss: 0.0163 - val_mse: 0.0163 - val_mae: 0.0529
# Epoch 30/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0168 - val_loss: 0.0170 - val_mse: 0.0170 - val_mae: 0.0577
# Epoch 31/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0192 - val_loss: 0.0168 - val_mse: 0.0168 - val_mae: 0.0557
# Epoch 32/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0187 - val_loss: 0.0170 - val_mse: 0.0170 - val_mae: 0.0551
# Epoch 33/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0186 - val_loss: 0.0170 - val_mse: 0.0170 - val_mae: 0.0545
# Epoch 34/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0169 - val_loss: 0.0169 - val_mse: 0.0169 - val_mae: 0.0550
# Epoch 35/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0148 - val_loss: 0.0168 - val_mse: 0.0168 - val_mae: 0.0566
# Epoch 36/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0147 - val_loss: 0.0173 - val_mse: 0.0173 - val_mae: 0.0551
# Epoch 37/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0142 - val_loss: 0.0172 - val_mse: 0.0172 - val_mae: 0.0548
# Epoch 38/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0137 - val_loss: 0.0175 - val_mse: 0.0175 - val_mae: 0.0569
# Epoch 39/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0132 - val_loss: 0.0177 - val_mse: 0.0177 - val_mae: 0.0558
# Epoch 40/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0160 - val_loss: 0.0181 - val_mse: 0.0181 - val_mae: 0.0620
# Epoch 41/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0196 - val_loss: 0.0179 - val_mse: 0.0179 - val_mae: 0.0584
# Epoch 42/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0173 - val_loss: 0.0178 - val_mse: 0.0178 - val_mae: 0.0569
# Epoch 43/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0186 - val_loss: 0.0179 - val_mse: 0.0179 - val_mae: 0.0575
# Epoch 44/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0173 - val_loss: 0.0182 - val_mse: 0.0182 - val_mae: 0.0592
# Epoch 45/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0236 - val_loss: 0.0182 - val_mse: 0.0182 - val_mae: 0.0593
# Epoch 46/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0216 - val_loss: 0.0182 - val_mse: 0.0182 - val_mae: 0.0595
# Epoch 47/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0185 - val_loss: 0.0185 - val_mse: 0.0185 - val_mae: 0.0609
# Epoch 48/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0178 - val_loss: 0.0182 - val_mse: 0.0182 - val_mae: 0.0594
# Epoch 49/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0155 - val_loss: 0.0190 - val_mse: 0.0190 - val_mae: 0.0617
# Epoch 50/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0156 - val_loss: 0.0183 - val_mse: 0.0183 - val_mae: 0.0593
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3577 - mse: 1.3577 - mae: 0.9428
# Validation Scorefor fold 3: [1.3576996326446533, 1.3576996326446533, 0.9427584409713745]
# Epoch 1/50
# 5/5 [==============================] - 1s 55ms/step - loss: 0.0165 - mse: 0.0165 - mae: 0.0835 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0787
# Epoch 2/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0682 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0573
# Epoch 3/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0589 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0417
# Epoch 4/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0557 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0525
# Epoch 5/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0523 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0676
# Epoch 6/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0475 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0569
# Epoch 7/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0453 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0425
# Epoch 8/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0346 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0439
# Epoch 9/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0336 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0489
# Epoch 10/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0313 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0444
# Epoch 11/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0297 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0413
# Epoch 12/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0241 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0404
# Epoch 13/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0216 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0401
# Epoch 14/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0200 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0406
# Epoch 15/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0196 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0458
# Epoch 16/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0234 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0413
# Epoch 17/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0211 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0438
# Epoch 18/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0267 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0561
# Epoch 19/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0308 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0436
# Epoch 20/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0231 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0439
# Epoch 21/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0201 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0455
# Epoch 22/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0205 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0428
# Epoch 23/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0179 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0428
# Epoch 24/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0184 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0443
# Epoch 25/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0209 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0451
# Epoch 26/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0222 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0430
# Epoch 27/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0168 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0433
# Epoch 28/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0164 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0414
# Epoch 29/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0167 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0427
# Epoch 30/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0182 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0419
# Epoch 31/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0176 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0439
# Epoch 32/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0202 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0492
# Epoch 33/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0206 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0470
# Epoch 34/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0251 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0419
# Epoch 35/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0230 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0475
# Epoch 36/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0240 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0475
# Epoch 37/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0256 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0417
# Epoch 38/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0210 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0436
# Epoch 39/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0203 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0446
# Epoch 40/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0199 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0490
# Epoch 41/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0226 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0456
# Epoch 42/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0238 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0493
# Epoch 43/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0276 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0481
# Epoch 44/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0319 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0475
# Epoch 45/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0347 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0474
# Epoch 46/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0335 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0464
# Epoch 47/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0324 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0487
# Epoch 48/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0284 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0540
# Epoch 49/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0285 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0500
# Epoch 50/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0236 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0477
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3602 - mse: 1.3602 - mae: 0.9452
# Validation Scorefor fold 4: [1.3602015972137451, 1.3602015972137451, 0.9452422261238098]

# %%
test3_loss, test3_mse, test3_mae = model3.evaluate(X_test, y_test)

print(f'Test Loss: {test3_loss}')
print(f'Test MAE: {test3_mae}')
print(f'Test MSE: {test3_mse}')
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3602 - mse: 1.3602 - mae: 0.9452
# Test Loss: 1.3602015972137451
# Test MAE: 0.9452422261238098
# Test MSE: 1.3602015972137451

# %%
#extracting relevant informationfrom the training history
train_loss =history3.history['loss']
val_loss = history3.history['val_loss']

#Plotting Traing and validation cures
plt.figure(figsize=(10,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and validation curves')
plt.show()

# %%
#making predictions
y_pred3 = model3.predict(X_test)
y_pred3_= y_pred3.flatten()
residual3 = y_test - y_pred3_
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
#Plotting the Residual Plot
plt.figure(figsize=(8,6))
plt.scatter(y_pred3_, residual3,alpha=0.5)
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.grid(True)
plt.show()

# %%
#plotting a learning curve
hist_dict = history3.history
loss_values = hist_dict['loss']
val_loss_values = hist_dict["val_loss"]

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs,loss_values,'ro-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
