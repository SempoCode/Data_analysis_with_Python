# %% [markdown]
# #Data loading and Preparation

# %%
#Importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
#Loading data
path = '/content/4A_cleaned_7.xlsx'
data =pd.read_excel(path)
data.head(2)
# Out:
#   IP NUMBER UNIT SEX  AGE MARITAL STATUS RELIGION DISTRICT OF RESIDENCE  \
# 0   1861416   GI   M   30              2      COU           Nakasongola
# 1   1868011   GI   F   46              2      COU               Kampala
#
#     REGION                 WORKING DIAGNOSIS ADDITIONAL WORKING DIAGNOSIS  \
# 0  CENTRAL                ISS,Abdominal TB,,                        ISS,,
# 1  CENTRAL  ISS Stage I&II,Disseminated TB,,             ISS Stage I&II,,
#
#    NUMBER OF ADDITIONAL WORKING DIAGNOSIS          TB_type  \
# 0                                       1     Abdominal_TB
# 1                                       1  Disseminated TB
#
#    NUMBER OF PREVIOUS ADMISSIONS DAY OF ADMISSION MONTH OF ADMISSION  \
# 0                              5          Tuesday           November
# 1                              3           Monday           December
#
#    YEAR OF ADMISSION  DURATION  OUT COME
# 0               2010         5  IMPROVED
# 1               2010         3  IMPROVED

# %%
data['TB_type'].unique()
# Out:
# array(['Abdominal_TB', 'Disseminated TB', 'PTB', 'Other TBs', 'CNS_TB',
#        'TB iris'], dtype=object)

# %% [markdown]
# ##**Preparing data**

# %%
data.dropna(subset=['NUMBER OF PREVIOUS ADMISSIONS'], inplace=True)
data.dropna(subset=['IP NUMBER'], inplace=True)

data = data[data['IP NUMBER']  != 'a' ]
data = data[data['IP NUMBER']  != 'vf' ]

# %%
data.shape
# Out:
# (4034, 18)

# %%
#data.to_excel('final_cleaned_TB-4a.xlsx', index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4034 entries, 0 to 4033
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   IP NUMBER                               4034 non-null   object
#  1   UNIT                                    4034 non-null   object
#  2   SEX                                     4034 non-null   object
#  3   AGE                                     4034 non-null   int64
#  4   MARITAL STATUS                          4031 non-null   object
#  5   RELIGION                                4034 non-null   object
#  6   DISTRICT OF RESIDENCE                   4034 non-null   object
#  7   REGION                                  4034 non-null   object
#  8   WORKING DIAGNOSIS                       4034 non-null   object
#  9   ADDITIONAL WORKING DIAGNOSIS            3854 non-null   object
#  10  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  4034 non-null   int64
#  11  TB_type                                 4034 non-null   object
#  12  NUMBER OF PREVIOUS ADMISSIONS           4034 non-null   int64
#  13  DAY OF ADMISSION                        4034 non-null   object
#  14  MONTH OF ADMISSION                      4034 non-null   object
#  15  YEAR OF ADMISSION                       4034 non-null   int64
#  16  DURATION                                4034 non-null   int64
#  17  OUT COME                                4034 non-null   object
# dtypes: int64(5), object(13)
# memory usage: 598.8+ KB

# %%
#filtering out only patients with "DIED" outcome
data = data[data['OUT COME'] == 'DIED']

# %%
#Deleting features which are not going to be used
features_to_remove = ['IP NUMBER', 'UNIT','YEAR OF ADMISSION','DISTRICT OF RESIDENCE','WORKING DIAGNOSIS' ,'ADDITIONAL WORKING DIAGNOSIS',
                'MARITAL STATUS']
data = data.drop(columns = features_to_remove)

# %%
non_features = ['OUT COME']
data1 = data.drop(columns=non_features)

# %% [markdown]
# #**Data Preprocessing**

# %%
#filtering out only patients with "DIED" outcome
data = data[data['OUT COME'] == 'DIED']

# %%
#data['YEAR OF ADMISSION'] = data['YEAR OF ADMISSION'].astype(str)

# %%
#Encoding categorical features
non_features = ['DURATION', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS','AGE','NUMBER OF PREVIOUS ADMISSIONS']
data1 = data.drop(columns=non_features)

text_columns = data1.select_dtypes(include=['object']).columns

data2 = pd.get_dummies(data, columns=text_columns)

# %%
data2['NUMBER OF PREVIOUS ADMISSIONS'].unique()
# Out:
# array([ 2,  4,  5,  1,  7,  6,  9, 20, 11, 13,  3,  8, 15, 14, 10, 18, 16,
#        22, 21, 25, 12, 26, 23, 92,  0])

# %%
data2['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'] = data2['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'].astype(float)
data2['AGE'] = data2['AGE'].astype(float)

# %%
data2.sample(4)
# Out:
#        AGE  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  \
# 1787  40.0                                     2.0
# 1255  40.0                                     1.0
# 648   41.0                                     1.0
# 1954  53.0                                     1.0
#
#       NUMBER OF PREVIOUS ADMISSIONS  DURATION  SEX_F  SEX_M  \
# 1787                              0         3      1      0
# 1255                              0         3      1      0
# 648                              14        13      1      0
# 1954                              0         4      0      1
#
#       RELIGION_CATHOLIC  RELIGION_COU  RELIGION_ISLAM  RELIGION_OTHERS  ...  \
# 1787                  1             0               0                0  ...
# 1255                  0             0               0                1  ...
# 648                   0             1               0                0  ...
# 1954                  0             1               0                0  ...
#
#       MONTH OF ADMISSION_February  MONTH OF ADMISSION_January  \
# 1787                            0                           0
# 1255                            0                           0
# 648                             0                           0
# 1954                            0                           0
#
#       MONTH OF ADMISSION_July  MONTH OF ADMISSION_June  \
# 1787                        0                        0
# 1255                        0                        0
# 648                         0                        0
# 1954                        0                        0
#
#       MONTH OF ADMISSION_March  MONTH OF ADMISSION_May  \
# 1787                         0                       0
# 1255                         0                       0
# 648                          0                       0
# 1954                         0                       0
#
#       MONTH OF ADMISSION_November  MONTH OF ADMISSION_October  \
# 1787                            0                           0
# 1255                            0                           0
# 648                             0                           0
# 1954                            0                           0
#
#       MONTH OF ADMISSION_September  OUT COME_DIED
# 1787                             1              1
# 1255                             0              1
# 648                              1              1
# 1954                             0              1
#
# [4 rows x 42 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291 entries, 5 to 4030
# Data columns (total 42 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   AGE                                     1291 non-null   float64
#  1   NUMBER OF ADDITIONAL WORKING DIAGNOSIS  1291 non-null   float64
#  2   NUMBER OF PREVIOUS ADMISSIONS           1291 non-null   int64
#  3   DURATION                                1291 non-null   int64
#  4   SEX_F                                   1291 non-null   uint8
#  5   SEX_M                                   1291 non-null   uint8
#  6   RELIGION_CATHOLIC                       1291 non-null   uint8
#  7   RELIGION_COU                            1291 non-null   uint8
#  8   RELIGION_ISLAM                          1291 non-null   uint8
#  9   RELIGION_OTHERS                         1291 non-null   uint8
#  10  RELIGION_PENTECOSTAL                    1291 non-null   uint8
#  11  REGION_CENTRAL                          1291 non-null   uint8
#  12  REGION_EASTERN                          1291 non-null   uint8
#  13  REGION_NORTHERN                         1291 non-null   uint8
#  14  REGION_UNKNOWN                          1291 non-null   uint8
#  15  REGION_WESTERN                          1291 non-null   uint8
#  16  TB_type_Abdominal_TB                    1291 non-null   uint8
#  17  TB_type_CNS_TB                          1291 non-null   uint8
#  18  TB_type_Disseminated TB                 1291 non-null   uint8
#  19  TB_type_Other TBs                       1291 non-null   uint8
#  20  TB_type_PTB                             1291 non-null   uint8
#  21  TB_type_TB iris                         1291 non-null   uint8
#  22  DAY OF ADMISSION_Friday                 1291 non-null   uint8
#  23  DAY OF ADMISSION_Monday                 1291 non-null   uint8
#  24  DAY OF ADMISSION_Saturday               1291 non-null   uint8
#  25  DAY OF ADMISSION_Sunday                 1291 non-null   uint8
#  26  DAY OF ADMISSION_Thursday               1291 non-null   uint8
#  27  DAY OF ADMISSION_Tuesday                1291 non-null   uint8
#  28  DAY OF ADMISSION_Wednesday              1291 non-null   uint8
#  29  MONTH OF ADMISSION_April                1291 non-null   uint8
#  30  MONTH OF ADMISSION_August               1291 non-null   uint8
#  31  MONTH OF ADMISSION_December             1291 non-null   uint8
#  32  MONTH OF ADMISSION_February             1291 non-null   uint8
#  33  MONTH OF ADMISSION_January              1291 non-null   uint8
#  34  MONTH OF ADMISSION_July                 1291 non-null   uint8
#  35  MONTH OF ADMISSION_June                 1291 non-null   uint8
#  36  MONTH OF ADMISSION_March                1291 non-null   uint8
#  37  MONTH OF ADMISSION_May                  1291 non-null   uint8
#  38  MONTH OF ADMISSION_November             1291 non-null   uint8
#  39  MONTH OF ADMISSION_October              1291 non-null   uint8
#  40  MONTH OF ADMISSION_September            1291 non-null   uint8
#  41  OUT COME_DIED                           1291 non-null   uint8
# dtypes: float64(2), int64(2), uint8(38)
# memory usage: 98.3 KB

# %%
from scipy.stats import skew
import seaborn as sns

#Visualizing skeness of the continuous features
continuous_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS','DURATION']
for col in continuous_features:
  print(col)
  print(skew(data2[col]))

  plt.figure()
  sns.distplot(data2[col])
  plt.show()
# Out:
# AGE
# 0.9509241869210756
# <ipython-input-628-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])
# NUMBER OF PREVIOUS ADMISSIONS
# 9.760011787542462
# <ipython-input-628-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])
# NUMBER OF ADDITIONAL WORKING DIAGNOSIS
# 0.47741907750448015
# <ipython-input-628-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])
# DURATION
# 1.4581473673442764
# <ipython-input-628-2ebe16f7c6fb>:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2[col])

# %%
#Visualizing Correlation among the continuous features nluding the target
continuous_features_target = ['AGE','NUMBER OF PREVIOUS ADMISSIONS', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS', 'DURATION']
plt.figure(figsize=(12,4))
sns.heatmap(data2[continuous_features_target].corr(), annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Heatmap of continuous Features Correlation')
plt.show()

# %%
#Transforming the continuous features
transform_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS', 'NUMBER OF ADDITIONAL WORKING DIAGNOSIS','DURATION']
for col in transform_features:
  data2[col] = np.log1p(data2[col])

#Second transformation
data2['NUMBER OF PREVIOUS ADMISSIONS'] = np.log1p(data2['NUMBER OF PREVIOUS ADMISSIONS'])
data2['DURATION'] = np.log1p(data2['DURATION'])
data2['DURATION'] = np.log1p(data2['DURATION'])

# %%
#Normalizing and Standardizing continuous features
normalise_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS','NUMBER OF ADDITIONAL WORKING DIAGNOSIS']
scaler = MinMaxScaler()
data2[normalise_features] = scaler.fit_transform(data2[normalise_features])

# %%
#Plotting Density plot
import seaborn as sns

continuous_features = ['AGE','NUMBER OF PREVIOUS ADMISSIONS','NUMBER OF ADDITIONAL WORKING DIAGNOSIS','DURATION']

fig, axes = plt.subplots(1, len(continuous_features), figsize=(15, 5))

for i, col in enumerate(continuous_features):
  sns.kdeplot(data[col], fill=True,ax=axes[i])
  axes[i].set_title(f'Density Plot for {col}')
  axes[i].set_xlabel('Values')
  axes[i].set_ylabel('Density')
# plt.figure(figsize=(8,9))
# plt.bar(data['AGE'])
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data2.head(2)
# Out:
#         AGE  NUMBER OF ADDITIONAL WORKING DIAGNOSIS  \
# 5  0.304489                                0.386853
# 6  0.160370                                0.613147
#
#    NUMBER OF PREVIOUS ADMISSIONS  DURATION  SEX_F  SEX_M  RELIGION_CATHOLIC  \
# 5                       0.433328  0.554618      1      0                  1
# 6                       0.560682  0.672503      1      0                  1
#
#    RELIGION_COU  RELIGION_ISLAM  RELIGION_OTHERS  ...  \
# 5             0               0                0  ...
# 6             0               0                0  ...
#
#    MONTH OF ADMISSION_February  MONTH OF ADMISSION_January  \
# 5                            0                           1
# 6                            0                           1
#
#    MONTH OF ADMISSION_July  MONTH OF ADMISSION_June  MONTH OF ADMISSION_March  \
# 5                        0                        0                         0
# 6                        0                        0                         0
#
#    MONTH OF ADMISSION_May  MONTH OF ADMISSION_November  \
# 5                       0                            0
# 6                       0                            0
#
#    MONTH OF ADMISSION_October  MONTH OF ADMISSION_September  OUT COME_DIED
# 5                           0                             0              1
# 6                           0                             0              1
#
# [2 rows x 42 columns]

# %%
data2['NUMBER OF ADDITIONAL WORKING DIAGNOSIS'].unique()
# Out:
# array([0.38685281, 0.61314719, 0.77370561, 1.        , 0.8982444 ,
#        0.        ])

# %%
data2.shape
# Out:
# (1291, 42)

# %%
#Saving Preprocced data
#data.to_excel('preprocessed1_TB-4a.xlsx', index=False)

# %%
#extracting features and targets

X = data2.drop(columns=continuous_features).values
y = data2['DURATION'].values

#Splitting data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %% [markdown]
# #**MODEL TRAINING (Tensorflow)**

# %% [markdown]
# ##**Libraries and architecture**

# %%
import tensorflow as tf
from tensorflow import keras

import torch
import torch.optim as optim

tf.random.set_seed(42)

# %%
n_neurons = X_train.shape[1] / 2
#neural network Architecture(ANN)
model1 = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(19, activation='sigmoid',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(6, activation='sigmoid',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(3, activation='sigmoid',kernel_initializer='he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='linear')
])

#custome loss function
def custom_mse(y_true, y_pred):
  return tf.reduce_mean(tf.square(y_true - y_pred))


model1.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae','mse'] )
model1.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_115 (Dense)           (None, 19)                741
#
#  batch_normalization_93 (Ba  (None, 19)                76
#  tchNormalization)
#
#  dropout_93 (Dropout)        (None, 19)                0
#
#  dense_116 (Dense)           (None, 6)                 120
#
#  batch_normalization_94 (Ba  (None, 6)                 24
#  tchNormalization)
#
#  dropout_94 (Dropout)        (None, 6)                 0
#
#  dense_117 (Dense)           (None, 3)                 21
#
#  batch_normalization_95 (Ba  (None, 3)                 12
#  tchNormalization)
#
#  dropout_95 (Dropout)        (None, 3)                 0
#
#  dense_118 (Dense)           (None, 1)                 4
#
# =================================================================
# Total params: 998 (3.90 KB)
# Trainable params: 942 (3.68 KB)
# Non-trainable params: 56 (224.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##Training, Evaluation and visualiztion

# %%
#model1 training and validation
history1 = model1.fit(X_train, y_train, epochs=80, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/80
# 26/26 [==============================] - 2s 9ms/step - loss: 3.8280 - mae: 1.5331 - mse: 3.8280 - val_loss: 0.7065 - val_mae: 0.8219 - val_mse: 0.7065
# Epoch 2/80
# 26/26 [==============================] - 0s 3ms/step - loss: 3.3345 - mae: 1.4236 - mse: 3.3345 - val_loss: 0.5565 - val_mae: 0.7244 - val_mse: 0.5565
# Epoch 3/80
# 26/26 [==============================] - 0s 2ms/step - loss: 2.8662 - mae: 1.3593 - mse: 2.8662 - val_loss: 0.4452 - val_mae: 0.6431 - val_mse: 0.4452
# Epoch 4/80
# 26/26 [==============================] - 0s 3ms/step - loss: 2.5902 - mae: 1.2874 - mse: 2.5902 - val_loss: 0.3751 - val_mae: 0.5864 - val_mse: 0.3751
# Epoch 5/80
# 26/26 [==============================] - 0s 3ms/step - loss: 2.1283 - mae: 1.1571 - mse: 2.1283 - val_loss: 0.3058 - val_mae: 0.5240 - val_mse: 0.3058
# Epoch 6/80
# 26/26 [==============================] - 0s 2ms/step - loss: 1.8318 - mae: 1.0984 - mse: 1.8318 - val_loss: 0.2504 - val_mae: 0.4661 - val_mse: 0.2504
# Epoch 7/80
# 26/26 [==============================] - 0s 3ms/step - loss: 1.8257 - mae: 1.1037 - mse: 1.8257 - val_loss: 0.2216 - val_mae: 0.4299 - val_mse: 0.2216
# Epoch 8/80
# 26/26 [==============================] - 0s 3ms/step - loss: 1.4843 - mae: 0.9940 - mse: 1.4843 - val_loss: 0.1971 - val_mae: 0.3963 - val_mse: 0.1971
# Epoch 9/80
# 26/26 [==============================] - 0s 3ms/step - loss: 1.3495 - mae: 0.9514 - mse: 1.3495 - val_loss: 0.1759 - val_mae: 0.3646 - val_mse: 0.1759
# Epoch 10/80
# 26/26 [==============================] - 0s 2ms/step - loss: 1.1787 - mae: 0.8931 - mse: 1.1787 - val_loss: 0.1524 - val_mae: 0.3304 - val_mse: 0.1524
# Epoch 11/80
# 26/26 [==============================] - 0s 3ms/step - loss: 1.1071 - mae: 0.8585 - mse: 1.1071 - val_loss: 0.1399 - val_mae: 0.3118 - val_mse: 0.1399
# Epoch 12/80
# 26/26 [==============================] - 0s 3ms/step - loss: 1.0594 - mae: 0.8485 - mse: 1.0594 - val_loss: 0.1297 - val_mae: 0.2971 - val_mse: 0.1297
# Epoch 13/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9454 - mae: 0.7902 - mse: 0.9454 - val_loss: 0.1191 - val_mae: 0.2819 - val_mse: 0.1191
# Epoch 14/80
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8213 - mae: 0.7414 - mse: 0.8213 - val_loss: 0.1102 - val_mae: 0.2700 - val_mse: 0.1102
# Epoch 15/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.7642 - mae: 0.7180 - mse: 0.7642 - val_loss: 0.1043 - val_mae: 0.2624 - val_mse: 0.1043
# Epoch 16/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7264 - mae: 0.6983 - mse: 0.7264 - val_loss: 0.0989 - val_mae: 0.2554 - val_mse: 0.0989
# Epoch 17/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6396 - mae: 0.6479 - mse: 0.6396 - val_loss: 0.0927 - val_mae: 0.2470 - val_mse: 0.0927
# Epoch 18/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6592 - mae: 0.6752 - mse: 0.6592 - val_loss: 0.0862 - val_mae: 0.2375 - val_mse: 0.0862
# Epoch 19/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.5979 - mae: 0.6466 - mse: 0.5979 - val_loss: 0.0794 - val_mae: 0.2278 - val_mse: 0.0794
# Epoch 20/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5923 - mae: 0.6445 - mse: 0.5923 - val_loss: 0.0725 - val_mae: 0.2174 - val_mse: 0.0725
# Epoch 21/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.4941 - mae: 0.5855 - mse: 0.4941 - val_loss: 0.0678 - val_mae: 0.2098 - val_mse: 0.0678
# Epoch 22/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.4936 - mae: 0.5839 - mse: 0.4936 - val_loss: 0.0635 - val_mae: 0.2027 - val_mse: 0.0635
# Epoch 23/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.4344 - mae: 0.5390 - mse: 0.4344 - val_loss: 0.0598 - val_mae: 0.1967 - val_mse: 0.0598
# Epoch 24/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.4298 - mae: 0.5435 - mse: 0.4298 - val_loss: 0.0570 - val_mae: 0.1922 - val_mse: 0.0570
# Epoch 25/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3932 - mae: 0.5178 - mse: 0.3932 - val_loss: 0.0548 - val_mae: 0.1890 - val_mse: 0.0548
# Epoch 26/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.4040 - mae: 0.5382 - mse: 0.4040 - val_loss: 0.0531 - val_mae: 0.1860 - val_mse: 0.0531
# Epoch 27/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3408 - mae: 0.4887 - mse: 0.3408 - val_loss: 0.0516 - val_mae: 0.1831 - val_mse: 0.0516
# Epoch 28/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3248 - mae: 0.4755 - mse: 0.3248 - val_loss: 0.0494 - val_mae: 0.1788 - val_mse: 0.0494
# Epoch 29/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3321 - mae: 0.4855 - mse: 0.3321 - val_loss: 0.0486 - val_mae: 0.1773 - val_mse: 0.0486
# Epoch 30/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3046 - mae: 0.4532 - mse: 0.3046 - val_loss: 0.0470 - val_mae: 0.1737 - val_mse: 0.0470
# Epoch 31/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2842 - mae: 0.4378 - mse: 0.2842 - val_loss: 0.0448 - val_mae: 0.1687 - val_mse: 0.0448
# Epoch 32/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2802 - mae: 0.4372 - mse: 0.2802 - val_loss: 0.0443 - val_mae: 0.1678 - val_mse: 0.0443
# Epoch 33/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.2641 - mae: 0.4289 - mse: 0.2641 - val_loss: 0.0421 - val_mae: 0.1632 - val_mse: 0.0421
# Epoch 34/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.2618 - mae: 0.4258 - mse: 0.2618 - val_loss: 0.0405 - val_mae: 0.1596 - val_mse: 0.0405
# Epoch 35/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.2379 - mae: 0.4035 - mse: 0.2379 - val_loss: 0.0389 - val_mae: 0.1557 - val_mse: 0.0389
# Epoch 36/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.2282 - mae: 0.3932 - mse: 0.2282 - val_loss: 0.0384 - val_mae: 0.1546 - val_mse: 0.0384
# Epoch 37/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.2187 - mae: 0.3916 - mse: 0.2187 - val_loss: 0.0382 - val_mae: 0.1543 - val_mse: 0.0382
# Epoch 38/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.2084 - mae: 0.3831 - mse: 0.2084 - val_loss: 0.0376 - val_mae: 0.1528 - val_mse: 0.0376
# Epoch 39/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1948 - mae: 0.3636 - mse: 0.1948 - val_loss: 0.0378 - val_mae: 0.1529 - val_mse: 0.0378
# Epoch 40/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1827 - mae: 0.3543 - mse: 0.1827 - val_loss: 0.0377 - val_mae: 0.1525 - val_mse: 0.0377
# Epoch 41/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1676 - mae: 0.3404 - mse: 0.1676 - val_loss: 0.0373 - val_mae: 0.1515 - val_mse: 0.0373
# Epoch 42/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1677 - mae: 0.3392 - mse: 0.1677 - val_loss: 0.0368 - val_mae: 0.1501 - val_mse: 0.0368
# Epoch 43/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1525 - mae: 0.3222 - mse: 0.1525 - val_loss: 0.0362 - val_mae: 0.1486 - val_mse: 0.0362
# Epoch 44/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1484 - mae: 0.3176 - mse: 0.1484 - val_loss: 0.0356 - val_mae: 0.1469 - val_mse: 0.0356
# Epoch 45/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1463 - mae: 0.3164 - mse: 0.1463 - val_loss: 0.0358 - val_mae: 0.1477 - val_mse: 0.0358
# Epoch 46/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1465 - mae: 0.3177 - mse: 0.1465 - val_loss: 0.0363 - val_mae: 0.1489 - val_mse: 0.0363
# Epoch 47/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1356 - mae: 0.3034 - mse: 0.1356 - val_loss: 0.0358 - val_mae: 0.1476 - val_mse: 0.0358
# Epoch 48/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1282 - mae: 0.2948 - mse: 0.1282 - val_loss: 0.0356 - val_mae: 0.1467 - val_mse: 0.0356
# Epoch 49/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1234 - mae: 0.2830 - mse: 0.1234 - val_loss: 0.0351 - val_mae: 0.1455 - val_mse: 0.0351
# Epoch 50/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1140 - mae: 0.2772 - mse: 0.1140 - val_loss: 0.0351 - val_mae: 0.1452 - val_mse: 0.0351
# Epoch 51/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1106 - mae: 0.2723 - mse: 0.1106 - val_loss: 0.0354 - val_mae: 0.1459 - val_mse: 0.0354
# Epoch 52/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1156 - mae: 0.2805 - mse: 0.1156 - val_loss: 0.0353 - val_mae: 0.1456 - val_mse: 0.0353
# Epoch 53/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1057 - mae: 0.2700 - mse: 0.1057 - val_loss: 0.0348 - val_mae: 0.1437 - val_mse: 0.0348
# Epoch 54/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0987 - mae: 0.2568 - mse: 0.0987 - val_loss: 0.0343 - val_mae: 0.1423 - val_mse: 0.0343
# Epoch 55/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0973 - mae: 0.2544 - mse: 0.0973 - val_loss: 0.0338 - val_mae: 0.1412 - val_mse: 0.0338
# Epoch 56/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1044 - mae: 0.2620 - mse: 0.1044 - val_loss: 0.0333 - val_mae: 0.1401 - val_mse: 0.0333
# Epoch 57/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0895 - mae: 0.2443 - mse: 0.0895 - val_loss: 0.0332 - val_mae: 0.1400 - val_mse: 0.0332
# Epoch 58/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0880 - mae: 0.2437 - mse: 0.0880 - val_loss: 0.0328 - val_mae: 0.1387 - val_mse: 0.0328
# Epoch 59/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0793 - mae: 0.2292 - mse: 0.0793 - val_loss: 0.0325 - val_mae: 0.1379 - val_mse: 0.0325
# Epoch 60/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0848 - mae: 0.2364 - mse: 0.0848 - val_loss: 0.0324 - val_mae: 0.1375 - val_mse: 0.0324
# Epoch 61/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0771 - mae: 0.2269 - mse: 0.0771 - val_loss: 0.0324 - val_mae: 0.1376 - val_mse: 0.0324
# Epoch 62/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0852 - mae: 0.2349 - mse: 0.0852 - val_loss: 0.0324 - val_mae: 0.1371 - val_mse: 0.0324
# Epoch 63/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0769 - mae: 0.2215 - mse: 0.0769 - val_loss: 0.0324 - val_mae: 0.1371 - val_mse: 0.0324
# Epoch 64/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0740 - mae: 0.2195 - mse: 0.0740 - val_loss: 0.0322 - val_mae: 0.1361 - val_mse: 0.0322
# Epoch 65/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0694 - mae: 0.2100 - mse: 0.0694 - val_loss: 0.0323 - val_mae: 0.1365 - val_mse: 0.0323
# Epoch 66/80
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0696 - mae: 0.2079 - mse: 0.0696 - val_loss: 0.0327 - val_mae: 0.1379 - val_mse: 0.0327
# Epoch 67/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0644 - mae: 0.2041 - mse: 0.0644 - val_loss: 0.0326 - val_mae: 0.1375 - val_mse: 0.0326
# Epoch 68/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0629 - mae: 0.2001 - mse: 0.0629 - val_loss: 0.0323 - val_mae: 0.1367 - val_mse: 0.0323
# Epoch 69/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0626 - mae: 0.2008 - mse: 0.0626 - val_loss: 0.0323 - val_mae: 0.1365 - val_mse: 0.0323
# Epoch 70/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0595 - mae: 0.1994 - mse: 0.0595 - val_loss: 0.0322 - val_mae: 0.1359 - val_mse: 0.0322
# Epoch 71/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0595 - mae: 0.1962 - mse: 0.0595 - val_loss: 0.0320 - val_mae: 0.1349 - val_mse: 0.0320
# Epoch 72/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0590 - mae: 0.1951 - mse: 0.0590 - val_loss: 0.0322 - val_mae: 0.1354 - val_mse: 0.0322
# Epoch 73/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0561 - mae: 0.1905 - mse: 0.0561 - val_loss: 0.0322 - val_mae: 0.1354 - val_mse: 0.0322
# Epoch 74/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0522 - mae: 0.1830 - mse: 0.0522 - val_loss: 0.0321 - val_mae: 0.1351 - val_mse: 0.0321
# Epoch 75/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0514 - mae: 0.1825 - mse: 0.0514 - val_loss: 0.0317 - val_mae: 0.1329 - val_mse: 0.0317
# Epoch 76/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0510 - mae: 0.1776 - mse: 0.0510 - val_loss: 0.0315 - val_mae: 0.1326 - val_mse: 0.0315
# Epoch 77/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0514 - mae: 0.1800 - mse: 0.0514 - val_loss: 0.0317 - val_mae: 0.1328 - val_mse: 0.0317
# Epoch 78/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0507 - mae: 0.1785 - mse: 0.0507 - val_loss: 0.0318 - val_mae: 0.1327 - val_mse: 0.0318
# Epoch 79/80
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0503 - mae: 0.1751 - mse: 0.0503 - val_loss: 0.0317 - val_mae: 0.1324 - val_mse: 0.0317
# Epoch 80/80
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0467 - mae: 0.1697 - mse: 0.0467 - val_loss: 0.0315 - val_mae: 0.1320 - val_mse: 0.0315

# %%
predictions = model1.predict(X_test)
mse = custom_mse(y_test, predictions)
print("Test Mean Squared Error:", mse)
# Out:
# 9/9 [==============================] - 0s 1ms/step
# Test Mean Squared Error: tf.Tensor(0.0331827406529489, shape=(), dtype=float64)

# %%
#Evaluating the model's performance
test_loss, test_mae, test_mse = model1.evaluate(X_test, y_test)

print(f'Test Loss: {test_loss}')
print(f'Test MAE: {test_mae}')
print(f'Test MSE: {test_mse}')
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0343 - mae: 0.1301 - mse: 0.0343
# Test Loss: 0.034267038106918335
# Test MAE: 0.13011662662029266
# Test MSE: 0.034267038106918335

# %%
#extracting relevant informationfrom the training history
train_loss =history1.history['loss']
val_loss = history1.history['val_loss']

#Plotting Traing and validation cures
plt.figure(figsize=(10,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and validation curves')
plt.show()

# %%
#making predictions
y_pred1 = model1.predict(X_test)

#Changing the shape of the results and getting the loss
y_pred1_= y_pred1.flatten()
residual1 = y_test - y_pred1_
# Out:
# 9/9 [==============================] - 0s 1ms/step

# %%
#Plotting the Residual Plot
plt.figure(figsize=(8,6))
plt.scatter(y_pred1_, residual1,alpha=0.5)
plt.title('Residual Plot 1')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.grid(True)
plt.show()

# %%
#plotting a learning curve
hist_dict = history1.history
loss_values = hist_dict['loss']
val_loss_values = hist_dict["val_loss"]

epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs,loss_values,'ro-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #**Model Training (PyTorch)**

# %% [markdown]
# ##Library and data

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %%
# Converting data to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %% [markdown]
# ##Architecture

# %%
# Define your regression model
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        self.fc1 = nn.Linear(38, 10)
        self.fc2 = nn.Linear(10, 6)
        self.fc3 = nn.Linear(6, 3)
        self.fc4 = nn.Linear(3, 1)

    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# Defining the custom mean absolute error loss function
def custom_mean_absolute_error(y_true, y_pred):
    diff = torch.abs(y_true - y_pred)
    return torch.mean(diff)

# Defining the custom mean squared error loss function
def custom_mean_squared_error(y_true, y_pred):
    diff = y_true - y_pred
    return torch.mean(torch.square(diff))

# %% [markdown]
# ##**Model**

# %%
model = MyModel()

# First, compiling the model with the Adam optimizer
adam_optimizer = optim.Adam(model.parameters(), lr=0.001)
adam_loss_fn = custom_mean_squared_error

# Training loop with Adam optimization
for epoch in range(10):
    adam_optimizer.zero_grad()
    y_pred = model(X_train)
    adam_loss = adam_loss_fn(y_train, y_pred)
    adam_loss.backward()
    adam_optimizer.step()

# Making predictions using the Adam-trained model
y_pred_adam = model(X_test)

# Calculating the test loss with MSE
mse_adam = custom_mean_squared_error(y_test, y_pred_adam)
print(f"Test MSE with Adam: {mse_adam:.4f}")

# Calculating the test loss with Mean Absolute Error (MAE)
mae_adam = custom_mean_absolute_error(y_test, y_pred_adam)
print(f"Test MAE with Adam: {mae_adam:.4f}")
# Out:
# Test MSE with Adam: 1.0592
# Test MAE with Adam: 1.0137

# %% [markdown]
# ##Fine tuning

# %%
# Creating an optimizer using L-BFGS
lbfgs_optimizer = optim.LBFGS(model.parameters(), max_iter=20, history_size=100)
lbfgs_loss_fn = custom_mean_squared_error

# Fine-tuning the model with L-BFGS optimization
def closure():
    lbfgs_optimizer.zero_grad()
    y_pred = model(X_train)
    lbfgs_loss = lbfgs_loss_fn(y_train, y_pred)
    lbfgs_loss.backward()
    return lbfgs_loss

for i in range(10):
    lbfgs_optimizer.step(closure)

# Making predictions using the L-BFGS fine-tuned model
y_pred_lbfgs = model(X_test)

# Calculating the test loss with Mean Absolute Error (MAE)
mse_lbfgs = custom_mean_squared_error(y_test, y_pred_lbfgs)
print(f"Test MSE with L-BFGS: {mse_lbfgs:.4f}")

# Calculating the test loss after fine-tuning with L-BFGS
mae_lbfgs = custom_mean_absolute_error(y_test, y_pred_lbfgs)
print(f"Test MAE with L-BFGS: {mae_lbfgs:.4f}")
# Out:
# Test MAE with L-BFGS: 0.0318
# Test Loss with L-BFGS: 0.1238
